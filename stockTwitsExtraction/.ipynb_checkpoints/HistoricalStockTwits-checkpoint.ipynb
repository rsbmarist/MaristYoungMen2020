# %%
#Import statements
import json
from pathlib import Path
import requests
import pandas as pd
import numpy as np
from pandas.io.json import json_normalize
import datetime
import os
import csv
import time
import ast

# %%
#This gets the parent directory of the current directory
current = os.getcwd()
path = Path(current)
twits_folder = str(path.parent)+'\\data\\StockTwits'
twits_folder
# Out:
# 'C:\\Users\\Russell\\OneDrive - Marist College\\School\\Spring 2020\\DATA 450 Data Capping\\Repository\\data\\StockTwits'

# %%
# The stock Symbols that we will iterate through
# Apple = AAPL
# Amazon = AMZN
# Google = GOOGL
# Microsoft = MSFT
# Dell = DELL
# IBM = IBM
# Intel = INTC
# HP = HPQ
# Facebook = FB
# Cisco Systems = CSCO
# Oracle = ORCL
# HP Enterprise = HPE
# Micron Tech = MU
# DXC Tech = DXC  We have recovered all available historical data March 2017 was IPO
# Thermo Fisher Scientific = TMO

#stockSymbol = ["AAPL", "AMZN", "GOOGL","MSFT", "DELL", "IBM", "INTC", "HPQ",
#               "FB", "CSCO", "ORCL", "HPE", "MU", "DXC", "TMO"] 

#Using only Apple to gather more days of twits, other companies have plenty of days.
stockSymbol = ["AAPL"]

# %%
#Gathers the json file and all needed data values.
def collect_Twits(res):
    try:
        
        #
        df = (json_normalize(res['messages'])[{'id','body','created_at','entities.sentiment.basic','symbols'}])
        
        #Reorders the columns
        df = df[['id','body','created_at','entities.sentiment.basic','symbols']]
        
        #Renames the columns
        df = df.rename(columns = {'created_at':'created', 'entities.sentiment.basic': 'tag'})
        
    except:
        df = (json_normalize(res['messages'])[{'id','body','created_at','entities.sentiment','symbols'}])
               
        #Reorders the columns and gets rid of old symbols column
        df = df[['id','body','created_at','entities.sentiment', 'symbols']]
        
        #Renames the columns
        df = df.rename(columns = {'created_at':'created', 'entities.sentiment': 'tag'})
        

    #The following loops reformat the symbols column
    #It creates a list of dictionaries, {symbol: "symbol of company mentioned", title: "name of company"}
    dataList=[]
    
    for index in df['symbols']:
        symbolsList = []

        for diction in index:

            symbolsList.append({'symbol' : diction.get('symbol'), 'title' : diction.get('title')})
            
        dataList.append(symbolsList)
        
    df.insert(5, "newSymbols" ,dataList)
    
    df = df[['id','body','created','tag', 'newSymbols']]

    #Replaces the NAN with a string "none"
    df = df.replace(np.nan, 'none', regex=True)
    
    #Replaces the string as a datetime variable
    dateFormat = "%Y-%m-%dT%H:%M:%SZ"
    df['created'] = pd.to_datetime(df['created'], format=dateFormat)
    
    #returns the dataframe in correct format
    return df

# %%
while True:
    for symbol in stockSymbol:
    
        #selects the file to add to
        file = twits_folder+'\\{}_twits.csv'.format(symbol)
    
        historicalTwits = pd.read_csv(file)
        oldestID = historicalTwits['id'].iloc[-1]
    
        url = "https://api.stocktwits.com/api/2/streams/symbol/{}.json".format(symbol)
        response = requests.get(url, params = {'max' :  oldestID}).json()
        
        if response['response']['status'] == 429:
            print("requests exceeded")
            time.sleep(600)
            continue
        
        if not (response['cursor']['more']):
            stockSymbol.remove(symbol)
            continue
    
        tempTwitsDf = collect_Twits(response)

        newHistoricalTwits = historicalTwits.append(tempTwitsDf)
    
        newHistoricalTwits.to_csv(file, index=False)
        time.sleep(15)
        #newHistoricalTwits.to_csv(r'{}_twitsCopy.csv'.format(symbol), index=False)
        time.sleep(15)

# %%
response
# Out:
# {'response': {'status': 200},
#  'symbol': {'id': 864,
#   'symbol': 'AMZN',
#   'title': 'Amazon.com Inc.',
#   'aliases': [],
#   'is_following': False,
#   'watchlist_count': 244429},
#  'cursor': {'more': True, 'since': 187900163, 'max': 187888660},
#  'messages': [{'id': 187900163,
#    'body': '$AMZN \nThought I saw $1790. The algos must have missed a beat on their selling.',
#    'created_at': '2019-12-23T19:24:54Z',
#    'user': {'id': 1255649,
#     'username': 'pauldrew2006',
#     'name': 'Paul Drew',
#     'avatar_url': 'http://avatars.stocktwits.com/images/default_avatar_thumb.jpg',
#     'avatar_url_ssl': 'https://s3.amazonaws.com/st-avatars/images/default_avatar_thumb.jpg',
#     'join_date': '2017-11-06',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 35,
#     'following': 51,
#     'ideas': 9386,
#     'watchlist_stocks_count': 297,
#     'like_count': 1193,
#     'plus_tier': '',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 1149,
#     'title': 'StockTwits for iOS',
#     'url': 'http://www.stocktwits.com/mobile'},
#    'symbols': [{'id': 864,
#      'symbol': 'AMZN',
#      'title': 'Amazon.com Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 244429}],
#    'mentioned_users': [],
#    'entities': {'sentiment': None},
#    'filters': {'day_counts': 33, 'official_api': True}},
#   {'id': 187899803,
#    'body': '$AMZN  can someone at stocktwits please list the new stock TFC  \n \nit is the new stock created after the merger of suntrust and BB&amp;T banks.. \n \nTruist Financial or TFC \n \nthank you',
#    'created_at': '2019-12-23T19:22:39Z',
#    'user': {'id': 2870246,
#     'username': 'lmhlmh',
#     'name': 'josh smith',
#     'avatar_url': 'http://avatars.stocktwits.com/images/default_avatar_thumb.jpg',
#     'avatar_url_ssl': 'https://s3.amazonaws.com/st-avatars/images/default_avatar_thumb.jpg',
#     'join_date': '2019-10-18',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 0,
#     'following': 1,
#     'ideas': 122,
#     'watchlist_stocks_count': 24,
#     'like_count': 17,
#     'plus_tier': '',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 2269,
#     'title': 'StockTwits Web',
#     'url': 'https://stocktwits.com'},
#    'symbols': [{'id': 864,
#      'symbol': 'AMZN',
#      'title': 'Amazon.com Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 244429}],
#    'conversation': {'parent_message_id': 187899803,
#     'in_reply_to_message_id': None,
#     'parent': True,
#     'replies': 2},
#    'mentioned_users': [],
#    'entities': {'sentiment': None},
#    'filters': {'day_counts': 1, 'official_api': True}},
#   {'id': 187899339,
#    'body': '$AMZN riding the collecting premium on this trend till it doesn’t work',
#    'created_at': '2019-12-23T19:19:40Z',
#    'user': {'id': 1631754,
#     'username': 'DennPennies',
#     'name': 'James Denn',
#     'avatar_url': 'http://avatars.stocktwits.com/images/default_avatar_thumb.jpg',
#     'avatar_url_ssl': 'https://s3.amazonaws.com/st-avatars/images/default_avatar_thumb.jpg',
#     'join_date': '2018-09-27',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 6,
#     'following': 8,
#     'ideas': 1010,
#     'watchlist_stocks_count': 34,
#     'like_count': 411,
#     'plus_tier': '',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 1149,
#     'title': 'StockTwits for iOS',
#     'url': 'http://www.stocktwits.com/mobile'},
#    'symbols': [{'id': 864,
#      'symbol': 'AMZN',
#      'title': 'Amazon.com Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 244429}],
#    'mentioned_users': [],
#    'entities': {'sentiment': None},
#    'filters': {'day_counts': 1, 'official_api': True}},
#   {'id': 187899327,
#    'body': '$AMZN ordered yesterday, delivered today!  #CountTheSmilingBoxes',
#    'created_at': '2019-12-23T19:19:36Z',
#    'user': {'id': 72831,
#     'username': 'vu_jade',
#     'name': 'Victor Jade',
#     'avatar_url': 'https://avatars.stocktwits.com/production/72831/thumb-1578916812.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/72831/thumb-1578916812.png',
#     'join_date': '2011-04-20',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 179,
#     'following': 53,
#     'ideas': 13175,
#     'watchlist_stocks_count': 298,
#     'like_count': 5661,
#     'plus_tier': '',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 2269,
#     'title': 'StockTwits Web',
#     'url': 'https://stocktwits.com'},
#    'symbols': [{'id': 864,
#      'symbol': 'AMZN',
#      'title': 'Amazon.com Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 244429}],
#    'mentioned_users': [],
#    'entities': {'sentiment': {'basic': 'Bullish'}},
#    'filters': {'day_counts': 15, 'official_api': True}},
#   {'id': 187899181,
#    'body': '$AMZN you better all pray the market doesn’t go down 1% cause this will be down 100$ lol.. you ain’t never gonna see over 1800',
#    'created_at': '2019-12-23T19:18:36Z',
#    'user': {'id': 177511,
#     'username': '200pips',
#     'name': 'Traderboy',
#     'avatar_url': 'https://avatars.stocktwits.com/production/177511/thumb-1515356758.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/177511/thumb-1515356758.png',
#     'join_date': '2012-08-16',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 1007,
#     'following': 72,
#     'ideas': 40179,
#     'watchlist_stocks_count': 116,
#     'like_count': 2540,
#     'plus_tier': '',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 1149,
#     'title': 'StockTwits for iOS',
#     'url': 'http://www.stocktwits.com/mobile'},
#    'symbols': [{'id': 864,
#      'symbol': 'AMZN',
#      'title': 'Amazon.com Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 244429}],
#    'mentioned_users': [],
#    'entities': {'sentiment': {'basic': 'Bearish'}},
#    'filters': {'day_counts': 1, 'official_api': True}},
#   {'id': 187897360,
#    'body': '$FB   I will die with my $FB, $BABA, $AAPL, and $AMZN shares , yaaasssss !!',
#    'created_at': '2019-12-23T19:07:24Z',
#    'user': {'id': 2956678,
#     'username': 'mbomba1',
#     'name': 'mbomba1',
#     'avatar_url': 'https://avatars.stocktwits.com/production/2956678/thumb-1578899903.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/2956678/thumb-1578899903.png',
#     'join_date': '2019-12-09',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 37,
#     'following': 4,
#     'ideas': 967,
#     'watchlist_stocks_count': 9,
#     'like_count': 1453,
#     'plus_tier': '',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 2269,
#     'title': 'StockTwits Web',
#     'url': 'https://stocktwits.com'},
#    'symbols': [{'id': 686,
#      'symbol': 'AAPL',
#      'title': 'Apple Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 348737},
#     {'id': 864,
#      'symbol': 'AMZN',
#      'title': 'Amazon.com Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 244429},
#     {'id': 7871,
#      'symbol': 'FB',
#      'title': 'Facebook',
#      'aliases': ['FBOOK'],
#      'is_following': False,
#      'watchlist_count': 245670},
#     {'id': 12100,
#      'symbol': 'BABA',
#      'title': 'Alibaba',
#      'aliases': ['ALIBABA'],
#      'is_following': False,
#      'watchlist_count': 168477}],
#    'conversation': {'parent_message_id': 187897360,
#     'in_reply_to_message_id': None,
#     'parent': True,
#     'replies': 1},
#    'likes': {'total': 12,
#     'user_ids': [251592,
#      621159,
#      387115,
#      2862738,
#      1900305,
#      1767436,
#      1221044,
#      949773,
#      1031533,
#      763628,
#      1900902,
#      758267]},
#    'mentioned_users': [],
#    'entities': {'sentiment': {'basic': 'Bullish'}},
#    'filters': {'day_counts': 23, 'official_api': True}},
#   {'id': 187897275,
#    'body': 'Best short idea \n \nsee report: http://bit.ly/36VjjS2 \n \n#Trade #Trading #Trades #NASDAQ #NYSE #Global #Finance #Bearish #Sell #Signl #Signals #UpTrend #Stock #Stocks #StockMarket #Model #Targets $AMZN #AMZN #Amazon #Quant #MarketIntelligence #TechnicalAnalysis #TradeSetup',
#    'created_at': '2019-12-23T19:06:46Z',
#    'user': {'id': 804251,
#     'username': '3rD_EYE',
#     'name': 'Third EYE',
#     'avatar_url': 'https://avatars.stocktwits.com/production/804251/thumb-1469562391.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/804251/thumb-1469562391.png',
#     'join_date': '2016-07-26',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 114,
#     'following': 148,
#     'ideas': 1226,
#     'watchlist_stocks_count': 1,
#     'like_count': 83,
#     'plus_tier': '',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 2269,
#     'title': 'StockTwits Web',
#     'url': 'https://stocktwits.com'},
#    'symbols': [{'id': 864,
#      'symbol': 'AMZN',
#      'title': 'Amazon.com Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 244323}],
#    'links': [{'title': None,
#      'url': 'http://bit.ly/36VjjS2',
#      'shortened_url': 'http://bit.ly/36VjjS2',
#      'shortened_expanded_url': 'dynamiccapitalholdingsllc.c...',
#      'description': None,
#      'image': None,
#      'created_at': '2019-12-23T19:06:47Z',
#      'video_url': None,
#      'source': {'name': 'Dynamiccapitalholdingsllc',
#       'website': 'http://www.dynamiccapitalholdingsllc.com'}}],
#    'mentioned_users': [],
#    'entities': {'sentiment': {'basic': 'Bearish'}},
#    'filters': {'day_counts': 1, 'official_api': True}},
#   {'id': 187896236,
#    'body': '$AMZN so people are excited about the debt that was given by china? Is that what i&#39;m reading lol.....',
#    'created_at': '2019-12-23T19:00:25Z',
#    'user': {'id': 1423094,
#     'username': 'SenseiOpt',
#     'name': 'Sensei ▪️',
#     'avatar_url': 'https://avatars.stocktwits.com/production/1423094/thumb-1577487155.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/1423094/thumb-1577487155.png',
#     'join_date': '2018-02-25',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 105,
#     'following': 17,
#     'ideas': 5955,
#     'watchlist_stocks_count': 36,
#     'like_count': 2328,
#     'plus_tier': '',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 2269,
#     'title': 'StockTwits Web',
#     'url': 'https://stocktwits.com'},
#    'symbols': [{'id': 864,
#      'symbol': 'AMZN',
#      'title': 'Amazon.com Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 244429}],
#    'conversation': {'parent_message_id': 187896236,
#     'in_reply_to_message_id': None,
#     'parent': True,
#     'replies': 1},
#    'mentioned_users': [],
#    'entities': {'sentiment': {'basic': 'Bearish'}},
#    'filters': {'day_counts': 53, 'official_api': True}},
#   {'id': 187896031,
#    'body': '$AMZN NEW ARTICLE : Apple Sports Could Be Game Changer https://dashboard.stck.pro/news.php?ticker=AMZN&amp;rowid=3052526 Get all the latest $AMZN related news here : https://dashboard.stck.pro/news.php?ticker=AMZN',
#    'created_at': '2019-12-23T18:59:05Z',
#    'user': {'id': 1555408,
#     'username': 'STCKPRO',
#     'name': 'STCK.PRO',
#     'avatar_url': 'https://avatars.stocktwits.com/production/1555408/thumb-1576077822.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/1555408/thumb-1576077822.png',
#     'join_date': '2018-07-24',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 716,
#     'following': 8,
#     'ideas': 62802,
#     'watchlist_stocks_count': 15,
#     'like_count': 36,
#     'plus_tier': 'month',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 5011,
#     'title': 'STCK.PRO',
#     'url': 'https://dashboard.stck.pro'},
#    'symbols': [{'id': 864,
#      'symbol': 'AMZN',
#      'title': 'Amazon.com Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 244323}],
#    'links': [{'title': 'AMAZON.COM (AMZN) News - STCK.PRO',
#      'url': 'https://dashboard.stck.pro/news.php?ticker=AMZN&rowid=3052526',
#      'shortened_url': 'https://dashboard.stck.pro/news.php?ticker=AMZN&rowid=3052526',
#      'shortened_expanded_url': 'dashboard.stck.pro/news.php...',
#      'description': 'Create watchlists and get real-time prices and news updates for all your watchlist symbols. join the STCK.PRO community of +40.000 active users and discover the power of social financial news!',
#      'image': 'https://dashboard.stck.pro/img/stocktwits.png',
#      'created_at': '2019-12-23T18:59:10Z',
#      'video_url': None,
#      'source': {'name': 'Stck', 'website': 'https://dashboard.stck.pro'}}],
#    'mentioned_users': [],
#    'entities': {'sentiment': None},
#    'filters': {'day_counts': 399, 'official_api': False}},
#   {'id': 187895593,
#    'body': '$AMZN \nA rip your face off shorts rally today! This pig is killing it.',
#    'created_at': '2019-12-23T18:56:04Z',
#    'user': {'id': 1255649,
#     'username': 'pauldrew2006',
#     'name': 'Paul Drew',
#     'avatar_url': 'http://avatars.stocktwits.com/images/default_avatar_thumb.jpg',
#     'avatar_url_ssl': 'https://s3.amazonaws.com/st-avatars/images/default_avatar_thumb.jpg',
#     'join_date': '2017-11-06',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 35,
#     'following': 51,
#     'ideas': 9386,
#     'watchlist_stocks_count': 297,
#     'like_count': 1193,
#     'plus_tier': '',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 1149,
#     'title': 'StockTwits for iOS',
#     'url': 'http://www.stocktwits.com/mobile'},
#    'symbols': [{'id': 864,
#      'symbol': 'AMZN',
#      'title': 'Amazon.com Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 244429}],
#    'likes': {'total': 1, 'user_ids': [407406]},
#    'mentioned_users': [],
#    'entities': {'sentiment': None},
#    'filters': {'day_counts': 31, 'official_api': True}},
#   {'id': 187894869,
#    'body': '$AMZN come January 2nd it’ll breakout with the January Effect and new tax year. Your posts are cute my friend. So cute.',
#    'created_at': '2019-12-23T18:51:09Z',
#    'user': {'id': 767238,
#     'username': 'Thankfulness',
#     'name': 'Toss A Coin To Your Witcher',
#     'avatar_url': 'https://avatars.stocktwits.com/production/767238/thumb-1580352664.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/767238/thumb-1580352664.png',
#     'join_date': '2016-06-06',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 1574,
#     'following': 69,
#     'ideas': 35303,
#     'watchlist_stocks_count': 147,
#     'like_count': 40642,
#     'plus_tier': '',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 1149,
#     'title': 'StockTwits for iOS',
#     'url': 'http://www.stocktwits.com/mobile'},
#    'symbols': [{'id': 864,
#      'symbol': 'AMZN',
#      'title': 'Amazon.com Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 244323}],
#    'conversation': {'parent_message_id': 187894869,
#     'in_reply_to_message_id': None,
#     'parent': True,
#     'replies': 1},
#    'likes': {'total': 1, 'user_ids': [1609953]},
#    'reshare_message': {'reshared_count': 1,
#     'reshared_deleted': False,
#     'reshared_user_deleted': False,
#     'parent_reshared_deleted': False,
#     'message': {'id': 187890033,
#      'body': '$AMZN - Here is Santa checking out his AMZN stock one last time hoping for a rally too before his all night around the world adventure.\n\nAmazon will deliver more packages than Santa but will not get a lick of market movement for such a feat...\n\nI remain Bullish on this Bullsh#t',
#      'created_at': '2019-12-23T18:23:08Z',
#      'user': {'id': 1847112,
#       'username': 'derek_james',
#       'name': 'Derek S',
#       'avatar_url': 'https://avatars.stocktwits.com/production/1847112/thumb-1549227187.png',
#       'avatar_url_ssl': 'https://avatars.stocktwits.com/production/1847112/thumb-1549227187.png',
#       'join_date': '2019-02-03',
#       'official': False,
#       'identity': 'User',
#       'classification': [],
#       'followers': 87,
#       'following': 3,
#       'ideas': 3752,
#       'watchlist_stocks_count': 33,
#       'like_count': 699,
#       'plus_tier': '',
#       'premium_room': '',
#       'trade_app': False},
#      'source': {'id': 2269,
#       'title': 'StockTwits Web',
#       'url': 'https://stocktwits.com'},
#      'symbols': [{'id': 864,
#        'symbol': 'AMZN',
#        'title': 'Amazon.com Inc.',
#        'aliases': [],
#        'is_following': False,
#        'watchlist_count': 244323}],
#      'conversation': {'parent_message_id': 187890033,
#       'in_reply_to_message_id': None,
#       'parent': True,
#       'replies': 1},
#      'likes': {'total': 3, 'user_ids': [407406, 767238, 1900305]},
#      'mentioned_users': [],
#      'entities': {'chart': {'thumb': 'https://charts.stocktwits.com/production/small_187890033.jpg',
#        'large': 'https://charts.stocktwits.com/production/large_187890033.jpg',
#        'original': 'https://charts.stocktwits.com/production/original_187890033.jpg',
#        'url': 'https://charts.stocktwits.com/production/original_187890033.jpg'},
#       'sentiment': {'basic': 'Bullish'}},
#      'filters': {'day_counts': 7, 'official_api': True}}},
#    'mentioned_users': [],
#    'entities': {'sentiment': None},
#    'filters': {'day_counts': 12, 'official_api': True}},
#   {'id': 187894481,
#    'body': '$AMZN that moment when a social media platform is higher on the year than this dog😂',
#    'created_at': '2019-12-23T18:48:51Z',
#    'user': {'id': 1744694,
#     'username': 'Stonktrader69',
#     'name': 'Stonktrader69',
#     'avatar_url': 'http://avatars.stocktwits.com/images/default_avatar_thumb.jpg',
#     'avatar_url_ssl': 'https://s3.amazonaws.com/st-avatars/images/default_avatar_thumb.jpg',
#     'join_date': '2018-12-04',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 3,
#     'following': 0,
#     'ideas': 1178,
#     'watchlist_stocks_count': 31,
#     'like_count': 531,
#     'plus_tier': '',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 1149,
#     'title': 'StockTwits for iOS',
#     'url': 'http://www.stocktwits.com/mobile'},
#    'symbols': [{'id': 864,
#      'symbol': 'AMZN',
#      'title': 'Amazon.com Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 244429}],
#    'mentioned_users': [],
#    'entities': {'sentiment': None},
#    'filters': {'day_counts': 8, 'official_api': True}},
#   {'id': 187894283,
#    'body': '$AMZN this is just plain flat for today.   When last has this had a 2% run up? It&#39;s been months',
#    'created_at': '2019-12-23T18:47:29Z',
#    'user': {'id': 631520,
#     'username': 'drew72rich',
#     'name': 'Drew',
#     'avatar_url': 'https://avatars.stocktwits.com/production/631520/thumb-1478473336.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/631520/thumb-1478473336.png',
#     'join_date': '2015-11-11',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 73,
#     'following': 153,
#     'ideas': 4296,
#     'watchlist_stocks_count': 44,
#     'like_count': 4379,
#     'plus_tier': '',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 2095,
#     'title': 'StockTwits For Android ',
#     'url': 'http://www.stocktwits.com/mobile'},
#    'symbols': [{'id': 864,
#      'symbol': 'AMZN',
#      'title': 'Amazon.com Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 244429}],
#    'mentioned_users': [],
#    'entities': {'sentiment': None},
#    'filters': {'day_counts': 8, 'official_api': True}},
#   {'id': 187893991,
#    'body': '$AMZN sigh, volatility on this for the last 6-7 years seems to have gone.',
#    'created_at': '2019-12-23T18:45:46Z',
#    'user': {'id': 517619,
#     'username': 'profitabletrade',
#     'name': 'Angela',
#     'avatar_url': 'https://avatars.stocktwits.com/production/517619/thumb-1437668713.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/517619/thumb-1437668713.png',
#     'join_date': '2015-05-14',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 44,
#     'following': 42,
#     'ideas': 2074,
#     'watchlist_stocks_count': 230,
#     'like_count': 411,
#     'plus_tier': '',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 1149,
#     'title': 'StockTwits for iOS',
#     'url': 'http://www.stocktwits.com/mobile'},
#    'symbols': [{'id': 864,
#      'symbol': 'AMZN',
#      'title': 'Amazon.com Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 244429}],
#    'mentioned_users': [],
#    'entities': {'sentiment': None},
#    'filters': {'day_counts': 2, 'official_api': True}},
#   {'id': 187893821,
#    'body': '$AMZN 1789 fail',
#    'created_at': '2019-12-23T18:44:47Z',
#    'user': {'id': 41685,
#     'username': 'Wat_Do_I_Know',
#     'name': 'JB',
#     'avatar_url': 'https://avatars.stocktwits.com/production/41685/thumb-1372799234.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/41685/thumb-1372799234.png',
#     'join_date': '2011-01-10',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 18,
#     'following': 19,
#     'ideas': 852,
#     'watchlist_stocks_count': 17,
#     'like_count': 240,
#     'plus_tier': '',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 1149,
#     'title': 'StockTwits for iOS',
#     'url': 'http://www.stocktwits.com/mobile'},
#    'symbols': [{'id': 864,
#      'symbol': 'AMZN',
#      'title': 'Amazon.com Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 244429}],
#    'mentioned_users': [],
#    'entities': {'sentiment': None},
#    'filters': {'day_counts': 2, 'official_api': True}},
#   {'id': 187893715,
#    'body': 'Rivian Closes $1.3B Funding Round $AMZN $BLK $F https://benzinga.com/z/15034841#.XgEIvQ-O9kI.twitter',
#    'created_at': '2019-12-23T18:44:06Z',
#    'user': {'id': 7108,
#     'username': 'Benzinga',
#     'name': 'Benzinga',
#     'avatar_url': 'https://avatars.stocktwits.com/production/7108/thumb-1568827739.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/7108/thumb-1568827739.png',
#     'join_date': '2009-12-04',
#     'official': True,
#     'identity': 'Official',
#     'classification': ['suggested', 'official'],
#     'followers': 281722,
#     'following': 530,
#     'ideas': 112033,
#     'watchlist_stocks_count': 1,
#     'like_count': 103,
#     'plus_tier': '',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 2269,
#     'title': 'StockTwits Web',
#     'url': 'https://stocktwits.com'},
#    'symbols': [{'id': 864,
#      'symbol': 'AMZN',
#      'title': 'Amazon.com Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 244429},
#     {'id': 4544,
#      'symbol': 'BLK',
#      'title': 'BlackRock, Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 3972},
#     {'id': 5281,
#      'symbol': 'F',
#      'title': 'Ford Motor Co.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 68248}],
#    'links': [{'title': 'Rivian Closes $1.3B Funding Round',
#      'url': 'https://benzinga.com/z/15034841#.XgEIvQ-O9kI.twitter',
#      'shortened_url': 'https://benzinga.com/z/15034841#.XgEIvQ-O9kI.twitter',
#      'shortened_expanded_url': 'benzinga.com/news/19/12/150...',
#      'description': 'The year 2019 has been good to Rivian, an electric truck maker headquartered in Plymouth, Michigan. The company completed four funding rounds this year, and the latest, announced on Dec. 23, was a doozy: a $1.3 billion investment led by funds and accounts advised by T. Rowe Price Associates. Amazon.com, Inc.',
#      'image': 'https://cdn2.benzinga.com/files/imagecache/story_image_685x375C/images/story/2012/tyre-1714669_1920_1_2.jpg',
#      'created_at': '2019-12-23T18:44:08Z',
#      'video_url': None,
#      'source': {'name': 'Benzinga', 'website': 'https://www.benzinga.com'}}],
#    'mentioned_users': [],
#    'entities': {'sentiment': None},
#    'filters': {'day_counts': 29, 'official_api': True}},
#   {'id': 187893632,
#    'body': '$AMZN amazon needs to release fire 2 phone.',
#    'created_at': '2019-12-23T18:43:34Z',
#    'user': {'id': 440644,
#     'username': 'Chris1233',
#     'name': 'Chris',
#     'avatar_url': 'http://avatars.stocktwits.com/images/default_avatar_thumb.jpg',
#     'avatar_url_ssl': 'https://s3.amazonaws.com/st-avatars/images/default_avatar_thumb.jpg',
#     'join_date': '2014-12-23',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 8,
#     'following': 47,
#     'ideas': 902,
#     'watchlist_stocks_count': 53,
#     'like_count': 319,
#     'plus_tier': '',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 1149,
#     'title': 'StockTwits for iOS',
#     'url': 'http://www.stocktwits.com/mobile'},
#    'symbols': [{'id': 864,
#      'symbol': 'AMZN',
#      'title': 'Amazon.com Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 244323}],
#    'mentioned_users': [],
#    'entities': {'sentiment': None},
#    'filters': {'day_counts': 1, 'official_api': True}},
#   {'id': 187893127,
#    'body': '$AMZN 27 sec ago: &#39;Amazon&#39;s Choice&#39; attached to unsafe, mislabeled products - WSJ: Amazon applies its &quot;Amazon&#39;s Choice&quot; badge to some unsafe and mislabeled products, according to a WSJ investigation. https://newsfilter.io/articles/amazons-choice-attached-to-unsafe-mislabeled-products---wsj-ee2101f0efcd5d1d5e801977e6e2c3bb',
#    'created_at': '2019-12-23T18:40:34Z',
#    'user': {'id': 2762379,
#     'username': 'newsfilter',
#     'name': '@newsfilterio',
#     'avatar_url': 'https://avatars.stocktwits.com/production/2762379/thumb-1570180226.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/2762379/thumb-1570180226.png',
#     'join_date': '2019-09-01',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 1805,
#     'following': 8,
#     'ideas': 225143,
#     'watchlist_stocks_count': 1,
#     'like_count': 435,
#     'plus_tier': 'month',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 4948,
#     'title': 'Newsfilter.io',
#     'url': 'https://newsfilter.io'},
#    'symbols': [{'id': 864,
#      'symbol': 'AMZN',
#      'title': 'Amazon.com Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 244429}],
#    'links': [{'title': "'Amazon's Choice' attached to unsafe, mislabeled products - WSJ",
#      'url': 'https://newsfilter.io/articles/amazons-choice-attached-to-unsafe-mislabeled-products---wsj-ee2101f0efcd5d1d5e801977e6e2c3bb',
#      'shortened_url': 'https://newsfilter.io/articles/amazons-choice-attached-to-unsafe-mislabeled-products---wsj-ee2101f0efcd5d1d5e801977e6e2c3bb',
#      'shortened_expanded_url': 'newsfilter.io/articles/amaz...',
#      'description': 'Amazon applies its "Amazon\'s Choice" badge to some unsafe and mislabeled products, according to a WSJ investigation.The selected products also include items that violate Amazon\'s own policies and controlled substances, including steroids and marijuana products.Third-party merchants have found ways to manipulate the algorithms by pushing customers to purchase an item, which boosts the listing.Amazon\'s statement: "When deciding to badge a product as Amazon\'s Choice, we proactively incorporate a number of factors that are designed to protect customers from those policy violations.',
#      'image': 'https://newsfilter.io/meta-images/?url=https://storage.googleapis.com/iex/api/logos/AMZN.png',
#      'created_at': '2019-12-23T18:40:37Z',
#      'video_url': None,
#      'source': {'name': 'Newsfilter', 'website': 'https://newsfilter.io'}}],
#    'mentioned_users': [],
#    'entities': {'chart': {'thumb': 'https://charts.stocktwits.com/production/small_187893127.png',
#      'large': 'https://charts.stocktwits.com/production/large_187893127.png',
#      'original': 'https://charts.stocktwits.com/production/original_187893127.png',
#      'url': 'https://charts.stocktwits.com/production/original_187893127.png'},
#     'sentiment': None},
#    'filters': {'day_counts': 914, 'official_api': False}},
#   {'id': 187893025,
#    'body': '$UBER my top position. $LYFT my second biggest position.\n\nPrediction: $LYFT will be a buyout candidate.\n\nI predict $AMZN will express interest in buying $LYFT as $UBER is now competing directly with $AMZN in many fronts.',
#    'created_at': '2019-12-23T18:39:56Z',
#    'user': {'id': 1237817,
#     'username': 'CalStockPicker',
#     'name': 'The Oracle @ UC Berkeley',
#     'avatar_url': 'https://avatars.stocktwits.com/production/1237817/thumb-1575785540.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/1237817/thumb-1575785540.png',
#     'join_date': '2017-10-23',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 422,
#     'following': 97,
#     'ideas': 4296,
#     'watchlist_stocks_count': 131,
#     'like_count': 762,
#     'plus_tier': '',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 2269,
#     'title': 'StockTwits Web',
#     'url': 'https://stocktwits.com'},
#    'symbols': [{'id': 864,
#      'symbol': 'AMZN',
#      'title': 'Amazon.com Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 244429},
#     {'id': 11554,
#      'symbol': 'UBER',
#      'title': 'Uber',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 44021},
#     {'id': 12535,
#      'symbol': 'LYFT',
#      'title': 'Lyft, Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 25394}],
#    'conversation': {'parent_message_id': 187893025,
#     'in_reply_to_message_id': None,
#     'parent': True,
#     'replies': 1},
#    'likes': {'total': 1, 'user_ids': [1213192]},
#    'mentioned_users': [],
#    'entities': {'sentiment': {'basic': 'Bullish'}},
#    'filters': {'day_counts': 30, 'official_api': True}},
#   {'id': 187892816,
#    'body': '$AMZN doesn’t it seem like they are working really hard behind the scenes to keep this down',
#    'created_at': '2019-12-23T18:38:51Z',
#    'user': {'id': 480119,
#     'username': 'goupdarnit',
#     'name': 'goupdarnit',
#     'avatar_url': 'http://avatars.stocktwits.com/images/default_avatar_thumb.jpg',
#     'avatar_url_ssl': 'https://s3.amazonaws.com/st-avatars/images/default_avatar_thumb.jpg',
#     'join_date': '2015-03-05',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 8,
#     'following': 63,
#     'ideas': 1626,
#     'watchlist_stocks_count': 14,
#     'like_count': 2,
#     'plus_tier': '',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 1149,
#     'title': 'StockTwits for iOS',
#     'url': 'http://www.stocktwits.com/mobile'},
#    'symbols': [{'id': 864,
#      'symbol': 'AMZN',
#      'title': 'Amazon.com Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 244429}],
#    'mentioned_users': [],
#    'entities': {'sentiment': None},
#    'filters': {'day_counts': 8, 'official_api': True}},
#   {'id': 187892490,
#    'body': '&#39;Amazon&#39;s Choice&#39; attached to unsafe, mislabeled products - WSJ https://seekingalpha.com/news/3528244?source=ansh $AMZN',
#    'created_at': '2019-12-23T18:36:59Z',
#    'user': {'id': 308620,
#     'username': 'lecorb',
#     'name': 'Alighieri - Day Trader',
#     'avatar_url': 'https://avatars.stocktwits.com/production/308620/thumb-1570925692.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/308620/thumb-1570925692.png',
#     'join_date': '2014-02-03',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 513,
#     'following': 104,
#     'ideas': 11539,
#     'watchlist_stocks_count': 300,
#     'like_count': 175,
#     'plus_tier': '',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 2095,
#     'title': 'StockTwits For Android ',
#     'url': 'http://www.stocktwits.com/mobile'},
#    'symbols': [{'id': 864,
#      'symbol': 'AMZN',
#      'title': 'Amazon.com Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 244429}],
#    'links': [{'title': "'Amazon's Choice' attached to unsafe, mislabeled products - WSJ",
#      'url': 'https://seekingalpha.com/news/3528244?source=ansh',
#      'shortened_url': 'https://seekingalpha.com/news/3528244?source=ansh',
#      'shortened_expanded_url': 'seekingalpha.com/news/35282...',
#      'description': 'Amazon ( AMZN +0.1%) applies its "Amazon\'s Choice" badge to some unsafe and mislabeled products, according to a WSJ investigation. The selected products also include items that violate Amazon\'s own policies and controlled substances, including steroids and marijuana products. Third-party merchants have found ways to manipulate the algorithms by pushing customers to purchase an item, which boosts the listing.',
#      'image': 'https://static3.seekingalpha.com/assets/og_image_192-59bfd51c9fe6af025b2f9f96c807e46f8e2f06c5ae787b15bf1423e6c676d4db.png',
#      'created_at': '2019-12-23T18:37:00Z',
#      'video_url': None,
#      'source': {'name': 'Seeking Alpha',
#       'website': 'https://seekingalpha.com'}}],
#    'mentioned_users': [],
#    'entities': {'sentiment': None},
#    'filters': {'day_counts': 9, 'official_api': True}},
#   {'id': 187892445,
#    'body': '$AMZN Maybe we just need a boost. I say each of us get a billion $ in margin and pump this bad buy up. What do you say?',
#    'created_at': '2019-12-23T18:36:43Z',
#    'user': {'id': 1672969,
#     'username': 'WheresMyBREAD',
#     'name': 'Ethan B',
#     'avatar_url': 'https://avatars.stocktwits.com/production/1672969/thumb-1544830567.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/1672969/thumb-1544830567.png',
#     'join_date': '2018-10-22',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 27,
#     'following': 14,
#     'ideas': 1248,
#     'watchlist_stocks_count': 140,
#     'like_count': 492,
#     'plus_tier': '',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 1149,
#     'title': 'StockTwits for iOS',
#     'url': 'http://www.stocktwits.com/mobile'},
#    'symbols': [{'id': 864,
#      'symbol': 'AMZN',
#      'title': 'Amazon.com Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 244429}],
#    'mentioned_users': [],
#    'entities': {'sentiment': {'basic': 'Bullish'}},
#    'filters': {'day_counts': 9, 'official_api': True}},
#   {'id': 187891106,
#    'body': '$FB $AMZN $MSFT $GOOG $AAPL\nThe #FAMGA (#Facebook, #Amazon, #Microsoft, #Google and #Apple) has made over 750 acquisitions in the last 30 years. \n@CBInsights has a nice chart on the $1+ billion acquisitions from 1999 to 2019.',
#    'created_at': '2019-12-23T18:29:04Z',
#    'user': {'id': 190665,
#     'username': 'BravoTrader',
#     'name': '@BravoTrader',
#     'avatar_url': 'https://avatars.stocktwits.com/production/190665/thumb-1561165964.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/190665/thumb-1561165964.png',
#     'join_date': '2012-10-23',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 193,
#     'following': 24,
#     'ideas': 1434,
#     'watchlist_stocks_count': 37,
#     'like_count': 65,
#     'plus_tier': '',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 2269,
#     'title': 'StockTwits Web',
#     'url': 'https://stocktwits.com'},
#    'symbols': [{'id': 686,
#      'symbol': 'AAPL',
#      'title': 'Apple Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 348737},
#     {'id': 864,
#      'symbol': 'AMZN',
#      'title': 'Amazon.com Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 244429},
#     {'id': 2044,
#      'symbol': 'GOOG',
#      'title': 'Alphabet Inc. Class C',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 128980},
#     {'id': 2735,
#      'symbol': 'MSFT',
#      'title': 'Microsoft Corporation',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 157952},
#     {'id': 7871,
#      'symbol': 'FB',
#      'title': 'Facebook',
#      'aliases': ['FBOOK'],
#      'is_following': False,
#      'watchlist_count': 245670}],
#    'likes': {'total': 1, 'user_ids': [9083]},
#    'mentioned_users': ['@CBInsights'],
#    'entities': {'chart': {'thumb': 'https://charts.stocktwits.com/production/small_187891106.png',
#      'large': 'https://charts.stocktwits.com/production/large_187891106.png',
#      'original': 'https://charts.stocktwits.com/production/original_187891106.png',
#      'url': 'https://charts.stocktwits.com/production/original_187891106.png'},
#     'sentiment': None},
#    'filters': {'day_counts': 4, 'official_api': True}},
#   {'id': 187890073,
#    'body': '$AMZN Is this not consolidation for another leg up?',
#    'created_at': '2019-12-23T18:23:21Z',
#    'user': {'id': 1672969,
#     'username': 'WheresMyBREAD',
#     'name': 'Ethan B',
#     'avatar_url': 'https://avatars.stocktwits.com/production/1672969/thumb-1544830567.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/1672969/thumb-1544830567.png',
#     'join_date': '2018-10-22',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 27,
#     'following': 14,
#     'ideas': 1248,
#     'watchlist_stocks_count': 140,
#     'like_count': 492,
#     'plus_tier': '',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 1149,
#     'title': 'StockTwits for iOS',
#     'url': 'http://www.stocktwits.com/mobile'},
#    'symbols': [{'id': 864,
#      'symbol': 'AMZN',
#      'title': 'Amazon.com Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 244429}],
#    'conversation': {'parent_message_id': 187890073,
#     'in_reply_to_message_id': None,
#     'parent': True,
#     'replies': 2},
#    'likes': {'total': 3, 'user_ids': [1062400, 348007, 1434622]},
#    'mentioned_users': [],
#    'entities': {'sentiment': None},
#    'filters': {'day_counts': 7, 'official_api': True}},
#   {'id': 187890033,
#    'body': '$AMZN - Here is Santa checking out his AMZN stock one last time hoping for a rally too before his all night around the world adventure.\n\nAmazon will deliver more packages than Santa but will not get a lick of market movement for such a feat...\n\nI remain Bullish on this Bullsh#t',
#    'created_at': '2019-12-23T18:23:08Z',
#    'user': {'id': 1847112,
#     'username': 'derek_james',
#     'name': 'Derek S',
#     'avatar_url': 'https://avatars.stocktwits.com/production/1847112/thumb-1549227187.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/1847112/thumb-1549227187.png',
#     'join_date': '2019-02-03',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 87,
#     'following': 3,
#     'ideas': 3749,
#     'watchlist_stocks_count': 33,
#     'like_count': 699,
#     'plus_tier': '',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 2269,
#     'title': 'StockTwits Web',
#     'url': 'https://stocktwits.com'},
#    'symbols': [{'id': 864,
#      'symbol': 'AMZN',
#      'title': 'Amazon.com Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 244429}],
#    'conversation': {'parent_message_id': 187890033,
#     'in_reply_to_message_id': None,
#     'parent': True,
#     'replies': 1},
#    'likes': {'total': 3, 'user_ids': [407406, 767238, 1900305]},
#    'reshares': {'reshared_count': 1, 'user_ids': [767238]},
#    'mentioned_users': [],
#    'entities': {'chart': {'thumb': 'https://charts.stocktwits.com/production/small_187890033.jpg',
#      'large': 'https://charts.stocktwits.com/production/large_187890033.jpg',
#      'original': 'https://charts.stocktwits.com/production/original_187890033.jpg',
#      'url': 'https://charts.stocktwits.com/production/original_187890033.jpg'},
#     'sentiment': {'basic': 'Bullish'}},
#    'filters': {'day_counts': 7, 'official_api': True}},
#   {'id': 187889980,
#    'body': '$AMZN up',
#    'created_at': '2019-12-23T18:22:53Z',
#    'user': {'id': 583432,
#     'username': 'Wolf50',
#     'name': 'Pedro Villagran-Garcia',
#     'avatar_url': 'https://avatars.stocktwits.com/production/583432/thumb-1452332788.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/583432/thumb-1452332788.png',
#     'join_date': '2015-08-25',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 51,
#     'following': 256,
#     'ideas': 372,
#     'watchlist_stocks_count': 92,
#     'like_count': 37,
#     'plus_tier': '',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 2095,
#     'title': 'StockTwits For Android ',
#     'url': 'http://www.stocktwits.com/mobile'},
#    'symbols': [{'id': 864,
#      'symbol': 'AMZN',
#      'title': 'Amazon.com Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 244429}],
#    'conversation': {'parent_message_id': 187889980,
#     'in_reply_to_message_id': None,
#     'parent': True,
#     'replies': 2},
#    'mentioned_users': [],
#    'entities': {'sentiment': {'basic': 'Bullish'}},
#    'filters': {'day_counts': 3, 'official_api': True}},
#   {'id': 187889648,
#    'body': '$AMZN - gotta laugh if not cry this  &quot;Santa Clause Rally Looks like for Amazon holders -',
#    'created_at': '2019-12-23T18:21:09Z',
#    'user': {'id': 1847112,
#     'username': 'derek_james',
#     'name': 'Derek S',
#     'avatar_url': 'https://avatars.stocktwits.com/production/1847112/thumb-1549227187.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/1847112/thumb-1549227187.png',
#     'join_date': '2019-02-03',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 87,
#     'following': 3,
#     'ideas': 3749,
#     'watchlist_stocks_count': 33,
#     'like_count': 699,
#     'plus_tier': '',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 2269,
#     'title': 'StockTwits Web',
#     'url': 'https://stocktwits.com'},
#    'symbols': [{'id': 864,
#      'symbol': 'AMZN',
#      'title': 'Amazon.com Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 244429}],
#    'likes': {'total': 2, 'user_ids': [767238, 407406]},
#    'mentioned_users': [],
#    'entities': {'chart': {'thumb': 'https://charts.stocktwits.com/production/small_187889648.jpg',
#      'large': 'https://charts.stocktwits.com/production/large_187889648.jpg',
#      'original': 'https://charts.stocktwits.com/production/original_187889648.jpg',
#      'url': 'https://charts.stocktwits.com/production/original_187889648.jpg'},
#     'sentiment': {'basic': 'Bullish'}},
#    'filters': {'day_counts': 6, 'official_api': True}},
#   {'id': 187889466,
#    'body': '$AMZN  What the &quot;Santa Clause Rally Looks like for Amazon holders - another bummer year unless tomorrow the 24th is &quot;magical&quot; -  $1800 was on my Christmas Wish List ....',
#    'created_at': '2019-12-23T18:19:59Z',
#    'user': {'id': 1847112,
#     'username': 'derek_james',
#     'name': 'Derek S',
#     'avatar_url': 'https://avatars.stocktwits.com/production/1847112/thumb-1549227187.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/1847112/thumb-1549227187.png',
#     'join_date': '2019-02-03',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 87,
#     'following': 3,
#     'ideas': 3749,
#     'watchlist_stocks_count': 33,
#     'like_count': 699,
#     'plus_tier': '',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 2269,
#     'title': 'StockTwits Web',
#     'url': 'https://stocktwits.com'},
#    'symbols': [{'id': 864,
#      'symbol': 'AMZN',
#      'title': 'Amazon.com Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 244429}],
#    'likes': {'total': 2, 'user_ids': [224024, 767238]},
#    'mentioned_users': [],
#    'entities': {'chart': {'thumb': 'https://charts.stocktwits.com/production/small_187889466.jpg',
#      'large': 'https://charts.stocktwits.com/production/large_187889466.jpg',
#      'original': 'https://charts.stocktwits.com/production/original_187889466.jpg',
#      'url': 'https://charts.stocktwits.com/production/original_187889466.jpg'},
#     'sentiment': {'basic': 'Bullish'}},
#    'filters': {'day_counts': 5, 'official_api': True}},
#   {'id': 187889119,
#    'body': '$AMZN NEW ARTICLE : 4 Reasons It Still Makes Sense to Get in on Amazon Stock https://dashboard.stck.pro/news.php?ticker=AMZN&amp;rowid=3052264 Get all the latest $AMZN related news here : https://dashboard.stck.pro/news.php?ticker=AMZN',
#    'created_at': '2019-12-23T18:18:05Z',
#    'user': {'id': 1555408,
#     'username': 'STCKPRO',
#     'name': 'STCK.PRO',
#     'avatar_url': 'https://avatars.stocktwits.com/production/1555408/thumb-1576077822.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/1555408/thumb-1576077822.png',
#     'join_date': '2018-07-24',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 719,
#     'following': 8,
#     'ideas': 63132,
#     'watchlist_stocks_count': 15,
#     'like_count': 36,
#     'plus_tier': 'month',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 5011,
#     'title': 'STCK.PRO',
#     'url': 'https://dashboard.stck.pro'},
#    'symbols': [{'id': 864,
#      'symbol': 'AMZN',
#      'title': 'Amazon.com Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 244429}],
#    'links': [{'title': 'AMAZON.COM (AMZN) News - STCK.PRO',
#      'url': 'https://dashboard.stck.pro/news.php?ticker=AMZN&rowid=3052264',
#      'shortened_url': 'https://dashboard.stck.pro/news.php?ticker=AMZN&rowid=3052264',
#      'shortened_expanded_url': 'dashboard.stck.pro/news.php...',
#      'description': 'Create watchlists and get real-time prices and news updates for all your watchlist symbols. join the STCK.PRO community of +40.000 active users and discover the power of social financial news!',
#      'image': 'https://dashboard.stck.pro/img/stocktwits.png',
#      'created_at': '2019-12-23T18:18:09Z',
#      'video_url': None,
#      'source': {'name': 'Stck', 'website': 'https://dashboard.stck.pro'}}],
#    'mentioned_users': [],
#    'entities': {'chart': {'thumb': 'https://charts.stocktwits.com/production/small_187889119.jpg',
#      'large': 'https://charts.stocktwits.com/production/large_187889119.jpg',
#      'original': 'https://charts.stocktwits.com/production/original_187889119.jpg',
#      'url': 'https://charts.stocktwits.com/production/original_187889119.jpg'},
#     'sentiment': None},
#    'filters': {'day_counts': 395, 'official_api': False}},
#   {'id': 187888660,
#    'body': '$HAL $AMZN 27 sec ago: Sanders, Warren Campaigns Spend the Most On Amazon While Trashing It: During the Democratic presidential debate in Los Angeles last week, Senator Elizabeth Warren once again made her positi.. https://newsfilter.io/articles/sanders-warren-campaigns-spend-the-most-on-amazon-while-trashing-it-007c47986f489215c9c3e255192de8f7',
#    'created_at': '2019-12-23T18:15:32Z',
#    'user': {'id': 2762379,
#     'username': 'newsfilter',
#     'name': '@newsfilterio',
#     'avatar_url': 'https://avatars.stocktwits.com/production/2762379/thumb-1570180226.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/2762379/thumb-1570180226.png',
#     'join_date': '2019-09-01',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 1805,
#     'following': 8,
#     'ideas': 225143,
#     'watchlist_stocks_count': 1,
#     'like_count': 435,
#     'plus_tier': 'month',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 4948,
#     'title': 'Newsfilter.io',
#     'url': 'https://newsfilter.io'},
#    'symbols': [{'id': 864,
#      'symbol': 'AMZN',
#      'title': 'Amazon.com Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 244429},
#     {'id': 5633,
#      'symbol': 'HAL',
#      'title': 'Halliburton Company',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 9368}],
#    'links': [{'title': 'Sanders, Warren Campaigns Spend the Most On Amazon While Trashing It',
#      'url': 'https://newsfilter.io/articles/sanders-warren-campaigns-spend-the-most-on-amazon-while-trashing-it-007c47986f489215c9c3e255192de8f7',
#      'shortened_url': 'https://newsfilter.io/articles/sanders-warren-campaigns-spend-the-most-on-amazon-while-trashing-it-007c47986f489215c9c3e255192de8f7',
#      'shortened_expanded_url': 'newsfilter.io/articles/sand...',
#      'description': 'During the Democratic presidential debate in Los Angeles last week, Senator Elizabeth Warren once again made her position on Amazon.com clear. "You know what unites my three brothers?" she asked, noting that one is a Democrat, the other two Republicans. "Amazon. They are furious that Amazon reported $10 billion in profits and paid zero in taxes."',
#      'image': 'https://assets.bwbx.io/images/users/iqjWHBFdfxIU/i6ir2prHtpU8/v1/-1x-1.jpg',
#      'created_at': '2019-12-23T18:15:35Z',
#      'video_url': None,
#      'source': {'name': 'Newsfilter', 'website': 'https://newsfilter.io'}}],
#    'likes': {'total': 1, 'user_ids': [597661]},
#    'mentioned_users': [],
#    'entities': {'chart': {'thumb': 'https://charts.stocktwits.com/production/small_187888660.jpg',
#      'large': 'https://charts.stocktwits.com/production/large_187888660.jpg',
#      'original': 'https://charts.stocktwits.com/production/original_187888660.jpg',
#      'url': 'https://charts.stocktwits.com/production/original_187888660.jpg'},
#     'sentiment': None},
#    'filters': {'day_counts': 888, 'official_api': False}}]}

# %%
#start the files and gather most recent data right now

#Do not RUN anymore!!

#for symbol in stockSymbol:
    
    #selects the file to add to
    #file = '{}_twits.csv'.format(symbol)
    
    #historicalTwits = pd.read_csv(file)
    #oldestID = historicalTwits['id'][-1]
    
    #url = "https://api.stocktwits.com/api/2/streams/symbol/{}.json".format(symbol)
    #response = requests.get(url, params = {'max' :  oldestID}).json()
    
    #response = requests.get(url).json()
    
    #tempTwitsDf = collect_Twits(response)
    
    #tempTwitsDf.to_csv(r'{}_twits.csv'.format(symbol), index=False)

# %% [markdown]
# ## This is file testing for the new repository

# %%
#This code will remove the specified text symbols.
# It was taken from stack overflow, here is the reference.
# https://stackoverflow.com/a/49146722/330558
def remove_emoji(string):
    emoji_pattern = re.compile("["
                           u"\U0001F600-\U0001F64F"  # emoticons
                           u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                           u"\U0001F680-\U0001F6FF"  # transport & map symbols
                           u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           u"\U00002702-\U000027B0"
                           u"\U000024C2-\U0001F251"
                           "]+", flags=re.UNICODE)
    return emoji_pattern.sub(r'', string)

# %%
file
# Out:
# 'C:\\Users\\Russell\\OneDrive - Marist College\\School\\Spring 2020\\DATA 450 Data Capping\\Repository\\data\\StockTwits\\AAPL_twits.csv'

# %%
dataFrametesting = pd.read_csv(file)

# %%
dataFrametesting
# Out:
#        Unnamed: 0         id  \
# 0               0  194214777
# 1               1  194214706
# 2               2  194214590
# 3               3  194214323
# 4               4  194214309
# 5               5  194214281
# 6               6  194213972
# 7               7  194213949
# 8               8  194213931
# 9               9  194213742
# 10             10  194213697
# 11             11  194213591
# 12             12  194213466
# 13             13  194213375
# 14             14  194213325
# 15             15  194213260
# 16             16  194213107
# 17             17  194213028
# 18             18  194213008
# 19             19  194212896
# 20             20  194212764
# 21             21  194212689
# 22             22  194212599
# 23             23  194212525
# 24             24  194212440
# 25             25  194212264
# 26             26  194212061
# 27             27  194211875
# 28             28  194211753
# 29             29  194211708
# ...           ...        ...
# 17880       17880  192264090
# 17881       17881  192264088
# 17882       17882  192264087
# 17883       17883  192264086
# 17884       17884  192264078
# 17885       17885  192264077
# 17886       17886  192264074
# 17887       17887  192264073
# 17888       17888  192264062
# 17889       17889  192264059
# 17890       17890  192264056
# 17891       17891  192264051
# 17892       17892  192264044
# 17893       17893  192264038
# 17894       17894  192264033
# 17895       17895  192264031
# 17896       17896  192264026
# 17897       17897  192264023
# 17898       17898  192264022
# 17899       17899  192264019
# 17900       17900  192264015
# 17901       17901  192264008
# 17902       17902  192264005
# 17903       17903  192264004
# 17904       17904  192264001
# 17905       17905  192263998
# 17906       17906  192263996
# 17907       17907  192263981
# 17908       17908  192263976
# 17909       17909  192263974
#
#                                                     body              created  \
# 0      $AAPL $CRM $AMD $BYND $LULU we all know nothin...  2020-02-10 20:10:04
# 1           At this rate, we may see 323 today. Go $AAPL  2020-02-10 20:09:43
# 2      $AAPL Tesla now resumed production in China. T...  2020-02-10 20:09:17
# 3                                      $AAPL delightful!  2020-02-10 20:08:11
# 4      $AAPL of course Trump interfered in the DOJ co...  2020-02-10 20:08:08
# 5                          $AAPL you just love to see it  2020-02-10 20:07:59
# 6                                $AAPL and $CTSO winners  2020-02-10 20:06:40
# 7      $AAPL REVERSAL! Going to EXPLODE! $$$$$$$$$$$$...  2020-02-10 20:06:34
# 8      $AAPL funny how certain people get sensitive w...  2020-02-10 20:06:31
# 9      $AAPL $spy get 2nd, 3rd mortgage, you can win ...  2020-02-10 20:05:43
# 10                                           $AAPL Bingo  2020-02-10 20:05:33
# 11          $SPY $SPX $AAPL $NVDA $SHOP\nPower hour! 🚀🚀🚀  2020-02-10 20:05:08
# 12     $AAPL Market is on crack and there’s no way ar...  2020-02-10 20:04:36
# 13     $AAPL Austria&#39;s AMS aims for domination ag...  2020-02-10 20:04:09
# 14     $AAPL $SPY $MSFT $GOOG $AMD \n\n&quot;The Fed ...  2020-02-10 20:03:59
# 15     $AAPL no way msft has a larger market cap than...  2020-02-10 20:03:43
# 16     $SPY $AAPL Should have known something was wro...  2020-02-10 20:03:00
# 17         $AAPL best market on the planet $$$$$$$$$$$$$  2020-02-10 20:02:45
# 18     $AAPL That virus will have to kill everybody b...  2020-02-10 20:02:38
# 19     $AAPL I’m glad bears warned us about today’s c...  2020-02-10 20:02:04
# 20     $AAPL  \nConfucius say: You&#39;ll be fine wit...  2020-02-10 20:01:36
# 21     $AAPL Held calls over the weekend and almost p...  2020-02-10 20:01:17
# 22                                 $AAPL okay $323 then!  2020-02-10 20:00:54
# 23     $AAPL The day started with so much promise, eh...  2020-02-10 20:00:38
# 24     $AAPL Should #Coronavirus Concerns Prevent You...  2020-02-10 20:00:17
# 25                    $AAPL bought calls 323.5/325 Feb21  2020-02-10 19:59:37
# 26          $AAPL my puts!  I was told Foxconn.  Oh well  2020-02-10 19:58:50
# 27                               $AAPL too easy now $$$$  2020-02-10 19:58:08
# 28                  $AAPL  Up Up Up, calls here we gooo.  2020-02-10 19:57:42
# 29                               $AAPL Loaded! $$$$$$$$$  2020-02-10 19:57:33
# ...                                                  ...                  ...
# 17880                       $AAPL will turn red. Buy buy  2020-01-28 21:33:54
# 17881  The SHOW GOES ON! $AAPL with a BLOWOUT quarter...  2020-01-28 21:33:54
# 17882  $MU —-$AAPL Big Beats on top and bottom with g...  2020-01-28 21:33:54
# 17883         $SPY told ya to buy the dip... easy! $AAPL  2020-01-28 21:33:53
# 17884  $AAPL dumb bears thought they could take this ...  2020-01-28 21:33:52
# 17885                                         $AAPL 💦💦💦💦  2020-01-28 21:33:51
# 17886                                 $AAPL To the moon!  2020-01-28 21:33:51
# 17887                  $AAPL time to short this bad boy.  2020-01-28 21:33:51
# 17888  $AAPL chat is moving so fast nobody will see t...  2020-01-28 21:33:49
# 17889                                  $AAPL keep going!  2020-01-28 21:33:48
# 17890                          $AAPL 335 on the road !!!  2020-01-28 21:33:47
# 17891  $AAPL didnt expect that $QQQ $SWKS $LSCC $QCOM...  2020-01-28 21:33:47
# 17892  $XLNX Good news is that $AAPL beat. Grab those...  2020-01-28 21:33:45
# 17893                     $SPY $AAPL pass $SPY price yet  2020-01-28 21:33:44
# 17894                            $AAPL congrats gamblers  2020-01-28 21:33:43
# 17895                                  $AAPL wohooooooo🚀  2020-01-28 21:33:43
# 17896  $BABA $AAPL coming in clutch on ER. Tomorrow w...  2020-01-28 21:33:42
# 17897                               $AAPL power house !!  2020-01-28 21:33:41
# 17898  $AAPL @Bullbearoptions wheres the drop to 300?...  2020-01-28 21:33:41
# 17899               $AAPL Bears are gonna be homeless 😂😂  2020-01-28 21:33:41
# 17900                     $SPY $AAPL fooling bears lmfao  2020-01-28 21:33:40
# 17901  $TSLA  \n\nwhere are these trollers\nBashing $...  2020-01-28 21:33:39
# 17902                                    $AAPL Bears lol  2020-01-28 21:33:38
# 17903                               $AAPL Tim Apple!!! 🍎  2020-01-28 21:33:38
# 17904  $AAPL guess report just came out. That just bo...  2020-01-28 21:33:38
# 17905                            $AAPL NEW ALL TIME HIGH  2020-01-28 21:33:38
# 17906  $AAPL how sad I fuckin got in at 313 and my ca...  2020-01-28 21:33:38
# 17907    $AAPL here is the pumper Dan Ives. He’s silly 😝  2020-01-28 21:33:36
# 17908                                     $SPY 😎🚀🚀 $AAPL  2020-01-28 21:33:35
# 17909                          $AAPL RU NOT ENTERTAINED?  2020-01-28 21:33:35
#
#            tag                                            symbols
# 0         none  [{'id': 686, 'symbol': 'AAPL', 'title': 'Apple...
# 1         none  [{'id': 686, 'symbol': 'AAPL', 'title': 'Apple...
# 2      Bullish  [{'id': 686, 'symbol': 'AAPL', 'title': 'Apple...
# 3         none  [{'id': 686, 'symbol': 'AAPL', 'title': 'Apple...
# 4         none  [{'id': 686, 'symbol': 'AAPL', 'title': 'Apple...
# 5      Bullish  [{'id': 686, 'symbol': 'AAPL', 'title': 'Apple...
# 6      Bullish  [{'id': 686, 'symbol': 'AAPL', 'title': 'Apple...
# 7      Bullish  [{'id': 686, 'symbol': 'AAPL', 'title': 'Apple...
# 8         none  [{'id': 686, 'symbol': 'AAPL', 'title': 'Apple...
# 9         none  [{'id': 686, 'symbol': 'AAPL', 'title': 'Apple...
# 10     Bullish  [{'id': 686, 'symbol': 'AAPL', 'title': 'Apple...
# 11     Bullish  [{'id': 679, 'symbol': 'SPX', 'title': 'S&P 50...
# 12     Bullish  [{'id': 686, 'symbol': 'AAPL', 'title': 'Apple...
# 13        none  [{'id': 686, 'symbol': 'AAPL', 'title': 'Apple...
# 14        none  [{'id': 686, 'symbol': 'AAPL', 'title': 'Apple...
# 15     Bullish  [{'id': 686, 'symbol': 'AAPL', 'title': 'Apple...
# 16     Bearish  [{'id': 686, 'symbol': 'AAPL', 'title': 'Apple...
# 17     Bullish  [{'id': 686, 'symbol': 'AAPL', 'title': 'Apple...
# 18     Bullish  [{'id': 686, 'symbol': 'AAPL', 'title': 'Apple...
# 19        none  [{'id': 686, 'symbol': 'AAPL', 'title': 'Apple...
# 20     Bearish  [{'id': 686, 'symbol': 'AAPL', 'title': 'Apple...
# 21        none  [{'id': 686, 'symbol': 'AAPL', 'title': 'Apple...
# 22     Bullish  [{'id': 686, 'symbol': 'AAPL', 'title': 'Apple...
# 23     Bullish  [{'id': 686, 'symbol': 'AAPL', 'title': 'Apple...
# 24        none  [{'id': 686, 'symbol': 'AAPL', 'title': 'Apple...
# 25     Bullish  [{'id': 686, 'symbol': 'AAPL', 'title': 'Apple...
# 26        none  [{'id': 686, 'symbol': 'AAPL', 'title': 'Apple...
# 27     Bullish  [{'id': 686, 'symbol': 'AAPL', 'title': 'Apple...
# 28     Bullish  [{'id': 686, 'symbol': 'AAPL', 'title': 'Apple...
# 29     Bullish  [{'id': 686, 'symbol': 'AAPL', 'title': 'Apple...
# ...        ...                                                ...
# 17880     none  [{'id': 686, 'symbol': 'AAPL', 'title': 'Apple...
# 17881     none  [{'id': 686, 'symbol': 'AAPL', 'title': 'Apple...
# 17882     none  [{'id': 686, 'symbol': 'AAPL', 'title': 'Apple...
# 17883     none  [{'id': 686, 'symbol': 'AAPL', 'title': 'Apple...
# 17884     none  [{'id': 686, 'symbol': 'AAPL', 'title': 'Apple...
# 17885  Bullish  [{'id': 686, 'symbol': 'AAPL', 'title': 'Apple...
# 17886  Bullish  [{'id': 686, 'symbol': 'AAPL', 'title': 'Apple...
# 17887  Bearish  [{'id': 686, 'symbol': 'AAPL', 'title': 'Apple...
# 17888     none  [{'id': 686, 'symbol': 'AAPL', 'title': 'Apple...
# 17889     none  [{'id': 686, 'symbol': 'AAPL', 'title': 'Apple...
# 17890  Bullish  [{'id': 686, 'symbol': 'AAPL', 'title': 'Apple...
# 17891  Bullish  [{'id': 686, 'symbol': 'AAPL', 'title': 'Apple...
# 17892  Bullish  [{'id': 686, 'symbol': 'AAPL', 'title': 'Apple...
# 17893     none  [{'id': 686, 'symbol': 'AAPL', 'title': 'Apple...
# 17894     none  [{'id': 686, 'symbol': 'AAPL', 'title': 'Apple...
# 17895  Bullish  [{'id': 686, 'symbol': 'AAPL', 'title': 'Apple...
# 17896  Bullish  [{'id': 686, 'symbol': 'AAPL', 'title': 'Apple...
# 17897     none  [{'id': 686, 'symbol': 'AAPL', 'title': 'Apple...
# 17898     none  [{'id': 686, 'symbol': 'AAPL', 'title': 'Apple...
# 17899  Bullish  [{'id': 686, 'symbol': 'AAPL', 'title': 'Apple...
# 17900     none  [{'id': 686, 'symbol': 'AAPL', 'title': 'Apple...
# 17901  Bullish  [{'id': 686, 'symbol': 'AAPL', 'title': 'Apple...
# 17902     none  [{'id': 686, 'symbol': 'AAPL', 'title': 'Apple...
# 17903     none  [{'id': 686, 'symbol': 'AAPL', 'title': 'Apple...
# 17904     none  [{'id': 686, 'symbol': 'AAPL', 'title': 'Apple...
# 17905     none  [{'id': 686, 'symbol': 'AAPL', 'title': 'Apple...
# 17906     none  [{'id': 686, 'symbol': 'AAPL', 'title': 'Apple...
# 17907     none  [{'id': 686, 'symbol': 'AAPL', 'title': 'Apple...
# 17908     none  [{'id': 686, 'symbol': 'AAPL', 'title': 'Apple...
# 17909  Bullish  [{'id': 686, 'symbol': 'AAPL', 'title': 'Apple...
#
# [17910 rows x 6 columns]

# %%
response
# Out:
# {'response': {'status': 200},
#  'symbol': {'id': 5715,
#   'symbol': 'HPQ',
#   'title': 'Hewlett-Packard Company',
#   'aliases': [],
#   'is_following': False,
#   'watchlist_count': 8176},
#  'cursor': {'more': True, 'since': 6499416, 'max': 6455327},
#  'messages': [{'id': 6499416,
#    'body': 'A quick look at $AAPL $HPQ $DELL.  Video posted at http://stks.co/23TY',
#    'created_at': '2012-01-24T06:59:49Z',
#    'user': {'id': 76669,
#     'username': 'smtrader',
#     'name': '@smtraderCA on Twitter',
#     'avatar_url': 'https://avatars.stocktwits.com/production/76669/thumb-1326107627.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/76669/thumb-1326107627.png',
#     'join_date': '2011-05-07',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 1010,
#     'following': 0,
#     'ideas': 8783,
#     'watchlist_stocks_count': 0,
#     'like_count': 79,
#     'plus_tier': '',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 1, 'title': 'Stocktwits', 'url': 'https://stocktwits.com'},
#    'symbols': [{'id': 686,
#      'symbol': 'AAPL',
#      'title': 'Apple Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 348000},
#     {'id': 1579,
#      'symbol': 'DELL',
#      'title': 'Dell Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 2961},
#     {'id': 5715,
#      'symbol': 'HPQ',
#      'title': 'Hewlett-Packard Company',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 8176}],
#    'links': [{'title': 'Last Chip Standing (opinions from a stock market trader): AAPL HPQ DELL (1/23/2012)',
#      'url': 'http://stks.co/23TY',
#      'shortened_url': 'http://stks.co/23TY',
#      'shortened_expanded_url': 'lastchipstanding.blogspot.c...',
#      'description': "A quick look at AAPL one more time before tomorrow's earnings report, and a look at two PC stock, HPQ &amp; DELL that appear to be setting up for a breakout. For the email subscribers, here is the links for you to view the video .",
#      'image': None,
#      'created_at': '2012-01-24T06:59:50Z',
#      'video_url': None,
#      'source': {'name': 'BlogSpot', 'website': 'http://blogspot.com'}}],
#    'mentioned_users': [],
#    'entities': {'sentiment': None},
#    'filters': {'day_counts': 0, 'official_api': False}},
#   {'id': 6498304,
#    'body': 'Another old school lookin&#39; ready to Run  $HPQ http://chart.ly/4n6kuj9',
#    'created_at': '2012-01-24T01:52:13Z',
#    'user': {'id': 16249,
#     'username': 'gtlackey',
#     'name': 'G. Thomas Lackey Jr. CMT CFP®',
#     'avatar_url': 'https://avatars.stocktwits.com/production/16249/thumb-1367840700.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/16249/thumb-1367840700.png',
#     'join_date': '2010-06-02',
#     'official': True,
#     'identity': 'Official',
#     'classification': ['suggested', 'official'],
#     'followers': 100549,
#     'following': 153,
#     'ideas': 32227,
#     'watchlist_stocks_count': 0,
#     'like_count': 6442,
#     'plus_tier': '',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 1, 'title': 'Stocktwits', 'url': 'https://stocktwits.com'},
#    'symbols': [{'id': 5715,
#      'symbol': 'HPQ',
#      'title': 'Hewlett-Packard Company',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 8176}],
#    'links': [{'title': "Another old school lookin' ready to Run",
#      'url': 'http://chart.ly/4n6kuj9',
#      'shortened_url': 'http://chart.ly/4n6kuj9',
#      'shortened_expanded_url': 'chart.ly/4n6kuj9',
#      'description': 'Real Investors. Real Ideas. Real Time.',
#      'image': None,
#      'created_at': '2012-01-24T01:52:14Z',
#      'video_url': None,
#      'source': {'name': 'Chart.ly', 'website': 'http://chart.ly'}}],
#    'mentioned_users': [],
#    'entities': {'chart': {'thumb': 'https://charts.stocktwits.com/production/small_6498304.png',
#      'large': 'https://charts.stocktwits.com/production/large_6498304.png',
#      'original': 'https://charts.stocktwits.com/production/original_6498304.png',
#      'url': 'https://charts.stocktwits.com/production/original_6498304.png'},
#     'sentiment': None},
#    'filters': {'day_counts': 0, 'official_api': False}},
#   {'id': 6498148,
#    'body': 'RS Movers: 20pts 5days $MRVL $XLNX $HPQ $GS $AA $EMR $GOOG $COP $JCI $AEP $STUDY http://chart.ly/tjrsrce $$',
#    'created_at': '2012-01-24T01:12:23Z',
#    'user': {'id': 16249,
#     'username': 'gtlackey',
#     'name': 'G. Thomas Lackey Jr. CMT CFP®',
#     'avatar_url': 'https://avatars.stocktwits.com/production/16249/thumb-1367840700.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/16249/thumb-1367840700.png',
#     'join_date': '2010-06-02',
#     'official': True,
#     'identity': 'Official',
#     'classification': ['suggested', 'official'],
#     'followers': 100549,
#     'following': 153,
#     'ideas': 32227,
#     'watchlist_stocks_count': 0,
#     'like_count': 6442,
#     'plus_tier': '',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 1, 'title': 'Stocktwits', 'url': 'https://stocktwits.com'},
#    'symbols': [{'id': 2044,
#      'symbol': 'GOOG',
#      'title': 'Alphabet Inc. Class C',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 128886},
#     {'id': 2728,
#      'symbol': 'MRVL',
#      'title': 'Marvell Technology Group Ltd.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 7153},
#     {'id': 4161,
#      'symbol': 'XLNX',
#      'title': 'Xilinx Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 7187},
#     {'id': 4202,
#      'symbol': 'AA',
#      'title': 'Alcoa Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 12442},
#     {'id': 4256,
#      'symbol': 'AEP',
#      'title': 'American Electric Power Co., Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 1294},
#     {'id': 4799,
#      'symbol': 'COP',
#      'title': 'ConocoPhillips',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 6515},
#     {'id': 5172,
#      'symbol': 'EMR',
#      'title': 'Emerson Electric Co.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 1749},
#     {'id': 5593,
#      'symbol': 'GS',
#      'title': 'Goldman Sachs Group, Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 21058},
#     {'id': 5715,
#      'symbol': 'HPQ',
#      'title': 'Hewlett-Packard Company',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 8176},
#     {'id': 5971,
#      'symbol': 'JCI',
#      'title': 'Johnson Controls Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 1488},
#     {'id': 8677,
#      'symbol': 'STUDY',
#      'title': 'Stocktwits Education',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 4883}],
#    'links': [{'title': 'RS Movers: 20pts 5days $MRVL $XLNX $HPQ $GS $AA $EMR $GOOG $COP $JCI $AEP $$',
#      'url': 'http://chart.ly/tjrsrce',
#      'shortened_url': 'http://chart.ly/tjrsrce',
#      'shortened_expanded_url': 'chart.ly/tjrsrce',
#      'description': 'Real Investors. Real Ideas. Real Time.',
#      'image': None,
#      'created_at': '2012-01-24T01:12:25Z',
#      'video_url': None,
#      'source': {'name': 'Chart.ly', 'website': 'http://chart.ly'}}],
#    'mentioned_users': [],
#    'entities': {'chart': {'thumb': 'https://charts.stocktwits.com/production/small_6498148.png',
#      'large': 'https://charts.stocktwits.com/production/large_6498148.png',
#      'original': 'https://charts.stocktwits.com/production/original_6498148.png',
#      'url': 'https://charts.stocktwits.com/production/original_6498148.png'},
#     'sentiment': None},
#    'filters': {'day_counts': 0, 'official_api': False}},
#   {'id': 6495312,
#    'body': '@TheArmoTrader u r probably right. i thought no chance $PALM could get bought and $HPQ proved me wrong on that one :)',
#    'created_at': '2012-01-23T20:48:07Z',
#    'user': {'id': 74,
#     'username': 'sspencer_smb',
#     'name': 'Steven Spencer',
#     'avatar_url': 'https://avatars.stocktwits.com/production/74/thumb-1348146944.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/74/thumb-1348146944.png',
#     'join_date': '2009-08-13',
#     'official': True,
#     'identity': 'Official',
#     'classification': ['suggested', 'official'],
#     'followers': 92489,
#     'following': 181,
#     'ideas': 21411,
#     'watchlist_stocks_count': 62,
#     'like_count': 1631,
#     'plus_tier': '',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 1, 'title': 'Stocktwits', 'url': 'https://stocktwits.com'},
#    'symbols': [{'id': 3055,
#      'symbol': 'PALM',
#      'title': 'Palm, Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 95},
#     {'id': 5715,
#      'symbol': 'HPQ',
#      'title': 'Hewlett-Packard Company',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 8176}],
#    'mentioned_users': ['@TheArmoTrader'],
#    'entities': {'sentiment': None},
#    'filters': {'day_counts': 0, 'official_api': False}},
#   {'id': 6495074,
#    'body': 'Seven Dow 30 stocks ($AA $BAC $CAT $HPQ $INTC $JPM $MSFT) are already up at least 10% so far this year. Because, you know, that&#39;s rational.',
#    'created_at': '2012-01-23T20:39:33Z',
#    'user': {'id': 23887,
#     'username': 'lamonicabuzz',
#     'name': 'Paul La Monica',
#     'avatar_url': 'https://avatars.stocktwits.com/production/23887/thumb-1284739798.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/23887/thumb-1284739798.png',
#     'join_date': '2010-09-17',
#     'official': True,
#     'identity': 'Official',
#     'classification': ['suggested', 'official'],
#     'followers': 225699,
#     'following': 23,
#     'ideas': 40539,
#     'watchlist_stocks_count': 0,
#     'like_count': 831,
#     'plus_tier': '',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 1, 'title': 'Stocktwits', 'url': 'https://stocktwits.com'},
#    'symbols': [{'id': 2310,
#      'symbol': 'INTC',
#      'title': 'Intel Corporation',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 63355},
#     {'id': 2735,
#      'symbol': 'MSFT',
#      'title': 'Microsoft Corporation',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 157667},
#     {'id': 4202,
#      'symbol': 'AA',
#      'title': 'Alcoa Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 12442},
#     {'id': 4438,
#      'symbol': 'BAC',
#      'title': 'Bank of America Corporation',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 80444},
#     {'id': 4656,
#      'symbol': 'CAT',
#      'title': 'Caterpillar Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 19470},
#     {'id': 5715,
#      'symbol': 'HPQ',
#      'title': 'Hewlett-Packard Company',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 8176},
#     {'id': 6020,
#      'symbol': 'JPM',
#      'title': 'JPMorgan Chase & Co.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 39354}],
#    'conversation': {'parent_message_id': 6495074,
#     'in_reply_to_message_id': None,
#     'parent': True,
#     'replies': 0},
#    'mentioned_users': [],
#    'entities': {'sentiment': None},
#    'filters': {'day_counts': 0, 'official_api': False}},
#   {'id': 6491888,
#    'body': '$HPQ is a little overbought after Friday&#39;s nice move on Volume. http://chart.ly/7ncdugd',
#    'created_at': '2012-01-23T17:57:25Z',
#    'user': {'id': 81084,
#     'username': 'Tynecastle',
#     'name': 'Alpha Trade Partners',
#     'avatar_url': 'https://avatars.stocktwits.com/production/81084/thumb-1306524836.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/81084/thumb-1306524836.png',
#     'join_date': '2011-05-27',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 291,
#     'following': 24,
#     'ideas': 863,
#     'watchlist_stocks_count': 9,
#     'like_count': 3,
#     'plus_tier': '',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 1, 'title': 'Stocktwits', 'url': 'https://stocktwits.com'},
#    'symbols': [{'id': 5715,
#      'symbol': 'HPQ',
#      'title': 'Hewlett-Packard Company',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 8176}],
#    'links': [{'title': "$HPQ is a little overbought after Friday's nice move on Volume.",
#      'url': 'http://chart.ly/7ncdugd',
#      'shortened_url': 'http://chart.ly/7ncdugd',
#      'shortened_expanded_url': 'chart.ly/7ncdugd',
#      'description': 'Real Investors. Real Ideas. Real Time.',
#      'image': None,
#      'created_at': '2012-01-23T17:57:30Z',
#      'video_url': None,
#      'source': {'name': 'Chart.ly', 'website': 'http://chart.ly'}}],
#    'mentioned_users': [],
#    'entities': {'chart': {'thumb': 'https://charts.stocktwits.com/production/small_6491888.png',
#      'large': 'https://charts.stocktwits.com/production/large_6491888.png',
#      'original': 'https://charts.stocktwits.com/production/original_6491888.png',
#      'url': 'https://charts.stocktwits.com/production/original_6491888.png'},
#     'sentiment': {'basic': 'Bullish'}},
#    'filters': {'day_counts': 0, 'official_api': False}},
#   {'id': 6490823,
#    'body': 'The Potential Losers if Ultrabooks Win http://stks.co/22tM via Forbes $INTC $AAPL $HPQ $DELL',
#    'created_at': '2012-01-23T17:02:21Z',
#    'user': {'id': 90935,
#     'username': 'STtech',
#     'name': 'STtech',
#     'avatar_url': 'https://avatars.stocktwits.com/production/90935/thumb-1309977716.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/90935/thumb-1309977716.png',
#     'join_date': '2011-07-06',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 254,
#     'following': 61,
#     'ideas': 3660,
#     'watchlist_stocks_count': 20,
#     'like_count': 413,
#     'plus_tier': '',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 1, 'title': 'Stocktwits', 'url': 'https://stocktwits.com'},
#    'symbols': [{'id': 686,
#      'symbol': 'AAPL',
#      'title': 'Apple Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 348000},
#     {'id': 1579,
#      'symbol': 'DELL',
#      'title': 'Dell Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 2961},
#     {'id': 2310,
#      'symbol': 'INTC',
#      'title': 'Intel Corporation',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 63355},
#     {'id': 5715,
#      'symbol': 'HPQ',
#      'title': 'Hewlett-Packard Company',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 8176}],
#    'links': [{'title': 'Potential Losers if Ultrabooks Win - Forbes',
#      'url': 'http://stks.co/22tM',
#      'shortened_url': 'http://stks.co/22tM',
#      'shortened_expanded_url': 'forbes.com/sites/patrickmoo...',
#      'description': "Ultrabooks were one of the most discussed form factors at this year's CES 2012. Â\xa0This was due not only to Intel's CES marketing push, but by all of Intel's ecosystem demonstrating their prowess by showing their latest and greatest designs. Â\xa0OEMs like Dell, HP, Acer, Asus, Toshiba and Lenovo showed [...]",
#      'image': None,
#      'created_at': '2012-01-23T17:02:26Z',
#      'video_url': None,
#      'source': {'name': 'Forbes', 'website': 'http://www.forbes.com/'}}],
#    'mentioned_users': [],
#    'entities': {'sentiment': None},
#    'filters': {'day_counts': 0, 'official_api': False}},
#   {'id': 6489874,
#    'body': '$SPX components trading beyond their 14-day ATR (based off open) http://stks.co/22q4 $NRG $SHLD $HRB $LLL $HPQ $PG $SBUX',
#    'created_at': '2012-01-23T16:14:45Z',
#    'user': {'id': 259,
#     'username': 'PsychTrader',
#     'name': 'Darren Miller',
#     'avatar_url': 'https://avatars.stocktwits.com/production/259/thumb-1397742026.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/259/thumb-1397742026.png',
#     'join_date': '2009-09-01',
#     'official': False,
#     'identity': 'User',
#     'classification': ['suggested'],
#     'followers': 46584,
#     'following': 277,
#     'ideas': 9200,
#     'watchlist_stocks_count': 4,
#     'like_count': 30,
#     'plus_tier': '',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 1, 'title': 'Stocktwits', 'url': 'https://stocktwits.com'},
#    'symbols': [{'id': 679,
#      'symbol': 'SPX',
#      'title': 'S&P 500 Index',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 47008},
#     {'id': 3465,
#      'symbol': 'SBUX',
#      'title': 'Starbucks Corporation',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 60519},
#     {'id': 3519,
#      'symbol': 'SHLD',
#      'title': 'Sears Holdings Corporation',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 6756},
#     {'id': 5715,
#      'symbol': 'HPQ',
#      'title': 'Hewlett-Packard Company',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 8176},
#     {'id': 5722,
#      'symbol': 'HRB',
#      'title': 'H&R Block, Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 2028},
#     {'id': 6182,
#      'symbol': 'LLL',
#      'title': 'L-3 Communications Holdings Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 1021},
#     {'id': 6558,
#      'symbol': 'NRG',
#      'title': 'NRG Energy, Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 2503},
#     {'id': 6741,
#      'symbol': 'PG',
#      'title': 'Procter & Gamble Co.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 12844}],
#    'links': [{'title': 'Stock Screener - Charts NRG,SHLD,HRB,LLL,HPQ,PG,SN,IP,SBUX,NBL,K',
#      'url': 'http://stks.co/22q4',
#      'shortened_url': 'http://stks.co/22q4',
#      'shortened_expanded_url': 'finviz.com/screener.ashx?v=...',
#      'description': 'Stock screener for investors and traders, financial visualizations.',
#      'image': None,
#      'created_at': '2012-01-23T16:14:49Z',
#      'video_url': None,
#      'source': {'name': 'Finviz', 'website': 'http://finviz.com/'}}],
#    'mentioned_users': [],
#    'entities': {'sentiment': None},
#    'filters': {'day_counts': 0, 'official_api': False}},
#   {'id': 6489153,
#    'body': 'Movers in portfolio up +2% (after 1 hr): $LVS $MGM $WYNN $NYT $JAZZ $PSUN $HPQ $UEC  $SB $ANW $HA $BZH $BAC $C $FAS $ACI $CNX $ECA $CNQ',
#    'created_at': '2012-01-23T15:46:03Z',
#    'user': {'id': 1560,
#     'username': 'traderclubtirol',
#     'name': 'Trader Club Tirol',
#     'avatar_url': 'https://avatars.stocktwits.com/production/1560/thumb-1317939520.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/1560/thumb-1317939520.png',
#     'join_date': '2009-09-02',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 1037,
#     'following': 100,
#     'ideas': 23874,
#     'watchlist_stocks_count': 2,
#     'like_count': 0,
#     'plus_tier': '',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 1, 'title': 'Stocktwits', 'url': 'https://stocktwits.com'},
#    'symbols': [{'id': 581,
#      'symbol': 'UEC',
#      'title': 'Uranium Energy Corp.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 4201},
#     {'id': 2082,
#      'symbol': 'HA',
#      'title': 'Hawaiian Holdings Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 2206},
#     {'id': 2383,
#      'symbol': 'JAZZ',
#      'title': 'Jazz Pharmaceuticals, Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 2793},
#     {'id': 3253,
#      'symbol': 'PSUN',
#      'title': 'Pacific Sunwear of California Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 831},
#     {'id': 4152,
#      'symbol': 'WYNN',
#      'title': 'Wynn Resorts Ltd.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 15125},
#     {'id': 4229,
#      'symbol': 'ACI',
#      'title': 'Arch Coal Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 2002},
#     {'id': 4345,
#      'symbol': 'ANW',
#      'title': 'Aegean Marine Petroleum Network Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 2826},
#     {'id': 4438,
#      'symbol': 'BAC',
#      'title': 'Bank of America Corporation',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 80444},
#     {'id': 4639,
#      'symbol': 'BZH',
#      'title': 'Beazer Homes USA Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 654},
#     {'id': 4641,
#      'symbol': 'C',
#      'title': 'Citigroup, Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 23524},
#     {'id': 4788,
#      'symbol': 'CNQ',
#      'title': 'Canadian Natural Resources Limited',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 1163},
#     {'id': 4791,
#      'symbol': 'CNX',
#      'title': 'CONSOL Energy Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 2019},
#     {'id': 5105,
#      'symbol': 'OVV',
#      'title': 'Ovintiv',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 3616},
#     {'id': 5290,
#      'symbol': 'FAS',
#      'title': 'Direxion Daily Financial Bull 3X Shares',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 4884},
#     {'id': 5715,
#      'symbol': 'HPQ',
#      'title': 'Hewlett-Packard Company',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 8176},
#     {'id': 6218,
#      'symbol': 'LVS',
#      'title': 'Las Vegas Sands Corp.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 6965},
#     {'id': 6292,
#      'symbol': 'MGM',
#      'title': 'MGM Resorts International',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 6051},
#     {'id': 6613,
#      'symbol': 'NYT',
#      'title': 'The New York Times Company',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 732},
#     {'id': 7136,
#      'symbol': 'SB',
#      'title': 'Safe Bulkers, Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 1978}],
#    'mentioned_users': [],
#    'entities': {'sentiment': None},
#    'filters': {'day_counts': 0, 'official_api': False}},
#   {'id': 6487317,
#    'body': '$HPQ ripping this morning',
#    'created_at': '2012-01-23T14:53:48Z',
#    'user': {'id': 6703,
#     'username': 'Exit_16W',
#     'name': 'Duce',
#     'avatar_url': 'https://avatars.stocktwits.com/production/6703/thumb-1512105437.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/6703/thumb-1512105437.png',
#     'join_date': '2009-11-17',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 416,
#     'following': 20,
#     'ideas': 14193,
#     'watchlist_stocks_count': 9,
#     'like_count': 8,
#     'plus_tier': '',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 1, 'title': 'Stocktwits', 'url': 'https://stocktwits.com'},
#    'symbols': [{'id': 5715,
#      'symbol': 'HPQ',
#      'title': 'Hewlett-Packard Company',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 8176}],
#    'mentioned_users': [],
#    'entities': {'sentiment': None},
#    'filters': {'day_counts': 0, 'official_api': False}},
#   {'id': 6487140,
#    'body': 'sold another $HPQ here. holding only 1 lot left',
#    'created_at': '2012-01-23T14:50:50Z',
#    'user': {'id': 49526,
#     'username': 'jmaula',
#     'name': 'Jonathan Maula',
#     'avatar_url': 'https://avatars.stocktwits.com/production/49526/thumb-1436476195.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/49526/thumb-1436476195.png',
#     'join_date': '2011-02-02',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 70,
#     'following': 51,
#     'ideas': 2784,
#     'watchlist_stocks_count': 0,
#     'like_count': 34,
#     'plus_tier': '',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 1, 'title': 'Stocktwits', 'url': 'https://stocktwits.com'},
#    'symbols': [{'id': 5715,
#      'symbol': 'HPQ',
#      'title': 'Hewlett-Packard Company',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 8176}],
#    'mentioned_users': [],
#    'entities': {'sentiment': None},
#    'filters': {'day_counts': 0, 'official_api': False}},
#   {'id': 6481418,
#    'body': 'Stocks in bottom 1/2 of yearly range coming out of short term range:  $HPQ $DDD $STI  $CHMT $ADM $WIT',
#    'created_at': '2012-01-22T22:45:39Z',
#    'user': {'id': 37944,
#     'username': 'TheEquitiesRoom',
#     'name': 'TheEquitiesRoom_Intraday',
#     'avatar_url': 'https://avatars.stocktwits.com/production/37944/thumb-1293723829.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/37944/thumb-1293723829.png',
#     'join_date': '2010-12-30',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 1046,
#     'following': 24,
#     'ideas': 3207,
#     'watchlist_stocks_count': 0,
#     'like_count': 23,
#     'plus_tier': '',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 1, 'title': 'Stocktwits', 'url': 'https://stocktwits.com'},
#    'symbols': [{'id': 123,
#      'symbol': 'DDD',
#      'title': '3D Systems Corporation',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 16194},
#     {'id': 4240,
#      'symbol': 'ADM',
#      'title': 'Archer Daniels Midland Company',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 1836},
#     {'id': 5715,
#      'symbol': 'HPQ',
#      'title': 'Hewlett-Packard Company',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 8176},
#     {'id': 7294,
#      'symbol': 'STI',
#      'title': 'SunTrust Banks, Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 907},
#     {'id': 7732,
#      'symbol': 'WIT',
#      'title': 'Wipro Ltd.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 723},
#     {'id': 9405,
#      'symbol': 'CHMT',
#      'title': 'Chemtura Corporation',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 84}],
#    'mentioned_users': [],
#    'entities': {'sentiment': None},
#    'filters': {'day_counts': 0, 'official_api': False}},
#   {'id': 6481006,
#    'body': '$HPQ Possible Cup and Handle Pattern Forming. 28.70 key area for bulls to break if so then 200DMA test. http://stks.co/223E',
#    'created_at': '2012-01-22T19:41:17Z',
#    'user': {'id': 46592,
#     'username': 'tradewithpete',
#     'name': 'Pete',
#     'avatar_url': 'https://avatars.stocktwits.com/production/46592/thumb-1295922881.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/46592/thumb-1295922881.png',
#     'join_date': '2011-01-23',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 25951,
#     'following': 6,
#     'ideas': 5690,
#     'watchlist_stocks_count': 0,
#     'like_count': 0,
#     'plus_tier': '',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 1, 'title': 'Stocktwits', 'url': 'https://stocktwits.com'},
#    'symbols': [{'id': 5715,
#      'symbol': 'HPQ',
#      'title': 'Hewlett-Packard Company',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 8176}],
#    'links': [{'title': 'Hewlett-Packard (HPQ) Possible Cup and Handle PatternTradeWithPete.com',
#      'url': 'http://stks.co/223E',
#      'shortened_url': 'http://stks.co/223E',
#      'shortened_expanded_url': 'tradewithpete.com/2012/01/2...',
#      'description': 'Hewlett-Packard (HPQ) is possibly forming a cup and handle pattern. Can the bulls break the key $28.70 area? If they do will they aim for the 200DMA? A breakout in HPQ will get some buzz by the technology traders. Traders should apply the Seven Steps to Better Stock Trading.',
#      'image': None,
#      'created_at': '2012-01-22T19:41:20Z',
#      'video_url': None,
#      'source': {'name': 'Tradewithpete',
#       'website': 'http://tradewithpete.com/'}}],
#    'mentioned_users': [],
#    'entities': {'sentiment': None},
#    'filters': {'day_counts': 0, 'official_api': False}},
#   {'id': 6480089,
#    'body': '$HPQ http://stks.co/21sd Trading in a consolidation range. On a Buy signal. B/O of the range will signal direction.',
#    'created_at': '2012-01-22T11:56:41Z',
#    'user': {'id': 10404,
#     'username': 'Fibline',
#     'name': 'Juan Doe',
#     'avatar_url': 'https://avatars.stocktwits.com/production/10404/thumb-1385670669.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/10404/thumb-1385670669.png',
#     'join_date': '2010-03-16',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 24306,
#     'following': 0,
#     'ideas': 53488,
#     'watchlist_stocks_count': 0,
#     'like_count': 22,
#     'plus_tier': '',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 1, 'title': 'Stocktwits', 'url': 'https://stocktwits.com'},
#    'symbols': [{'id': 5715,
#      'symbol': 'HPQ',
#      'title': 'Hewlett-Packard Company',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 8176}],
#    'links': [{'title': 'Trading in a consolidation range. On a Buy signal. B/O of the range will signal direction.',
#      'url': 'http://stks.co/21sd',
#      'shortened_url': 'http://stks.co/21sd',
#      'shortened_expanded_url': 'chart.ly/878xi7r',
#      'description': 'Real Investors. Real Ideas. Real Time.',
#      'image': None,
#      'created_at': '2012-01-22T11:56:43Z',
#      'video_url': None,
#      'source': {'name': 'Chart.ly', 'website': 'http://chart.ly'}}],
#    'mentioned_users': [],
#    'entities': {'chart': {'thumb': 'https://charts.stocktwits.com/production/small_6480089.png',
#      'large': 'https://charts.stocktwits.com/production/large_6480089.png',
#      'original': 'https://charts.stocktwits.com/production/original_6480089.png',
#      'url': 'https://charts.stocktwits.com/production/original_6480089.png'},
#     'sentiment': {'basic': 'Bullish'}},
#    'filters': {'day_counts': 0, 'official_api': False}},
#   {'id': 6477891,
#    'body': 'The 3 Dow stocks that exploded today http://stks.co/21Zk $MSFT $IBM $HPQ $$',
#    'created_at': '2012-01-21T00:46:33Z',
#    'user': {'id': 45296,
#     'username': 'MuhammadBiz',
#     'name': 'muhammad',
#     'avatar_url': 'https://avatars.stocktwits.com/production/45296/thumb-1384885077.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/45296/thumb-1384885077.png',
#     'join_date': '2011-01-19',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 18,
#     'following': 5,
#     'ideas': 89,
#     'watchlist_stocks_count': 0,
#     'like_count': 8,
#     'plus_tier': '',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 1, 'title': 'Stocktwits', 'url': 'https://stocktwits.com'},
#    'symbols': [{'id': 2735,
#      'symbol': 'MSFT',
#      'title': 'Microsoft Corporation',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 157667},
#     {'id': 5715,
#      'symbol': 'HPQ',
#      'title': 'Hewlett-Packard Company',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 8176},
#     {'id': 5786,
#      'symbol': 'IBM',
#      'title': 'International Business Machines Corp.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 35813}],
#    'links': [{'title': 'The 3 Dow Stocks That Exploded Today',
#      'url': 'http://stks.co/21Zk',
#      'shortened_url': 'http://stks.co/21Zk',
#      'shortened_expanded_url': 'fool.com/investing/general/...',
#      'description': 'By Brendan Byrnes | More Articles January 20, 2012 | Today was a mixed day overall for the markets, with two of the three major indices ending the day in the black. The Dow Jones Industrial Average (INDEX: ^DJI ) led the charge, closing up 0.76%.',
#      'image': None,
#      'created_at': '2012-01-21T00:46:36Z',
#      'video_url': None,
#      'source': {'name': 'Fool', 'website': 'http://www.fool.com/'}}],
#    'mentioned_users': [],
#    'entities': {'sentiment': None},
#    'filters': {'day_counts': 0, 'official_api': False}},
#   {'id': 6477527,
#    'body': 'RS Movers: 20pts 5days $XLNX $HSP $MRVL $GS $MSFT $HPQ $GOOG $JCI $C $STUDY $SPY http://chart.ly/6ji48ji',
#    'created_at': '2012-01-20T22:56:28Z',
#    'user': {'id': 16249,
#     'username': 'gtlackey',
#     'name': 'G. Thomas Lackey Jr. CMT CFP®',
#     'avatar_url': 'https://avatars.stocktwits.com/production/16249/thumb-1367840700.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/16249/thumb-1367840700.png',
#     'join_date': '2010-06-02',
#     'official': True,
#     'identity': 'Official',
#     'classification': ['suggested', 'official'],
#     'followers': 100549,
#     'following': 153,
#     'ideas': 32227,
#     'watchlist_stocks_count': 0,
#     'like_count': 6442,
#     'plus_tier': '',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 1, 'title': 'Stocktwits', 'url': 'https://stocktwits.com'},
#    'symbols': [{'id': 2044,
#      'symbol': 'GOOG',
#      'title': 'Alphabet Inc. Class C',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 128886},
#     {'id': 2728,
#      'symbol': 'MRVL',
#      'title': 'Marvell Technology Group Ltd.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 7153},
#     {'id': 2735,
#      'symbol': 'MSFT',
#      'title': 'Microsoft Corporation',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 157667},
#     {'id': 4161,
#      'symbol': 'XLNX',
#      'title': 'Xilinx Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 7187},
#     {'id': 4641,
#      'symbol': 'C',
#      'title': 'Citigroup, Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 23524},
#     {'id': 5593,
#      'symbol': 'GS',
#      'title': 'Goldman Sachs Group, Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 21058},
#     {'id': 5715,
#      'symbol': 'HPQ',
#      'title': 'Hewlett-Packard Company',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 8176},
#     {'id': 5733,
#      'symbol': 'HSP',
#      'title': 'Hospira Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 109},
#     {'id': 5971,
#      'symbol': 'JCI',
#      'title': 'Johnson Controls Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 1488},
#     {'id': 7271,
#      'symbol': 'SPY',
#      'title': 'SPDR S&P 500',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 160970},
#     {'id': 8677,
#      'symbol': 'STUDY',
#      'title': 'Stocktwits Education',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 4883}],
#    'links': [{'title': 'RS Movers: 20pts 5days $XLNX $HSP $MRVL $GS $MSFT $HPQ $GOOG $JCI $C $STUDY',
#      'url': 'http://chart.ly/6ji48ji',
#      'shortened_url': 'http://chart.ly/6ji48ji',
#      'shortened_expanded_url': 'chart.ly/6ji48ji',
#      'description': 'Real Investors. Real Ideas. Real Time.',
#      'image': None,
#      'created_at': '2012-01-20T22:56:31Z',
#      'video_url': None,
#      'source': {'name': 'Chart.ly', 'website': 'http://chart.ly'}}],
#    'mentioned_users': [],
#    'entities': {'chart': {'thumb': 'https://charts.stocktwits.com/production/small_6477527.png',
#      'large': 'https://charts.stocktwits.com/production/large_6477527.png',
#      'original': 'https://charts.stocktwits.com/production/original_6477527.png',
#      'url': 'https://charts.stocktwits.com/production/original_6477527.png'},
#     'sentiment': None},
#    'filters': {'day_counts': 0, 'official_api': False}},
#   {'id': 6477067,
#    'body': 'Party like it&#39;s 1989. The Dow&#39;s 4 biggest winners today? $MSFT $IBM $HPQ $INTC. Can&#39;t wait to get a hot new PC running on DOS &amp; a 486 chip!',
#    'created_at': '2012-01-20T21:42:32Z',
#    'user': {'id': 23887,
#     'username': 'lamonicabuzz',
#     'name': 'Paul La Monica',
#     'avatar_url': 'https://avatars.stocktwits.com/production/23887/thumb-1284739798.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/23887/thumb-1284739798.png',
#     'join_date': '2010-09-17',
#     'official': True,
#     'identity': 'Official',
#     'classification': ['suggested', 'official'],
#     'followers': 225699,
#     'following': 23,
#     'ideas': 40539,
#     'watchlist_stocks_count': 0,
#     'like_count': 831,
#     'plus_tier': '',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 1, 'title': 'Stocktwits', 'url': 'https://stocktwits.com'},
#    'symbols': [{'id': 2310,
#      'symbol': 'INTC',
#      'title': 'Intel Corporation',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 63355},
#     {'id': 2735,
#      'symbol': 'MSFT',
#      'title': 'Microsoft Corporation',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 157667},
#     {'id': 5715,
#      'symbol': 'HPQ',
#      'title': 'Hewlett-Packard Company',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 8176},
#     {'id': 5786,
#      'symbol': 'IBM',
#      'title': 'International Business Machines Corp.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 35813}],
#    'mentioned_users': [],
#    'entities': {'sentiment': None},
#    'filters': {'day_counts': 0, 'official_api': False}},
#   {'id': 6476905,
#    'body': 'Today&#39;s Dividend-Paying Winners and Losers: http://stks.co/21SI / $NCMI $WLT $MSFT $IBM $HPQ $GPS $SON $ANF $NVS $COF',
#    'created_at': '2012-01-20T21:24:46Z',
#    'user': {'id': 22542,
#     'username': 'DynamicDividend',
#     'name': 'The Dynamic Dividend',
#     'avatar_url': 'https://avatars.stocktwits.com/production/22542/thumb-1291735668.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/22542/thumb-1291735668.png',
#     'join_date': '2010-08-29',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 344,
#     'following': 32,
#     'ideas': 3493,
#     'watchlist_stocks_count': 5,
#     'like_count': 59,
#     'plus_tier': '',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 1, 'title': 'Stocktwits', 'url': 'https://stocktwits.com'},
#    'symbols': [{'id': 2735,
#      'symbol': 'MSFT',
#      'title': 'Microsoft Corporation',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 157667},
#     {'id': 2811,
#      'symbol': 'NCMI',
#      'title': 'National CineMedia, Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 591},
#     {'id': 4340,
#      'symbol': 'ANF',
#      'title': 'Abercrombie & Fitch Co.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 4550},
#     {'id': 4794,
#      'symbol': 'COF',
#      'title': 'Capital One Financial Corp.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 2854},
#     {'id': 5576,
#      'symbol': 'GPS',
#      'title': 'Gap Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 4164},
#     {'id': 5715,
#      'symbol': 'HPQ',
#      'title': 'Hewlett-Packard Company',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 8176},
#     {'id': 5786,
#      'symbol': 'IBM',
#      'title': 'International Business Machines Corp.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 35813},
#     {'id': 6594,
#      'symbol': 'NVS',
#      'title': 'Novartis AG',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 4436},
#     {'id': 7259,
#      'symbol': 'SON',
#      'title': 'Sonoco Products Co.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 165},
#     {'id': 7738,
#      'symbol': 'WLT',
#      'title': 'Walter Energy, Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 1381}],
#    'links': [{'title': 'Todayâ€™s Dividend-Paying Winners and Losers | The Dynamic Dividend',
#      'url': 'http://stks.co/21SI',
#      'shortened_url': 'http://stks.co/21SI',
#      'shortened_expanded_url': 'dynamicdividend.com/todays-...',
#      'description': "Here's a rundown of notable dividend-paying stocks that made big moves today.",
#      'image': None,
#      'created_at': '2012-01-20T21:24:50Z',
#      'video_url': None,
#      'source': {'name': 'Dynamicdividend',
#       'website': 'http://dynamicdividend.com/'}}],
#    'mentioned_users': [],
#    'entities': {'sentiment': None},
#    'filters': {'day_counts': 0, 'official_api': False}},
#   {'id': 6475706,
#    'body': '$HPQ still Little Blue/$IBM Lite. But up 3.7% today &amp; 9% YTD. Still, who is CEO in alternate universe where Meg Whitman is Calif. governor?',
#    'created_at': '2012-01-20T20:31:11Z',
#    'user': {'id': 23887,
#     'username': 'lamonicabuzz',
#     'name': 'Paul La Monica',
#     'avatar_url': 'https://avatars.stocktwits.com/production/23887/thumb-1284739798.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/23887/thumb-1284739798.png',
#     'join_date': '2010-09-17',
#     'official': True,
#     'identity': 'Official',
#     'classification': ['suggested', 'official'],
#     'followers': 225699,
#     'following': 23,
#     'ideas': 40539,
#     'watchlist_stocks_count': 0,
#     'like_count': 831,
#     'plus_tier': '',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 1, 'title': 'Stocktwits', 'url': 'https://stocktwits.com'},
#    'symbols': [{'id': 5715,
#      'symbol': 'HPQ',
#      'title': 'Hewlett-Packard Company',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 8176}],
#    'mentioned_users': [],
#    'entities': {'sentiment': None},
#    'filters': {'day_counts': 0, 'official_api': False}},
#   {'id': 6472395,
#    'body': '$HPQ http://stks.co/21EW HPQ is trading in ABC Bullish Pattern. HPQ&#39;s targets: $30-$32',
#    'created_at': '2012-01-20T17:56:42Z',
#    'user': {'id': 16911,
#     'username': 'suriNotes',
#     'name': 'Suri Duddella',
#     'avatar_url': 'https://avatars.stocktwits.com/production/16911/thumb-1475588436.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/16911/thumb-1475588436.png',
#     'join_date': '2010-06-11',
#     'official': True,
#     'identity': 'Official',
#     'classification': ['suggested', 'official'],
#     'followers': 64699,
#     'following': 2154,
#     'ideas': 21701,
#     'watchlist_stocks_count': 7,
#     'like_count': 29,
#     'plus_tier': '',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 1, 'title': 'Stocktwits', 'url': 'https://stocktwits.com'},
#    'symbols': [{'id': 5715,
#      'symbol': 'HPQ',
#      'title': 'Hewlett-Packard Company',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 8176}],
#    'links': [{'title': "HPQ is trading in ABC Bullish Pattern. HPQ's targets: $30-$32",
#      'url': 'http://stks.co/21EW',
#      'shortened_url': 'http://stks.co/21EW',
#      'shortened_expanded_url': 'chart.ly/6523yrx',
#      'description': 'Real Investors. Real Ideas. Real Time.',
#      'image': None,
#      'created_at': '2012-01-20T17:56:44Z',
#      'video_url': None,
#      'source': {'name': 'Chart.ly', 'website': 'http://chart.ly'}}],
#    'mentioned_users': [],
#    'entities': {'chart': {'thumb': 'https://charts.stocktwits.com/production/small_6472395.png',
#      'large': 'https://charts.stocktwits.com/production/large_6472395.png',
#      'original': 'https://charts.stocktwits.com/production/original_6472395.png',
#      'url': 'https://charts.stocktwits.com/production/original_6472395.png'},
#     'sentiment': None},
#    'filters': {'day_counts': 0, 'official_api': False}},
#   {'id': 6469391,
#    'body': 'Meg! Meg! Meg! Meg!  $HPQ',
#    'created_at': '2012-01-20T15:43:29Z',
#    'user': {'id': 259,
#     'username': 'PsychTrader',
#     'name': 'Darren Miller',
#     'avatar_url': 'https://avatars.stocktwits.com/production/259/thumb-1397742026.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/259/thumb-1397742026.png',
#     'join_date': '2009-09-01',
#     'official': False,
#     'identity': 'User',
#     'classification': ['suggested'],
#     'followers': 46584,
#     'following': 277,
#     'ideas': 9200,
#     'watchlist_stocks_count': 4,
#     'like_count': 30,
#     'plus_tier': '',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 1, 'title': 'Stocktwits', 'url': 'https://stocktwits.com'},
#    'symbols': [{'id': 5715,
#      'symbol': 'HPQ',
#      'title': 'Hewlett-Packard Company',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 8176}],
#    'mentioned_users': [],
#    'entities': {'sentiment': None},
#    'filters': {'day_counts': 0, 'official_api': False}},
#   {'id': 6469099,
#    'body': 'bought some $HPQ and $CRZO',
#    'created_at': '2012-01-20T15:32:46Z',
#    'user': {'id': 32931,
#     'username': 'nrp',
#     'name': 'Neal smith',
#     'avatar_url': 'https://avatars.stocktwits.com/production/32931/thumb-1581622938.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/32931/thumb-1581622938.png',
#     'join_date': '2010-12-11',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 113,
#     'following': 69,
#     'ideas': 4129,
#     'watchlist_stocks_count': 106,
#     'like_count': 46,
#     'plus_tier': '',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 1, 'title': 'Stocktwits', 'url': 'https://stocktwits.com'},
#    'symbols': [{'id': 1466,
#      'symbol': 'CRZO',
#      'title': 'Carrizo Oil & Gas Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 1449},
#     {'id': 5715,
#      'symbol': 'HPQ',
#      'title': 'Hewlett-Packard Company',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 8176}],
#    'mentioned_users': [],
#    'entities': {'sentiment': None},
#    'filters': {'day_counts': 0, 'official_api': False}},
#   {'id': 6468927,
#    'body': '$NTAP A more likely takeover target, $HPQ in the near future. Ripe for the taking, developers dropping left and right. Most important CHEAP!',
#    'created_at': '2012-01-20T15:28:18Z',
#    'user': {'id': 130454,
#     'username': 'TradeSokolov',
#     'name': 'Viktor Sokolov',
#     'avatar_url': 'https://avatars.stocktwits.com/production/130454/thumb-1326924303.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/130454/thumb-1326924303.png',
#     'join_date': '2012-01-18',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 3,
#     'following': 12,
#     'ideas': 82,
#     'watchlist_stocks_count': 0,
#     'like_count': 2,
#     'plus_tier': '',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 1, 'title': 'Stocktwits', 'url': 'https://stocktwits.com'},
#    'symbols': [{'id': 2904,
#      'symbol': 'NTAP',
#      'title': 'NetApp, Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 2925},
#     {'id': 5715,
#      'symbol': 'HPQ',
#      'title': 'Hewlett-Packard Company',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 8176}],
#    'mentioned_users': [],
#    'entities': {'sentiment': None},
#    'filters': {'day_counts': 0, 'official_api': False}},
#   {'id': 6468716,
#    'body': 'correction on that 2nd $HPQ tgt. more like 29.75-30 instead of that 30-30.25',
#    'created_at': '2012-01-20T15:22:43Z',
#    'user': {'id': 49526,
#     'username': 'jmaula',
#     'name': 'Jonathan Maula',
#     'avatar_url': 'https://avatars.stocktwits.com/production/49526/thumb-1436476195.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/49526/thumb-1436476195.png',
#     'join_date': '2011-02-02',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 70,
#     'following': 51,
#     'ideas': 2784,
#     'watchlist_stocks_count': 0,
#     'like_count': 34,
#     'plus_tier': '',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 1, 'title': 'Stocktwits', 'url': 'https://stocktwits.com'},
#    'symbols': [{'id': 5715,
#      'symbol': 'HPQ',
#      'title': 'Hewlett-Packard Company',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 8176}],
#    'mentioned_users': [],
#    'entities': {'sentiment': None},
#    'filters': {'day_counts': 0, 'official_api': False}},
#   {'id': 6468661,
#    'body': 'Geez, $HPQ went vertical out of daily consol.',
#    'created_at': '2012-01-20T15:21:22Z',
#    'user': {'id': 37944,
#     'username': 'TheEquitiesRoom',
#     'name': 'TheEquitiesRoom_Intraday',
#     'avatar_url': 'https://avatars.stocktwits.com/production/37944/thumb-1293723829.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/37944/thumb-1293723829.png',
#     'join_date': '2010-12-30',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 1046,
#     'following': 24,
#     'ideas': 3207,
#     'watchlist_stocks_count': 0,
#     'like_count': 23,
#     'plus_tier': '',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 1, 'title': 'Stocktwits', 'url': 'https://stocktwits.com'},
#    'symbols': [{'id': 5715,
#      'symbol': 'HPQ',
#      'title': 'Hewlett-Packard Company',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 8176}],
#    'conversation': {'parent_message_id': 6468661,
#     'in_reply_to_message_id': None,
#     'parent': True,
#     'replies': 2},
#    'mentioned_users': [],
#    'entities': {'sentiment': None},
#    'filters': {'day_counts': 0, 'official_api': False}},
#   {'id': 6468656,
#    'body': 'sold 1/3 of $HPQ into this upmove. next tgts are 28.50 and 30-30.25',
#    'created_at': '2012-01-20T15:21:12Z',
#    'user': {'id': 49526,
#     'username': 'jmaula',
#     'name': 'Jonathan Maula',
#     'avatar_url': 'https://avatars.stocktwits.com/production/49526/thumb-1436476195.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/49526/thumb-1436476195.png',
#     'join_date': '2011-02-02',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 70,
#     'following': 51,
#     'ideas': 2784,
#     'watchlist_stocks_count': 0,
#     'like_count': 34,
#     'plus_tier': '',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 1, 'title': 'Stocktwits', 'url': 'https://stocktwits.com'},
#    'symbols': [{'id': 5715,
#      'symbol': 'HPQ',
#      'title': 'Hewlett-Packard Company',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 8176}],
#    'mentioned_users': [],
#    'entities': {'sentiment': None},
#    'filters': {'day_counts': 0, 'official_api': False}},
#   {'id': 6465072,
#    'body': '$HPQ http://stks.co/20u2 HPQ daily...trying to break from tight consol.',
#    'created_at': '2012-01-20T14:10:21Z',
#    'user': {'id': 37944,
#     'username': 'TheEquitiesRoom',
#     'name': 'TheEquitiesRoom_Intraday',
#     'avatar_url': 'https://avatars.stocktwits.com/production/37944/thumb-1293723829.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/37944/thumb-1293723829.png',
#     'join_date': '2010-12-30',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 1046,
#     'following': 24,
#     'ideas': 3207,
#     'watchlist_stocks_count': 0,
#     'like_count': 23,
#     'plus_tier': '',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 1, 'title': 'Stocktwits', 'url': 'https://stocktwits.com'},
#    'symbols': [{'id': 5715,
#      'symbol': 'HPQ',
#      'title': 'Hewlett-Packard Company',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 8176}],
#    'links': [{'title': 'HPQ daily...trying to break from tight consol.',
#      'url': 'http://stks.co/20u2',
#      'shortened_url': 'http://stks.co/20u2',
#      'shortened_expanded_url': 'chart.ly/drusgmn',
#      'description': 'Real Investors. Real Ideas. Real Time.',
#      'image': None,
#      'created_at': '2012-01-20T14:10:31Z',
#      'video_url': None,
#      'source': {'name': 'Chart.ly', 'website': 'http://chart.ly'}}],
#    'mentioned_users': [],
#    'entities': {'chart': {'thumb': 'https://charts.stocktwits.com/production/small_6465072.png',
#      'large': 'https://charts.stocktwits.com/production/large_6465072.png',
#      'original': 'https://charts.stocktwits.com/production/original_6465072.png',
#      'url': 'https://charts.stocktwits.com/production/original_6465072.png'},
#     'sentiment': None},
#    'filters': {'day_counts': 0, 'official_api': False}},
#   {'id': 6465037,
#    'body': 'Tight range on the daily chart in $HPQ...wonder if &quot;old tech&quot; positive earnings last night $IBM $MSFT $INTC can lift this one?',
#    'created_at': '2012-01-20T14:08:02Z',
#    'user': {'id': 37944,
#     'username': 'TheEquitiesRoom',
#     'name': 'TheEquitiesRoom_Intraday',
#     'avatar_url': 'https://avatars.stocktwits.com/production/37944/thumb-1293723829.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/37944/thumb-1293723829.png',
#     'join_date': '2010-12-30',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 1046,
#     'following': 24,
#     'ideas': 3207,
#     'watchlist_stocks_count': 0,
#     'like_count': 23,
#     'plus_tier': '',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 1, 'title': 'Stocktwits', 'url': 'https://stocktwits.com'},
#    'symbols': [{'id': 2310,
#      'symbol': 'INTC',
#      'title': 'Intel Corporation',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 63355},
#     {'id': 2735,
#      'symbol': 'MSFT',
#      'title': 'Microsoft Corporation',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 157667},
#     {'id': 5715,
#      'symbol': 'HPQ',
#      'title': 'Hewlett-Packard Company',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 8176},
#     {'id': 5786,
#      'symbol': 'IBM',
#      'title': 'International Business Machines Corp.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 35813}],
#    'mentioned_users': [],
#    'entities': {'sentiment': None},
#    'filters': {'day_counts': 0, 'official_api': False}},
#   {'id': 6458532,
#    'body': 'flattening out $HPQ daytrade for a minimal gain +10c but will hold some for a swing to see if it can get any legs',
#    'created_at': '2012-01-19T20:54:34Z',
#    'user': {'id': 49526,
#     'username': 'jmaula',
#     'name': 'Jonathan Maula',
#     'avatar_url': 'https://avatars.stocktwits.com/production/49526/thumb-1436476195.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/49526/thumb-1436476195.png',
#     'join_date': '2011-02-02',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 70,
#     'following': 51,
#     'ideas': 2784,
#     'watchlist_stocks_count': 0,
#     'like_count': 34,
#     'plus_tier': '',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 1, 'title': 'Stocktwits', 'url': 'https://stocktwits.com'},
#    'symbols': [{'id': 5715,
#      'symbol': 'HPQ',
#      'title': 'Hewlett-Packard Company',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 8176}],
#    'mentioned_users': [],
#    'entities': {'sentiment': None},
#    'filters': {'day_counts': 0, 'official_api': False}},
#   {'id': 6455327,
#    'body': 'The best ultrabook we&#39;ve seen yet | Performance, price, and ergonomics http://stks.co/1zyY via CNet $HPQ $MSFT',
#    'created_at': '2012-01-19T18:54:29Z',
#    'user': {'id': 90935,
#     'username': 'STtech',
#     'name': 'STtech',
#     'avatar_url': 'https://avatars.stocktwits.com/production/90935/thumb-1309977716.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/90935/thumb-1309977716.png',
#     'join_date': '2011-07-06',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 254,
#     'following': 61,
#     'ideas': 3660,
#     'watchlist_stocks_count': 20,
#     'like_count': 413,
#     'plus_tier': '',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 1, 'title': 'Stocktwits', 'url': 'https://stocktwits.com'},
#    'symbols': [{'id': 2735,
#      'symbol': 'MSFT',
#      'title': 'Microsoft Corporation',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 157667},
#     {'id': 5715,
#      'symbol': 'HPQ',
#      'title': 'Hewlett-Packard Company',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 8176}],
#    'links': [{'title': 'HP Folio 13',
#      'url': 'http://stks.co/1zyY',
#      'shortened_url': 'http://stks.co/1zyY',
#      'shortened_expanded_url': 'reviews.cnet.com/laptops/hp...',
#      'description': 'The good: The HP Folio 13 has everything that matters most in an ultrabook: very good battery life, an excellent backlit keyboard, all the requisite ports for mobile use, and a very comfortable feel, along with a competitive entry-level price.',
#      'image': None,
#      'created_at': '2012-01-19T18:54:31Z',
#      'video_url': None,
#      'source': {'name': 'Cnet', 'website': 'http://reviews.cnet.com/'}}],
#    'mentioned_users': [],
#    'entities': {'sentiment': None},
#    'filters': {'day_counts': 0, 'official_api': False}}]}
