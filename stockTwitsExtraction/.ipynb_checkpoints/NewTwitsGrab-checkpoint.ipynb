# %%
#Import statements
import json
import requests
import pandas as pd
import numpy as np
import datetime
from pandas.io.json import json_normalize
from pathlib import Path
import os
import csv
import time

# %%
import demoji
from collections import Counter
import ast

# %%
# The stock Symbols that we will iterate through
# Apple = AAPL
# Amazon = AMZN
# Google = GOOGL
# Microsoft = MSFT
# Dell = DELL
# IBM = IBM
# Intel = INTC
# HP = HPQ
# Facebook = FB
# Cisco Systems = CSCO
# Oracle = ORCL
# HP Enterprise = HPE
# Micron Tech = MU
# DXC Tech = DXC
# Thermo Fisher Scientific = TMO
stockSymbol = ["AAPL", "AMZN", "GOOGL","MSFT", "DELL", "IBM", "INTC", "HPQ",
               "FB", "CSCO", "ORCL", "HPE", "MU", "DXC", "TMO"]

# %%
#This gets the parent directory of the current directory
current = os.getcwd()
path = Path(current)
twits_folder = str(path.parent)+'\\data\\StockTwits'
twits_folder
# Out:
# 'C:\\Users\\Russell\\OneDrive - Marist College\\School\\Spring 2020\\DATA 450 Data Capping\\Repository\\data\\StockTwits'

# %%
#Gathers the json file and all needed data values.
def collect_New_Twits(res):
    try:
        
        #
        df = (pd.json_normalize(res['messages'])[{'id','body','created_at','entities.sentiment.basic','symbols'}])
        
        #Reorders the columns
        df = df[['id','body','created_at','entities.sentiment.basic','symbols']]
        
        #Renames the columns
        df = df.rename(columns = {'created_at':'created', 'entities.sentiment.basic': 'tag'})
        
    except:
        df = (pd.json_normalize(res['messages'])[{'id','body','created_at','entities.sentiment','symbols'}])
               
        #Reorders the columns and gets rid of old symbols column
        df = df[['id','body','created_at','entities.sentiment', 'symbols']]
        
        #Renames the columns
        df = df.rename(columns = {'created_at':'created', 'entities.sentiment': 'tag'})
        

    #The following loops reformat the symbols column
    #It creates a list of dictionaries, {symbol: "symbol of company mentioned", title: "name of company"}
    dataList=[]
    
    for index in df['symbols']:
        symbolsList = []

        for diction in index:

            symbolsList.append({'symbol' : diction.get('symbol'), 'title' : diction.get('title')})
            
        dataList.append(symbolsList)
        
    df.insert(5, "newSymbols" ,dataList)
    
    df = df[['id','body','created','tag', 'newSymbols']]
    
    df = remove_emojis(df)

    #Replaces the NAN with a string "none"
    df = df.replace(np.nan, 'none', regex=True)
    
    #Replaces the string as a datetime variable
    dateFormat = "%Y-%m-%dT%H:%M:%SZ"
    df['created'] = pd.to_datetime(df['created'], format=dateFormat)
    
    df = df.sort_values(by = 'id', ascending = False)
    
    #returns the dataframe in correct format
    return df

# %%
##This function takes a Stocktwits dataframe and removes the emojis from the twit.
#This function then returns a dataframe with an extra column for the twit without emojis
def remove_emojis(dataframe):
    cleanSentList=[]
    
    for row in dataframe.body:
        cleanSentList.append(demoji.replace(row))
        
    dataframe.insert(5, 'cleanSents', cleanSentList)
    
    dataframe = dataframe[['id', 'cleanSents', 'created','tag', 'newSymbols']]
    
    return dataframe

# %%
while True:
    for symbol in stockSymbol:
    
        #selects the file to add to
        file = twits_folder+'\\{}_twits.csv'.format(symbol)
    
        historicalTwits = pd.read_csv(file)
        newestID = historicalTwits['id'].iloc[0]
    
        url = "https://api.stocktwits.com/api/2/streams/symbol/{}.json".format(symbol)
        try:
            response = requests.get(url, params = {'since' : newestID}).json()
       
        except:
            continue
        if response['response']['status'] == 429:
            print("requests exceeded")
            time.sleep(600)
            continue
        
        if pd.json_normalize(response['messages']).empty:
            time.sleep(15)
            time.sleep(15)
            continue
    
        tempTwitsDf = collect_New_Twits(response)

        newHistoricalTwits = tempTwitsDf.append(historicalTwits)
        
        newHistoricalTwits = newHistoricalTwits.drop_duplicates(subset = 'id')
    
        newHistoricalTwits.to_csv(file, index=False)
        time.sleep(15)
        #newHistoricalTwits.to_csv(r'{}_twitsCopy.csv'.format(symbol), index=False)
        time.sleep(15)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-21560ce831cb> in <module>
#       5         file = twits_folder+'\\{}_twits.csv'.format(symbol)
#       6
# ----> 7         historicalTwits = pd.read_csv(file)
#       8         newestID = historicalTwits['id'].iloc[0]
#       9
#
# c:\users\russell\appdata\local\programs\python\python37\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# c:\users\russell\appdata\local\programs\python\python37\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     452
#     453     try:
# --> 454         data = parser.read(nrows)
#     455     finally:
#     456         parser.close()
#
# c:\users\russell\appdata\local\programs\python\python37\lib\site-packages\pandas\io\parsers.py in read(self, nrows)
#    1131     def read(self, nrows=None):
#    1132         nrows = _validate_integer("nrows", nrows)
# -> 1133         ret = self._engine.read(nrows)
#    1134
#    1135         # May alter columns / col_dict
#
# c:\users\russell\appdata\local\programs\python\python37\lib\site-packages\pandas\io\parsers.py in read(self, nrows)
#    2035     def read(self, nrows=None):
#    2036         try:
# -> 2037             data = self._reader.read(nrows)
#    2038         except StopIteration:
#    2039             if self._first_chunk:
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_column_data()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# c:\users\russell\appdata\local\programs\python\python37\lib\site-packages\pandas\core\dtypes\common.py in is_categorical_dtype(arr_or_dtype)
#     570     if arr_or_dtype is None:
#     571         return False
# --> 572     return CategoricalDtype.is_dtype(arr_or_dtype)
#     573
#     574
#
# KeyboardInterrupt:

# %%
file = twits_folder+'\\{}_twits.csv'.format("MSFT")
MSFTdf = pd.read_csv(file)

# %%
DXCdf.newSymbols.to_json(twits_folder+'\\DXC_jsonTest.json')

# %%
DXCdf.to_json(twits_folder+'\\DXC_jsonTest.json')

# %%
response
# Out:
# {'response': {'status': 200},
#  'symbol': {'id': 1471,
#   'symbol': 'CSCO',
#   'title': 'Cisco Systems, Inc.',
#   'aliases': [],
#   'is_following': False,
#   'watchlist_count': 38862},
#  'cursor': {'more': False, 'since': None, 'max': None},
#  'messages': []}

# %%
column = []
for row in AAPLdf.newSymbols:
    lists = ast.literal_eval(row)
    for diction in lists:
        column.append(diction)

# %%
#This function counts the occurance of each company mentioned per dataframe passed in
# returns a dataframe with three columns, company symbol, company name, and occurances of mentions
#The function was tranformed to our needs but came from the link below
#https://stackoverflow.com/questions/30963408/count-occurrences-of-each-key-in-python-dictionary
def predominant_sign(data):
    signs = Counter(k['symbol'] for k in data if dict(k).get('symbol'))
    for sign, count in signs.most_common():
        print(sign, count)

# %%
predominant_sign(column)
# Out:
# AAPL 99297
# SPY 17550
# TSLA 6421
# AMZN 5658
# MSFT 5476
# QQQ 4222
# AMD 2961
# FB 2852
# BABA 1851
# NFLX 1714
# DIS 1417
# BA 1160
# GOOG 1127
# NVDA 1095
# GOOGL 1043
# ROKU 977
# SPCE 846
# DJIA 743
# BTC.X 635
# TVIX 613
# MU 535
# SPX 474
# BYND 400
# JPM 342
# DIA 328
# ES_F 325
# INTC 315
# SHOP 309
# QCOM 296
# IWM 283
# TWTR 247
# V 243
# GS 237
# UVXY 228
# SBUX 207
# RTN 202
# AVGO 198
# CRM 193
# VIX 179
# UBER 172
# SNAP 169
# XLF 165
# BAC 158
# WMT 156
# NIO 154
# LRCX 151
# GE 151
# T 150
# LK 147
# NKE 146
# CAT 144
# NQ_F 143
# AA 140
# PCG 137
# STUDY 136
# JD 132
# MA 123
# XLK 116
# CSCO 116
# LULU 113
# TGT 109
# MCD 104
# HD 103
# SQ 99
# SWKS 99
# VXX 96
# GLD 95
# BB 95
# FIT 89
# BIDU 88
# NBRV 87
# F 85
# ADBE 81
# IBM 77
# FCEL 76
# GILD 75
# QRVO 73
# TQQQ 72
# COST 71
# CMCSA 70
# WATT 67
# WYNN 66
# VZ 66
# SMH 63
# PYPL 61
# ACB 58
# SPXS 57
# EROS 57
# YM_F 56
# AMRN 56
# NASDAQ 55
# AMAT 55
# PSJ 1
# NTEC 1
# BXMT 1
# NFBK 1
# MAT 1
# MOH 1
# NVO 1
# GMAB 1
# LVMUY 1
# MG 1
# CRCM 1
# CNOB 1
# ZIXI 1
# ON 1
# ISEE 1
# DPW 1
# CNET 1
# MARA 1
# SKX 1
# EL 1
# CGIX 1
# ENDP 1
# NYA 1
# TD 1
# PETS 1
# CIDM 1
# OSK 1
# TMST 1
# BSX 1
# STX 1
# VG 1
# AAC 1
# SWK 1
# CP 1
# APOP 1
# CAPR 1
# NLS 1
# CETX 1
# MLNT 1
# REZI 1
# IGE 1
# ELY 1
# TRN 1
# TROV 1
# AEP 1
# PZZA 1
# MLSS 1
# PSEC 1
# UMBF 1
# EQR 1
# STI 1
# SCWX 1
# BSGM 1
# PDFS 1
# DERM 1
# GASL 1
# ASMB 1
# BAT.X 1
# VGSH 1
# TNA 1
# HRB 1
# PNC 1
# ISM 1
# CADE 1
# IM 1
# RETA 1
# WWR 1
# BK 1
# PE 1
# OIH 1
# AVB 1
# SAFM 1
# IRM 1
# COLB 1
# DJ_F 1
# CMA 1
# APC 1
# TSS 1
# ORLY 1
# GIB 1
# MTB 1
# BAA 1
# ALIM 1
# HA 1
# RRD 1
# GBT 1
# DT 1
# FOSL 1
# NI 1
# SGH 1
# RST 1
# SREV 1
# LITE 1
# NEO.X 1
# EGO 1
# AWR 1
# ES 1
# LGF.B 1
# XLV 1
# WPM 1
# EXPD 1
# FAST 1
# JE 1
# OKE 1
# RDHL 1
# OPRA 1
# FITB 1
# SFIX 1
# TOL 1
# CDW 1
# PEAK 1
# AABA 1
# INFO 1
# BAYRY 1
# APLE 1
# IWB 1
# FLIR 1
# FONR 1
# TX 1
# JASN 1
# UNM 1
# TFSL 1
# NNA 1
# LEDS 1
# BE 1
# WE 1
# APX 1
# AIG 1
# PTN 1

# %%
column
# Out:
# [{'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'BIDU', 'title': 'Baidu, Inc.'},
#  {'symbol': 'GDI', 'title': 'Gardner Denver Inc.'},
#  {'symbol': 'TWLO', 'title': 'Twilio'},
#  {'symbol': 'TWOU', 'title': '2U'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'ABMD', 'title': 'Abiomed Inc.'},
#  {'symbol': 'GPS', 'title': 'Gap Inc.'},
#  {'symbol': 'MOS', 'title': 'Mosaic Co.'},
#  {'symbol': 'XEC', 'title': 'Cimarex Energy Co.'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'CHNG', 'title': 'Change Healthcare Inc.'},
#  {'symbol': 'MCK', 'title': 'McKesson Corporation'},
#  {'symbol': 'NIO', 'title': 'NIO Inc.'},
#  {'symbol': 'S', 'title': 'Sprint Nextel Corp.'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'MCK', 'title': 'McKesson Corporation'},
#  {'symbol': 'S', 'title': 'Sprint Nextel Corp.'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'TLRY', 'title': 'Tilray, Inc.'},
#  {'symbol': 'DISH', 'title': 'Dish Network Corp.'},
#  {'symbol': 'BMY', 'title': 'Bristol-Myers Squibb Company'},
#  {'symbol': 'BWA', 'title': 'BorgWarner Inc.'},
#  {'symbol': 'DOW', 'title': 'The Dow Chemical Company'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'AER', 'title': 'AerCap Holdings N.V.'},
#  {'symbol': 'DDS', 'title': "Dillard's Inc."},
#  {'symbol': 'VOYA', 'title': 'Voya Financial Inc'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'ATUS', 'title': 'Altice USA Inc.'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'CLR', 'title': 'Continental Resources Inc.'},
#  {'symbol': 'MRO', 'title': 'Marathon Oil Corporation'},
#  {'symbol': 'GRUB', 'title': 'GrubHub'},
#  {'symbol': 'SHAK', 'title': 'Shake Shack'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXCM', 'title': 'DexCom, Inc.'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'ABMD', 'title': 'Abiomed Inc.'},
#  {'symbol': 'MOS', 'title': 'Mosaic Co.'},
#  {'symbol': 'XEC', 'title': 'Cimarex Energy Co.'},
#  {'symbol': 'KHC', 'title': 'The Kraft Heinz Company'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'AAPL', 'title': 'Apple Inc.'},
#  {'symbol': 'MSFT', 'title': 'Microsoft Corporation'},
#  {'symbol': 'TEVA', 'title': 'Teva Pharmaceutical Industries Limited'},
#  {'symbol': 'S', 'title': 'Sprint Nextel Corp.'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'AAPL', 'title': 'Apple Inc.'},
#  {'symbol': 'MSFT', 'title': 'Microsoft Corporation'},
#  {'symbol': 'TEVA', 'title': 'Teva Pharmaceutical Industries Limited'},
#  {'symbol': 'S', 'title': 'Sprint Nextel Corp.'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'AIG', 'title': 'American International Group, Inc.'},
#  {'symbol': 'PFE', 'title': 'Pfizer Inc.'},
#  {'symbol': 'RIG', 'title': 'Transocean Ltd.'},
#  {'symbol': 'KHC', 'title': 'The Kraft Heinz Company'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'MRK', 'title': 'Merck & Co. Inc.'},
#  {'symbol': 'W', 'title': 'Wayfair'},
#  {'symbol': 'KHC', 'title': 'The Kraft Heinz Company'},
#  {'symbol': 'INST', 'title': 'Instructure'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'ABMD', 'title': 'Abiomed Inc.'},
#  {'symbol': 'NOV', 'title': 'National Oilwell Varco, Inc.'},
#  {'symbol': 'XEC', 'title': 'Cimarex Energy Co.'},
#  {'symbol': 'NCLH', 'title': 'Norwegian Cruise Lines'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'ABMD', 'title': 'Abiomed Inc.'},
#  {'symbol': 'NOV', 'title': 'National Oilwell Varco, Inc.'},
#  {'symbol': 'XEC', 'title': 'Cimarex Energy Co.'},
#  {'symbol': 'NCLH', 'title': 'Norwegian Cruise Lines'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'ABMD', 'title': 'Abiomed Inc.'},
#  {'symbol': 'COG', 'title': 'Cabot Oil & Gas Corporation'},
#  {'symbol': 'XEC', 'title': 'Cimarex Energy Co.'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'CPRI', 'title': 'Capri Holdings Ltd'},
#  {'symbol': 'IPGP', 'title': 'IPG Photonics Corporation'},
#  {'symbol': 'TTWO', 'title': 'Take-Two Interactive Software Inc.'},
#  {'symbol': 'VRSN', 'title': 'VeriSign Inc.'},
#  {'symbol': 'FLT', 'title': 'FleetCor Technologies, Inc.'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'ZGNX', 'title': 'Zogenix, Inc.'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'ASRT', 'title': 'Assertio Therapeutics Inc'},
#  {'symbol': 'IBIO', 'title': 'iBio, Inc.'},
#  {'symbol': 'PINS', 'title': 'Pinterest'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'CODX', 'title': 'CO Diagnostics Inc'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'ASRT', 'title': 'Assertio Therapeutics Inc'},
#  {'symbol': 'SKX', 'title': 'Skechers USA Inc.'},
#  {'symbol': 'PINS', 'title': 'Pinterest'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'NLOK', 'title': 'NortonLifeLock Inc'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'ASRT', 'title': 'Assertio Therapeutics Inc'},
#  {'symbol': 'IBIO', 'title': 'iBio, Inc.'},
#  {'symbol': 'PINS', 'title': 'Pinterest'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'CODX', 'title': 'CO Diagnostics Inc'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'MYGN', 'title': 'Myriad Genetics Inc.'},
#  {'symbol': 'PINS', 'title': 'Pinterest'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'SPY', 'title': 'SPDR S&P 500'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'ABMD', 'title': 'Abiomed Inc.'},
#  {'symbol': 'ADS', 'title': 'Alliance Data Systems Corporation'},
#  {'symbol': 'COG', 'title': 'Cabot Oil & Gas Corporation'},
#  {'symbol': 'XEC', 'title': 'Cimarex Energy Co.'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'ABMD', 'title': 'Abiomed Inc.'},
#  {'symbol': 'COG', 'title': 'Cabot Oil & Gas Corporation'},
#  {'symbol': 'MAC', 'title': 'Macerich Co.'},
#  {'symbol': 'TRIP', 'title': 'Tripadvisor Inc'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'FORTY', 'title': 'Formula Systems (1985) Ltd.'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'MDT', 'title': 'Medtronic, Inc.'},
#  {'symbol': 'T', 'title': 'AT&T, Inc.'},
#  {'symbol': 'UTX', 'title': 'United Technologies Corp.'},
#  {'symbol': 'V', 'title': 'Visa, Inc.'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'ARWR', 'title': 'Arrowhead Research Corp.'},
#  {'symbol': 'SERV', 'title': 'ServiceMaster'},
#  {'symbol': 'RCL', 'title': 'Royal Caribbean Cruises Ltd.'},
#  {'symbol': 'LPLA', 'title': 'LPL Investment Holdings Inc.'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'ABMD', 'title': 'Abiomed Inc.'},
#  {'symbol': 'COG', 'title': 'Cabot Oil & Gas Corporation'},
#  {'symbol': 'MAC', 'title': 'Macerich Co.'},
#  {'symbol': 'TRIP', 'title': 'Tripadvisor Inc'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXCM', 'title': 'DexCom, Inc.'},
#  {'symbol': 'DXY', 'title': 'US Dollar Index'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'ACN', 'title': 'Accenture plc'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'CCL', 'title': 'Carnival Corporation'},
#  {'symbol': 'IFF', 'title': 'International Flavors & Fragrances Inc.'},
#  {'symbol': 'JBL', 'title': 'Jabil Circuit Inc.'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'CTSH', 'title': 'Cognizant Technology Solutions Corp.'},
#  {'symbol': 'ACN', 'title': 'Accenture plc'},
#  {'symbol': 'IBM', 'title': 'International Business Machines Corp.'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'AAPL', 'title': 'Apple Inc.'},
#  {'symbol': 'QCOM', 'title': 'QUALCOMM Incorporated'},
#  {'symbol': 'GOOGL', 'title': 'Alphabet Inc. Class A'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'ABMD', 'title': 'Abiomed Inc.'},
#  {'symbol': 'MAC', 'title': 'Macerich Co.'},
#  {'symbol': 'MOS', 'title': 'Mosaic Co.'},
#  {'symbol': 'TRIP', 'title': 'Tripadvisor Inc'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'IT', 'title': 'Gartner Inc.'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'INCY', 'title': 'Incyte Corporation'},
#  {'symbol': 'HFC', 'title': 'HollyFrontier Corporation'},
#  {'symbol': 'MPC', 'title': 'Marathon Petroleum Corporation'},
#  {'symbol': 'AAL', 'title': 'American Airlines Group'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'MYL', 'title': 'Mylan, Inc.'},
#  {'symbol': 'DD', 'title': 'EI DuPont de Nemours & Co.'},
#  {'symbol': 'MAC', 'title': 'Macerich Co.'},
#  {'symbol': 'MOS', 'title': 'Mosaic Co.'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'ABMD', 'title': 'Abiomed Inc.'},
#  {'symbol': 'M', 'title': "Macy's, Inc."},
#  {'symbol': 'MAC', 'title': 'Macerich Co.'},
#  {'symbol': 'TRIP', 'title': 'Tripadvisor Inc'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'TNDM', 'title': 'Tandem Diabetes Care Inc'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'CDW', 'title': 'CDW Corp.'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXCM', 'title': 'DexCom, Inc.'},
#  {'symbol': 'DXB', 'title': 'Deutsche Bank Contingent Capital Trust II'},
#  {'symbol': 'DXD', 'title': 'ProShares UltraShort Dow30'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'BIDU', 'title': 'Baidu, Inc.'},
#  {'symbol': 'CGNX', 'title': 'Cognex Corporation'},
#  {'symbol': 'ARW', 'title': 'Arrow Electronics, Inc.'},
#  {'symbol': 'AMBA', 'title': 'Ambarella, Inc.'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DMRC', 'title': 'Digimarc Corporation'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'BWA', 'title': 'BorgWarner Inc.'},
#  {'symbol': 'COUP', 'title': 'Coupa Software'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'FOLD', 'title': 'Amicus Therapeutics, Inc.'},
#  {'symbol': 'CLVS', 'title': 'Clovis Oncology, Inc. '},
#  {'symbol': 'MAXR.CA', 'title': 'Maxar Technologies Ltd'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'CACI', 'title': 'CACI International Inc.'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXCM', 'title': 'DexCom, Inc.'},
#  {'symbol': 'DXY', 'title': 'US Dollar Index'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'CTSH', 'title': 'Cognizant Technology Solutions Corp.'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'TTWO', 'title': 'Take-Two Interactive Software Inc.'},
#  {'symbol': 'CCI', 'title': 'Crown Castle International Corp.'},
#  {'symbol': 'NEM', 'title': 'Newmont Mining Corp.'},
#  {'symbol': 'SLG', 'title': 'SL Green Realty Corp.'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'CTSH', 'title': 'Cognizant Technology Solutions Corp.'},
#  {'symbol': 'ACN', 'title': 'Accenture plc'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'CF', 'title': 'CF Industries Holdings, Inc.'},
#  {'symbol': 'CTL', 'title': 'CenturyLink, Inc.'},
#  {'symbol': 'HPQ', 'title': 'Hewlett-Packard Company'},
#  {'symbol': 'NRG', 'title': 'NRG Energy, Inc.'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'CF', 'title': 'CF Industries Holdings, Inc.'},
#  {'symbol': 'CTL', 'title': 'CenturyLink, Inc.'},
#  {'symbol': 'HPQ', 'title': 'Hewlett-Packard Company'},
#  {'symbol': 'NRG', 'title': 'NRG Energy, Inc.'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'TSLA', 'title': 'Tesla, Inc.'},
#  {'symbol': 'PANW', 'title': 'PALO ALTO NETWORKS, INC'},
#  {'symbol': 'TWOU', 'title': '2U'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'ZS', 'title': 'Zscaler'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'XLNX', 'title': 'Xilinx Inc.'},
#  {'symbol': 'TWTR', 'title': 'Twitter'},
#  {'symbol': 'TRIP', 'title': 'Tripadvisor Inc'},
#  {'symbol': 'ANET', 'title': 'Arista Networks'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'AMAT', 'title': 'Applied Materials Inc.'},
#  {'symbol': 'MKTX', 'title': 'MarketAxess Holdings Inc.'},
#  {'symbol': 'ROK', 'title': 'Rockwell Automation Inc.'},
#  {'symbol': 'TSN', 'title': 'Tyson Foods Inc.'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'USO', 'title': 'United States Oil ETF'},
#  {'symbol': 'VXX', 'title': 'iPath S&P 500 VIX Short-Term Futures ETN'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'AMAT', 'title': 'Applied Materials Inc.'},
#  {'symbol': 'DHR', 'title': 'Danaher Corp.'},
#  {'symbol': 'GPS', 'title': 'Gap Inc.'},
#  {'symbol': 'M', 'title': "Macy's, Inc."},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'PWR', 'title': 'Quanta Services, Inc.'},
#  {'symbol': 'WFC', 'title': 'Wells Fargo & Company'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'BA', 'title': 'Boeing Co.'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'AM', 'title': 'Antero Resources Midstream'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'IHRT', 'title': 'iHeartMedia'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'ADSK', 'title': 'Autodesk, Inc.'},
#  {'symbol': 'FLEX', 'title': 'Flextronics International Ltd.'},
#  {'symbol': 'CARB', 'title': 'Carbonite, Inc'},
#  {'symbol': 'MIME', 'title': 'Mimecast'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'CHFC', 'title': 'Chemical Financial Corp.'},
#  {'symbol': 'TSN', 'title': 'Tyson Foods Inc.'},
#  {'symbol': 'FLT', 'title': 'FleetCor Technologies, Inc.'},
#  {'symbol': 'QTS', 'title': 'QTS Realty Trust'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'AMRN', 'title': 'Amarin Corporation plc'},
#  {'symbol': 'FCEL', 'title': 'FuelCell Energy Inc.'},
#  {'symbol': 'CBPX', 'title': 'Continental Building Products'},
#  {'symbol': 'APDN', 'title': 'Applied DNA Sciences Inc. '},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'ADSK', 'title': 'Autodesk, Inc.'},
#  {'symbol': 'ROK', 'title': 'Rockwell Automation Inc.'},
#  {'symbol': 'TSN', 'title': 'Tyson Foods Inc.'},
#  {'symbol': 'FTNT', 'title': 'Fortinet Inc.'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'AMRN', 'title': 'Amarin Corporation plc'},
#  {'symbol': 'HLIT', 'title': 'Harmonic Inc.'},
#  {'symbol': 'TSN', 'title': 'Tyson Foods Inc.'},
#  {'symbol': 'CRSP', 'title': 'CRISPR Therapeutics'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'AMRN', 'title': 'Amarin Corporation plc'},
#  {'symbol': 'FCEL', 'title': 'FuelCell Energy Inc.'},
#  {'symbol': 'CBPX', 'title': 'Continental Building Products'},
#  {'symbol': 'APDN', 'title': 'Applied DNA Sciences Inc. '},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'SPX', 'title': 'S&P 500 Index'},
#  {'symbol': 'ROK', 'title': 'Rockwell Automation Inc.'},
#  {'symbol': 'XLK', 'title': 'Technology Select Sector SPDR'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'AMRN', 'title': 'Amarin Corporation plc'},
#  {'symbol': 'BSX', 'title': 'Boston Scientific Corporation'},
#  {'symbol': 'JCP', 'title': 'J. C. Penney Company, Inc.'},
#  {'symbol': 'SE', 'title': 'Sea Ltd'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'MCK', 'title': 'McKesson Corporation'},
#  {'symbol': 'ROK', 'title': 'Rockwell Automation Inc.'},
#  {'symbol': 'TSN', 'title': 'Tyson Foods Inc.'},
#  {'symbol': 'FTNT', 'title': 'Fortinet Inc.'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'TSLA', 'title': 'Tesla, Inc.'},
#  {'symbol': 'ROKU', 'title': 'Roku'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'SNCR', 'title': 'Synchronoss Technologies, Inc.'},
#  {'symbol': 'SE', 'title': 'Sea Ltd'},
#  {'symbol': 'APDN', 'title': 'Applied DNA Sciences Inc. '},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'CVET', 'title': 'HS SPINCO INC/SH'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'AMRN', 'title': 'Amarin Corporation plc'},
#  {'symbol': 'SE', 'title': 'Sea Ltd'},
#  {'symbol': 'TRXC', 'title': 'TransEnterix Inc. '},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'CVET', 'title': 'HS SPINCO INC/SH'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'BNGO', 'title': 'BioNano Genomics, Inc'},
#  {'symbol': 'AMRN', 'title': 'Amarin Corporation plc'},
#  {'symbol': 'JCP', 'title': 'J. C. Penney Company, Inc.'},
#  {'symbol': 'SE', 'title': 'Sea Ltd'},
#  {'symbol': 'X', 'title': 'United States Steel Corp.'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'AMRN', 'title': 'Amarin Corporation plc'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'AMRN', 'title': 'Amarin Corporation plc'},
#  {'symbol': 'MRVL', 'title': 'Marvell Technology Group Ltd.'},
#  {'symbol': 'PLUG', 'title': 'Plug Power Inc.'},
#  {'symbol': 'APPS', 'title': 'Digital Turbine, Inc.'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'AMRN', 'title': 'Amarin Corporation plc'},
#  {'symbol': 'PLUG', 'title': 'Plug Power Inc.'},
#  {'symbol': 'BAC', 'title': 'Bank of America Corporation'},
#  {'symbol': 'SE', 'title': 'Sea Ltd'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'AMRN', 'title': 'Amarin Corporation plc'},
#  {'symbol': 'SE', 'title': 'Sea Ltd'},
#  {'symbol': 'CRSP', 'title': 'CRISPR Therapeutics'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DHI', 'title': 'DR Horton Inc.'},
#  {'symbol': 'DIS', 'title': 'Walt Disney Co.'},
#  {'symbol': 'ROK', 'title': 'Rockwell Automation Inc.'},
#  {'symbol': 'TSN', 'title': 'Tyson Foods Inc.'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'AMRN', 'title': 'Amarin Corporation plc'},
#  {'symbol': 'KEM', 'title': 'KEMET Corp.'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'AMRN', 'title': 'Amarin Corporation plc'},
#  {'symbol': 'PLUG', 'title': 'Plug Power Inc.'},
#  {'symbol': 'TSN', 'title': 'Tyson Foods Inc.'},
#  {'symbol': 'APPS', 'title': 'Digital Turbine, Inc.'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'AMRN', 'title': 'Amarin Corporation plc'},
#  {'symbol': 'SE', 'title': 'Sea Ltd'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'SLDB', 'title': 'Solid Biosciences'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'SE', 'title': 'Sea Ltd'},
#  {'symbol': 'DGAZ', 'title': 'VelocityShares 3x Inverse Natural Gas ETN'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'AEIS', 'title': 'Advanced Energy Industries, Inc.'},
#  {'symbol': 'ROK', 'title': 'Rockwell Automation Inc.'},
#  {'symbol': 'CRSP', 'title': 'CRISPR Therapeutics'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'AMRN', 'title': 'Amarin Corporation plc'},
#  {'symbol': 'FCEL', 'title': 'FuelCell Energy Inc.'},
#  {'symbol': 'CHK', 'title': 'Chesapeake Energy Corporation'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'TME', 'title': 'Tencent Music Entertainment Group'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'SE', 'title': 'Sea Ltd'},
#  {'symbol': 'SPY', 'title': 'SPDR S&P 500'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DIS', 'title': 'Walt Disney Co.'},
#  {'symbol': 'SPY', 'title': 'SPDR S&P 500'},
#  {'symbol': 'QQQ', 'title': 'PowerShares Nasdaq-100 QQQ'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'NOW', 'title': 'ServiceNow'},
#  {'symbol': 'GOOGL', 'title': 'Alphabet Inc. Class A'},
#  {'symbol': 'AYX', 'title': 'Alteryx'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'STM', 'title': 'STMicroelectronics NV'},
#  {'symbol': 'KEM', 'title': 'KEMET Corp.'},
#  {'symbol': 'UBER', 'title': 'Uber'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'MFGP', 'title': 'Micro Focus Intl ADR'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'STM', 'title': 'STMicroelectronics NV'},
#  {'symbol': 'KEM', 'title': 'KEMET Corp.'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'BREW', 'title': 'Craft Brewers Alliance, Inc.'},
#  {'symbol': 'CBS', 'title': 'CBS Corporation'},
#  {'symbol': 'TRXC', 'title': 'TransEnterix Inc. '},
#  {'symbol': 'KDMN', 'title': 'Kadmon Holdings'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'CBS', 'title': 'CBS Corporation'},
#  {'symbol': 'DHI', 'title': 'DR Horton Inc.'},
#  {'symbol': 'TRXC', 'title': 'TransEnterix Inc. '},
#  {'symbol': 'KDMN', 'title': 'Kadmon Holdings'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'TME', 'title': 'Tencent Music Entertainment Group'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  {'symbol': 'DXC', 'title': 'DXC Technology Rg'},
#  ...]

# %%
#Without Apple because I tested the code on Apple already
#stockSymbol = ["AMZN", "GOOGL","MSFT", "DELL", "IBM", "INTC", "HPQ",
#               "FB", "CSCO", "ORCL", "HPE", "MU", "DXC", "TMO"]

# %%
#Want to add a column with a clean twit
for symbol in stockSymbol:
    
        #selects the file to add to
    file = twits_folder+'\\{}_twits.csv'.format(symbol)
    
    historicalTwits = pd.read_csv(file)

    historicalTwits = historicalTwits.sort_values(by = 'id', ascending = False)
    
    historicalTwits = historicalTwits.drop_duplicates(subset = 'id')
    
    historicalTwits.to_csv(file, index=False)

# %%
    file = twits_folder+'\\{}_twits.csv'.format('DXC')
    
    historicalTwits = pd.read_csv(file)

# %%
twits_folder
amznDF = pd.read_csv('https://raw.githubusercontent.com/rsbmarist/MaristYoungMen2020/master/data/StockTwits/AMZN_twits.csv')

# %%
amznDF.to_csv(twits_folder+'\\AMZN_twits.csv', index=False)

# %%
response
# Out:
# {'response': {'status': 200},
#  'symbol': {'id': 1471,
#   'symbol': 'CSCO',
#   'title': 'Cisco Systems, Inc.',
#   'aliases': [],
#   'is_following': False,
#   'watchlist_count': 38563},
#  'cursor': {'more': True, 'since': 195259058, 'max': 195194515},
#  'messages': [{'id': 195194515,
#    'body': 'Your daily News digest for Cisco Systems $CSCO https://wsfriend.com/daily/news/CSCO/2020-02-16/',
#    'created_at': '2020-02-16T21:29:56Z',
#    'user': {'id': 732840,
#     'username': 'WallStreetFriend',
#     'name': 'Wall Street Friend',
#     'avatar_url': 'https://avatars.stocktwits.com/production/732840/thumb-1577167895.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/732840/thumb-1577167895.png',
#     'join_date': '2016-04-17',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 87,
#     'following': 39,
#     'ideas': 12614,
#     'watchlist_stocks_count': 31,
#     'like_count': 23,
#     'plus_tier': '',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 5142,
#     'title': 'Programmatic Alerts ',
#     'url': 'https://wsfriend.com'},
#    'symbols': [{'id': 1471,
#      'symbol': 'CSCO',
#      'title': 'Cisco Systems, Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 38533}],
#    'links': [{'title': 'CSCO Trending News and Daily News Digest for on Feb 16, 2020',
#      'url': 'https://wsfriend.com/daily/news/CSCO/2020-02-16/',
#      'shortened_url': 'https://wsfriend.com/daily/news/CSCO/2020-02-16/',
#      'shortened_expanded_url': 'wsfriend.com/daily/news/CSC...',
#      'description': 'CSCO Dail News Digest and Top trending news for',
#      'image': 'https://g.foolcdn.com/editorial/images/557756/it-technician-with-a-laptop-and-engineer-are-talking-in-data-center-while-walking-next-to-server-racks.jpg',
#      'created_at': '2020-02-16T21:29:57Z',
#      'video_url': None,
#      'source': {'name': 'Wsfriend', 'website': 'https://wsfriend.com'}}],
#    'likes': {'total': 1, 'user_ids': [1793737]},
#    'mentioned_users': [],
#    'entities': {'sentiment': None},
#    'filters': {'day_counts': 225, 'official_api': False}},
#   {'id': 195194979,
#    'body': '$CSCO bought 150 2/21 calls at the bottom, it’s going to be beautiful next week!',
#    'created_at': '2020-02-16T21:42:44Z',
#    'user': {'id': 1662934,
#     'username': 'Chr0meSn0w',
#     'name': 'Paul B',
#     'avatar_url': 'https://avatars.stocktwits.com/production/1662934/thumb-1539898835.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/1662934/thumb-1539898835.png',
#     'join_date': '2018-10-16',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 5,
#     'following': 1,
#     'ideas': 225,
#     'watchlist_stocks_count': 12,
#     'like_count': 140,
#     'plus_tier': '',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 1149,
#     'title': 'StockTwits for iOS',
#     'url': 'http://www.stocktwits.com/mobile'},
#    'symbols': [{'id': 1471,
#      'symbol': 'CSCO',
#      'title': 'Cisco Systems, Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 38533}],
#    'conversation': {'parent_message_id': 195194979,
#     'in_reply_to_message_id': None,
#     'parent': True,
#     'replies': 1},
#    'likes': {'total': 7,
#     'user_ids': [1484683, 1782869, 1142792, 1486374, 240864, 268229, 1243207]},
#    'mentioned_users': [],
#    'entities': {'sentiment': {'basic': 'Bullish'}},
#    'filters': {'day_counts': 2, 'official_api': True}},
#   {'id': 195197533,
#    'body': '$CSCO NEW ARTICLE : Cisco Systems: Is It Worth Holding The Stock? https://dashboard.stck.pro/news.php?ticker=CSCO&amp;rowid=3630301 Get all the latest $CSCO related news here : https://dashboard.stck.pro/news.php?ticker=CSCO',
#    'created_at': '2020-02-16T22:48:05Z',
#    'user': {'id': 1555408,
#     'username': 'STCKPRO',
#     'name': 'STCK.PRO',
#     'avatar_url': 'https://avatars.stocktwits.com/production/1555408/thumb-1576077822.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/1555408/thumb-1576077822.png',
#     'join_date': '2018-07-24',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 725,
#     'following': 8,
#     'ideas': 63647,
#     'watchlist_stocks_count': 15,
#     'like_count': 36,
#     'plus_tier': 'month',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 5011,
#     'title': 'STCK.PRO',
#     'url': 'https://dashboard.stck.pro'},
#    'symbols': [{'id': 1471,
#      'symbol': 'CSCO',
#      'title': 'Cisco Systems, Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 38533}],
#    'links': [{'title': 'CISCO SYSTEMS (CSCO) News - STCK.PRO',
#      'url': 'https://dashboard.stck.pro/news.php?ticker=CSCO&rowid=3630301',
#      'shortened_url': 'https://dashboard.stck.pro/news.php?ticker=CSCO&rowid=3630301',
#      'shortened_expanded_url': 'dashboard.stck.pro/news.php...',
#      'description': 'Create watchlists and get real-time prices and news updates for all your watchlist symbols. join the STCK.PRO community of +40.000 active users and discover the power of social financial news!',
#      'image': 'https://dashboard.stck.pro/img/stocktwits.png',
#      'created_at': '2020-02-16T22:48:10Z',
#      'video_url': None,
#      'source': {'name': 'Stck', 'website': 'https://dashboard.stck.pro'}}],
#    'mentioned_users': [],
#    'entities': {'sentiment': None},
#    'filters': {'day_counts': 118, 'official_api': False}},
#   {'id': 195197605,
#    'body': '$CSCO - Cisco Systems: Is It Worth Holding The Stock?. https://t.co/aovjv8E7rU #economy #business #finance',
#    'created_at': '2020-02-16T22:49:34Z',
#    'user': {'id': 3100678,
#     'username': 'Seeking_Alpha_',
#     'name': 'Seeking Alpha',
#     'avatar_url': 'https://avatars.stocktwits.com/production/3100678/thumb-1581856355.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/3100678/thumb-1581856355.png',
#     'join_date': '2020-02-16',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 26,
#     'following': 39,
#     'ideas': 561,
#     'watchlist_stocks_count': 13,
#     'like_count': 76,
#     'plus_tier': '',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 1022, 'title': 'Zapier', 'url': 'https://zapier.com/'},
#    'symbols': [{'id': 1471,
#      'symbol': 'CSCO',
#      'title': 'Cisco Systems, Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 38533}],
#    'links': [{'title': 'Cisco Systems: Is It Worth Holding The Stock?',
#      'url': 'https://t.co/aovjv8E7rU',
#      'shortened_url': 'https://t.co/aovjv8E7rU',
#      'shortened_expanded_url': 'seekingalpha.com/article/43...',
#      'description': "On 02/13/20, Cisco Sytems ( CSCO) disappointed investors, again, with its weak revenue guidance for Q3 2020 (-2.5% midpoint). I read that many investors are getting frustrated and worried about Cisco's growth prospects. In this article I will try to forecast if these headwinds are secular or only temporary, which is an important question to crack.",
#      'image': 'https://static2.seekingalpha.com/uploads/2020/2/13/48562496-15815960608739946.png',
#      'created_at': '2020-02-16T22:49:35Z',
#      'video_url': None,
#      'source': {'name': 'Seeking Alpha',
#       'website': 'https://seekingalpha.com'}}],
#    'mentioned_users': [],
#    'entities': {'sentiment': None},
#    'filters': {'day_counts': 47, 'official_api': False}},
#   {'id': 195197773,
#    'body': '$CSCO easy money in a healthy 5G-promising stock!',
#    'created_at': '2020-02-16T22:54:01Z',
#    'user': {'id': 2907403,
#     'username': 'Investingator',
#     'name': 'Arnold',
#     'avatar_url': 'https://avatars.stocktwits.com/production/2907403/thumb-1573343805.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/2907403/thumb-1573343805.png',
#     'join_date': '2019-11-09',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 26,
#     'following': 2,
#     'ideas': 826,
#     'watchlist_stocks_count': 34,
#     'like_count': 1083,
#     'plus_tier': '',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 2269,
#     'title': 'StockTwits Web',
#     'url': 'https://stocktwits.com'},
#    'symbols': [{'id': 1471,
#      'symbol': 'CSCO',
#      'title': 'Cisco Systems, Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 38552}],
#    'likes': {'total': 1, 'user_ids': [1782869]},
#    'mentioned_users': [],
#    'entities': {'chart': {'thumb': 'https://charts.stocktwits.com/production/small_195197773.jpg',
#      'large': 'https://charts.stocktwits.com/production/large_195197773.jpg',
#      'original': 'https://charts.stocktwits.com/production/original_195197773.jpg',
#      'url': 'https://charts.stocktwits.com/production/original_195197773.jpg'},
#     'sentiment': {'basic': 'Bullish'}},
#    'filters': {'day_counts': 9, 'official_api': True}},
#   {'id': 195199741,
#    'body': '$CSCO NEW ARTICLE : Datadog - Anything But A Dog So Far https://dashboard.stck.pro/news.php?ticker=CSCO&amp;rowid=3630713 Get all the latest $CSCO related news here : https://dashboard.stck.pro/news.php?ticker=CSCO',
#    'created_at': '2020-02-16T23:35:04Z',
#    'user': {'id': 1555408,
#     'username': 'STCKPRO',
#     'name': 'STCK.PRO',
#     'avatar_url': 'https://avatars.stocktwits.com/production/1555408/thumb-1576077822.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/1555408/thumb-1576077822.png',
#     'join_date': '2018-07-24',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 725,
#     'following': 8,
#     'ideas': 63647,
#     'watchlist_stocks_count': 15,
#     'like_count': 36,
#     'plus_tier': 'month',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 5011,
#     'title': 'STCK.PRO',
#     'url': 'https://dashboard.stck.pro'},
#    'symbols': [{'id': 1471,
#      'symbol': 'CSCO',
#      'title': 'Cisco Systems, Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 38533}],
#    'links': [{'title': 'CISCO SYSTEMS (CSCO) News - STCK.PRO',
#      'url': 'https://dashboard.stck.pro/news.php?ticker=CSCO&rowid=3630713',
#      'shortened_url': 'https://dashboard.stck.pro/news.php?ticker=CSCO&rowid=3630713',
#      'shortened_expanded_url': 'dashboard.stck.pro/news.php...',
#      'description': 'Create watchlists and get real-time prices and news updates for all your watchlist symbols. join the STCK.PRO community of +40.000 active users and discover the power of social financial news!',
#      'image': 'https://dashboard.stck.pro/img/stocktwits.png',
#      'created_at': '2020-02-16T23:35:09Z',
#      'video_url': None,
#      'source': {'name': 'Stck', 'website': 'https://dashboard.stck.pro'}}],
#    'mentioned_users': [],
#    'entities': {'sentiment': None},
#    'filters': {'day_counts': 120, 'official_api': False}},
#   {'id': 195202486,
#    'body': '$CSCO encouraging article on seeking alpha. It’s an hold and attractive buy in this over priced market. This is going up folks.',
#    'created_at': '2020-02-17T00:33:31Z',
#    'user': {'id': 268229,
#     'username': 'Lord_Kickass',
#     'name': 'Alpha Male',
#     'avatar_url': 'https://avatars.stocktwits.com/production/268229/thumb-1580881512.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/268229/thumb-1580881512.png',
#     'join_date': '2013-10-07',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 17,
#     'following': 4,
#     'ideas': 1043,
#     'watchlist_stocks_count': 20,
#     'like_count': 183,
#     'plus_tier': '',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 1149,
#     'title': 'StockTwits for iOS',
#     'url': 'http://www.stocktwits.com/mobile'},
#    'symbols': [{'id': 1471,
#      'symbol': 'CSCO',
#      'title': 'Cisco Systems, Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 38533}],
#    'conversation': {'parent_message_id': 195202486,
#     'in_reply_to_message_id': None,
#     'parent': True,
#     'replies': 5},
#    'likes': {'total': 2, 'user_ids': [1432054, 1243207]},
#    'mentioned_users': [],
#    'entities': {'sentiment': {'basic': 'Bullish'}},
#    'filters': {'day_counts': 3, 'official_api': True}},
#   {'id': 195202498,
#    'body': '$CSCO - Cisco Systems: Not Inspiring, But Cheap. https://t.co/gDNAG1WmEs #stockmarket #markets #trading',
#    'created_at': '2020-02-17T00:33:46Z',
#    'user': {'id': 3100678,
#     'username': 'Seeking_Alpha_',
#     'name': 'Seeking Alpha',
#     'avatar_url': 'https://avatars.stocktwits.com/production/3100678/thumb-1581856355.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/3100678/thumb-1581856355.png',
#     'join_date': '2020-02-16',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 26,
#     'following': 39,
#     'ideas': 561,
#     'watchlist_stocks_count': 13,
#     'like_count': 76,
#     'plus_tier': '',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 1022, 'title': 'Zapier', 'url': 'https://zapier.com/'},
#    'symbols': [{'id': 1471,
#      'symbol': 'CSCO',
#      'title': 'Cisco Systems, Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 38533}],
#    'links': [{'title': 'Cisco Systems: Not Inspiring, But Cheap',
#      'url': 'https://t.co/gDNAG1WmEs',
#      'shortened_url': 'https://t.co/gDNAG1WmEs',
#      'shortened_expanded_url': 'seekingalpha.com/article/43...',
#      'description': 'Cisco Systems (CSCO) is a large tech player which has long traded at modest multiples, and in fact still does. The current situation has perhaps somewhat been comparable to This semiconductor business long traded at low valuation multiples, as operational improvements in terms of revenue growth triggered the start of a huge run in the share price and thus re-rating through valuation multiple inflation.',
#      'image': 'https://static3.seekingalpha.com/assets/og_image_192-59bfd51c9fe6af025b2f9f96c807e46f8e2f06c5ae787b15bf1423e6c676d4db.png',
#      'created_at': '2020-02-17T00:33:48Z',
#      'video_url': None,
#      'source': {'name': 'Seeking Alpha',
#       'website': 'https://seekingalpha.com'}}],
#    'likes': {'total': 1, 'user_ids': [1432054]},
#    'mentioned_users': [],
#    'entities': {'sentiment': None},
#    'filters': {'day_counts': 56, 'official_api': False}},
#   {'id': 195202733,
#    'body': '$CSCO Investors are flocking to the largest US growth stocks as concerns rise over the global economy. $CSCO to benefit.',
#    'created_at': '2020-02-17T00:39:02Z',
#    'user': {'id': 268229,
#     'username': 'Lord_Kickass',
#     'name': 'Alpha Male',
#     'avatar_url': 'https://avatars.stocktwits.com/production/268229/thumb-1580881512.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/268229/thumb-1580881512.png',
#     'join_date': '2013-10-07',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 17,
#     'following': 4,
#     'ideas': 1043,
#     'watchlist_stocks_count': 20,
#     'like_count': 183,
#     'plus_tier': '',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 1149,
#     'title': 'StockTwits for iOS',
#     'url': 'http://www.stocktwits.com/mobile'},
#    'symbols': [{'id': 1471,
#      'symbol': 'CSCO',
#      'title': 'Cisco Systems, Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 38533}],
#    'mentioned_users': [],
#    'entities': {'sentiment': {'basic': 'Bullish'}},
#    'filters': {'day_counts': 4, 'official_api': True}},
#   {'id': 195202861,
#    'body': '$CSCO weekly, buying in the green zone has been profitable',
#    'created_at': '2020-02-17T00:41:54Z',
#    'user': {'id': 1557204,
#     'username': 'holdingbags',
#     'name': 'holdingbags',
#     'avatar_url': 'https://avatars.stocktwits.com/production/1557204/thumb-1563504595.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/1557204/thumb-1563504595.png',
#     'join_date': '2018-07-26',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 268,
#     'following': 63,
#     'ideas': 5916,
#     'watchlist_stocks_count': 69,
#     'like_count': 4902,
#     'plus_tier': '',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 2269,
#     'title': 'StockTwits Web',
#     'url': 'https://stocktwits.com'},
#    'symbols': [{'id': 1471,
#      'symbol': 'CSCO',
#      'title': 'Cisco Systems, Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 38538}],
#    'likes': {'total': 1, 'user_ids': [196441]},
#    'reshares': {'reshared_count': 1, 'user_ids': [1557204]},
#    'mentioned_users': [],
#    'entities': {'chart': {'thumb': 'https://charts.stocktwits.com/production/small_195202861.png',
#      'large': 'https://charts.stocktwits.com/production/large_195202861.png',
#      'original': 'https://charts.stocktwits.com/production/original_195202861.png',
#      'url': 'https://charts.stocktwits.com/production/original_195202861.png'},
#     'sentiment': None},
#    'filters': {'day_counts': 111, 'official_api': True}},
#   {'id': 195205791,
#    'body': 'JUST UPDATED ANALYSIS: \n$CSCO  \nCisco Systems \nValuation, Earnings Quality, and Dividend Safety Scores.  \nStock Analysis: \n http://dividendvaluebuilder.com/cisco-systems-csco-stock-analysis/  \n#dividends #technology #valueinvesting #dividend #investing #stocks #AAAMPortfolios',
#    'created_at': '2020-02-17T01:50:33Z',
#    'user': {'id': 309853,
#     'username': 'KenFaulkenberry',
#     'name': 'Ken Faulkenberry',
#     'avatar_url': 'https://avatars.stocktwits.com/production/309853/thumb-1495856543.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/309853/thumb-1495856543.png',
#     'join_date': '2014-02-06',
#     'official': True,
#     'identity': 'Official',
#     'classification': ['suggested', 'official'],
#     'followers': 35384,
#     'following': 54,
#     'ideas': 13430,
#     'watchlist_stocks_count': 54,
#     'like_count': 571,
#     'plus_tier': '',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 2269,
#     'title': 'StockTwits Web',
#     'url': 'https://stocktwits.com'},
#    'symbols': [{'id': 1471,
#      'symbol': 'CSCO',
#      'title': 'Cisco Systems, Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 38563}],
#    'links': [{'title': 'Cisco Systems (CSCO) Stock Analysis - Dividend Value Builder',
#      'url': 'http://dividendvaluebuilder.com/cisco-systems-csco-stock-analysis/',
#      'shortened_url': 'http://dividendvaluebuilder.com/cisco-systems-csco-stock-analysis/',
#      'shortened_expanded_url': 'dividendvaluebuilder.com/ci...',
#      'description': 'Cisco Systems has the management and financial strength to successfully transform itself from a company emphasizing individual products to a solutions and services company with a much higher percentage of recurring subscriptions and revenue than in the past. Cisco has a large established clientele that is producing a steady increase of revenue from high margin services.',
#      'image': 'http://dividendvaluebuilder.com/wp-content/uploads/2017/06/CSCO1.jpg',
#      'created_at': '2020-02-17T01:50:36Z',
#      'video_url': None,
#      'source': {'name': 'Dividend Value Builder',
#       'website': 'http://dividendvaluebuilder.com'}}],
#    'mentioned_users': [],
#    'entities': {'chart': {'thumb': 'https://charts.stocktwits.com/production/small_195205791.jpg',
#      'large': 'https://charts.stocktwits.com/production/large_195205791.jpg',
#      'original': 'https://charts.stocktwits.com/production/original_195205791.jpg',
#      'url': 'https://charts.stocktwits.com/production/original_195205791.jpg'},
#     'sentiment': None},
#    'filters': {'day_counts': 2, 'official_api': True}},
#   {'id': 195208860,
#    'body': '$CSCO - Cisco Systems: Not Inspiring, But Cheap - https://bit.ly/2uT3cH7',
#    'created_at': '2020-02-17T03:02:10Z',
#    'user': {'id': 181780,
#     'username': 'Ace8Trades2Day',
#     'name': 'Johnny Who',
#     'avatar_url': 'https://avatars.stocktwits.com/production/181780/thumb-1522821435.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/181780/thumb-1522821435.png',
#     'join_date': '2012-09-08',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 225,
#     'following': 40,
#     'ideas': 1084,
#     'watchlist_stocks_count': 87,
#     'like_count': 169,
#     'plus_tier': '',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 2269,
#     'title': 'StockTwits Web',
#     'url': 'https://stocktwits.com'},
#    'symbols': [{'id': 1471,
#      'symbol': 'CSCO',
#      'title': 'Cisco Systems, Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 38533}],
#    'links': [{'title': 'Cisco Systems: Not Inspiring, But Cheap',
#      'url': 'https://bit.ly/2uT3cH7',
#      'shortened_url': 'https://bit.ly/2uT3cH7',
#      'shortened_expanded_url': 'seekingalpha.com/article/43...',
#      'description': 'Cisco Systems (CSCO) is a large tech player which has long traded at modest multiples, and in fact still does. The current situation has perhaps somewhat been comparable to This semiconductor business long traded at low valuation multiples, as operational improvements in terms of revenue growth triggered the start of a huge run in the share price and thus re-rating through valuation multiple inflation.',
#      'image': 'https://static3.seekingalpha.com/assets/og_image_192-59bfd51c9fe6af025b2f9f96c807e46f8e2f06c5ae787b15bf1423e6c676d4db.png',
#      'created_at': '2020-02-17T03:02:11Z',
#      'video_url': None,
#      'source': {'name': 'Seeking Alpha',
#       'website': 'https://seekingalpha.com'}}],
#    'likes': {'total': 1, 'user_ids': [1950150]},
#    'mentioned_users': [],
#    'entities': {'sentiment': None},
#    'filters': {'day_counts': 11, 'official_api': True}},
#   {'id': 195216957,
#    'body': 'Oppenheimer Lowers Cisco Systems Q3 2020 Earnings Estimates to $0.73 EPS (Previously $0.74). https://www.marketbeat.com/x/790169 $CSCO',
#    'created_at': '2020-02-17T07:55:31Z',
#    'user': {'id': 284225,
#     'username': 'AnalystRatingsNetwork',
#     'name': 'MarketBeat.com',
#     'avatar_url': 'https://avatars.stocktwits.com/production/284225/thumb-1484325936.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/284225/thumb-1484325936.png',
#     'join_date': '2013-11-24',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 8118,
#     'following': 9,
#     'ideas': 804783,
#     'watchlist_stocks_count': 0,
#     'like_count': 9,
#     'plus_tier': '',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 1022, 'title': 'Zapier', 'url': 'https://zapier.com/'},
#    'symbols': [{'id': 1471,
#      'symbol': 'CSCO',
#      'title': 'Cisco Systems, Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 38533}],
#    'links': [{'title': "Equities Analysts Offer Predictions for Cisco Systems, Inc.'s Q3 2020 Earnings (NASDAQ:CSCO)",
#      'url': 'https://www.marketbeat.com/x/790169',
#      'shortened_url': 'https://www.marketbeat.com/x/790169',
#      'shortened_expanded_url': 'americanbankingnews.com/202...',
#      'description': 'Cisco Systems, Inc. (NASDAQ:CSCO) - Investment analysts at Oppenheimer dropped their Q3 2020 EPS estimates for shares of Cisco Systems in a report released on Wednesday, February 12th. Oppenheimer analyst I. Kidron now forecasts that the network equipment provider will post earnings of $0.73 per share for the quarter, down from their prior estimate of [...]',
#      'image': 'https://www.marketbeat.com/logos/cisco-systems-inc-logo.jpg',
#      'created_at': '2020-02-17T07:55:39Z',
#      'video_url': None,
#      'source': {'name': 'American Banking News',
#       'website': 'https://www.americanbankingnews.com'}}],
#    'mentioned_users': [],
#    'entities': {'sentiment': None},
#    'filters': {'day_counts': 252, 'official_api': False}},
#   {'id': 195217275,
#    'body': 'Piper Sandler Raises Cisco Systems Q2 2021 Earnings Estimates to $0.75 EPS (Previously $0.72). https://www.marketbeat.com/x/790174 $CSCO',
#    'created_at': '2020-02-17T08:20:32Z',
#    'user': {'id': 284225,
#     'username': 'AnalystRatingsNetwork',
#     'name': 'MarketBeat.com',
#     'avatar_url': 'https://avatars.stocktwits.com/production/284225/thumb-1484325936.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/284225/thumb-1484325936.png',
#     'join_date': '2013-11-24',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 8118,
#     'following': 9,
#     'ideas': 804783,
#     'watchlist_stocks_count': 0,
#     'like_count': 9,
#     'plus_tier': '',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 1022, 'title': 'Zapier', 'url': 'https://zapier.com/'},
#    'symbols': [{'id': 1471,
#      'symbol': 'CSCO',
#      'title': 'Cisco Systems, Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 38533}],
#    'links': [{'title': 'Piper Sandler Equities Analysts Lift Earnings Estimates for Cisco Systems, Inc. (NASDAQ:CSCO)',
#      'url': 'https://www.marketbeat.com/x/790174',
#      'shortened_url': 'https://www.marketbeat.com/x/790174',
#      'shortened_expanded_url': 'zolmax.com/investing/piper-...',
#      'description': 'Cisco Systems, Inc. (NASDAQ:CSCO) - Analysts at Piper Sandler raised their Q2 2021 EPS estimates for shares of Cisco Systems in a research report issued to clients and investors on Wednesday, February 12th. Piper Sandler analyst J. Fish now forecasts that the network equipment provider will post earnings of $0.75 per share for the quarter, [...]',
#      'image': 'https://www.marketbeat.com/logos/cisco-systems-inc-logo.jpg',
#      'created_at': '2020-02-17T08:20:43Z',
#      'video_url': None,
#      'source': {'name': 'Zolmax', 'website': 'https://zolmax.com'}}],
#    'mentioned_users': [],
#    'entities': {'sentiment': None},
#    'filters': {'day_counts': 308, 'official_api': False}},
#   {'id': 195217276,
#    'body': 'William Blair Sets Cisco Systems Q1 2021 Earnings Estimates at $0.79 EPS. https://www.marketbeat.com/x/790172 $CSCO',
#    'created_at': '2020-02-17T08:20:33Z',
#    'user': {'id': 284225,
#     'username': 'AnalystRatingsNetwork',
#     'name': 'MarketBeat.com',
#     'avatar_url': 'https://avatars.stocktwits.com/production/284225/thumb-1484325936.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/284225/thumb-1484325936.png',
#     'join_date': '2013-11-24',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 8118,
#     'following': 9,
#     'ideas': 804783,
#     'watchlist_stocks_count': 0,
#     'like_count': 9,
#     'plus_tier': '',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 1022, 'title': 'Zapier', 'url': 'https://zapier.com/'},
#    'symbols': [{'id': 1471,
#      'symbol': 'CSCO',
#      'title': 'Cisco Systems, Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 38533}],
#    'links': [{'title': "Analysts Issue Forecasts for Cisco Systems, Inc.'s Q1 2021 Earnings (NASDAQ:CSCO)",
#      'url': 'https://www.marketbeat.com/x/790172',
#      'shortened_url': 'https://www.marketbeat.com/x/790172',
#      'shortened_expanded_url': 'modernreaders.com/news/2020...',
#      'description': 'Cisco Systems, Inc. (NASDAQ:CSCO) - William Blair issued their Q1 2021 earnings per share (EPS) estimates for Cisco Systems in a report issued on Thursday, February 13th. William Blair analyst J. Ader expects that the network equipment provider will post earnings of $0.79 per share for the quarter.',
#      'image': 'https://www.marketbeat.com/logos/cisco-systems-inc-logo.jpg',
#      'created_at': '2020-02-17T08:20:40Z',
#      'video_url': None,
#      'source': {'name': 'Modern Readers',
#       'website': 'https://www.modernreaders.com'}}],
#    'mentioned_users': [],
#    'entities': {'sentiment': None},
#    'filters': {'day_counts': 309, 'official_api': False}},
#   {'id': 195217288,
#    'body': 'KeyCorp Lowers Cisco Systems Q4 2020 Earnings Estimates to $0.77 EPS (Previously $0.78). https://www.marketbeat.com/x/790170 $CSCO',
#    'created_at': '2020-02-17T08:20:43Z',
#    'user': {'id': 284225,
#     'username': 'AnalystRatingsNetwork',
#     'name': 'MarketBeat.com',
#     'avatar_url': 'https://avatars.stocktwits.com/production/284225/thumb-1484325936.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/284225/thumb-1484325936.png',
#     'join_date': '2013-11-24',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 8118,
#     'following': 9,
#     'ideas': 804783,
#     'watchlist_stocks_count': 0,
#     'like_count': 9,
#     'plus_tier': '',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 1022, 'title': 'Zapier', 'url': 'https://zapier.com/'},
#    'symbols': [{'id': 1471,
#      'symbol': 'CSCO',
#      'title': 'Cisco Systems, Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 38533}],
#    'links': [{'title': "Brokers Offer Predictions for Cisco Systems, Inc.'s Q4 2020 Earnings (NASDAQ:CSCO)",
#      'url': 'https://www.marketbeat.com/x/790170',
#      'shortened_url': 'https://www.marketbeat.com/x/790170',
#      'shortened_expanded_url': 'zolmax.com/investing/broker...',
#      'description': 'Cisco Systems, Inc. (NASDAQ:CSCO) - Equities researchers at KeyCorp lowered their Q4 2020 earnings per share (EPS) estimates for shares of Cisco Systems in a report issued on Thursday, February 13th. KeyCorp analyst A. Kurtz now expects that the network equipment provider will post earnings per share of $0.77 for the quarter, down from their [...]',
#      'image': 'https://www.marketbeat.com/logos/cisco-systems-inc-logo.jpg',
#      'created_at': '2020-02-17T08:21:00Z',
#      'video_url': None,
#      'source': {'name': 'Zolmax', 'website': 'https://zolmax.com'}}],
#    'mentioned_users': [],
#    'entities': {'sentiment': None},
#    'filters': {'day_counts': 319, 'official_api': False}},
#   {'id': 195218424,
#    'body': '$CSCO was analyzed by 20. The buy percentage consensus is at 86. So analysts seem to be very confident about $CSCO. https://www.chartmill.com/stock/quote/CSCO/analyst-ratings?utm_source=stocktwits&amp;utm_medium=ANALYST&amp;utm_content=CSCO&amp;utm_campaign=social_tracking',
#    'created_at': '2020-02-17T10:05:03Z',
#    'user': {'id': 47688,
#     'username': 'ChartMill',
#     'name': 'ChartMill',
#     'avatar_url': 'https://avatars.stocktwits.com/production/47688/thumb-1363343728.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/47688/thumb-1363343728.png',
#     'join_date': '2011-01-26',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 13943,
#     'following': 899,
#     'ideas': 799155,
#     'watchlist_stocks_count': 20,
#     'like_count': 32,
#     'plus_tier': '',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 1135,
#     'title': 'ChartMill',
#     'url': 'http://www.chartmill.com'},
#    'symbols': [{'id': 1471,
#      'symbol': 'CSCO',
#      'title': 'Cisco Systems, Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 38533}],
#    'links': [{'title': None,
#      'url': 'https://www.chartmill.com/stock/quote/CSCO/analyst-ratings?utm_source=stocktwits&utm_medium=ANALYST&utm_content=CSCO&utm_campaign=social_tracking',
#      'shortened_url': 'https://www.chartmill.com/stock/quote/CSCO/analyst-ratings?utm_source=stocktwits&utm_medium=ANALYST&utm_content=CSCO&utm_campaign=social_tracking',
#      'shortened_expanded_url': 'chartmill.com/stock/quote/C...',
#      'description': None,
#      'image': None,
#      'created_at': '2020-02-17T10:05:07Z',
#      'video_url': None,
#      'source': {'name': 'Chartmill', 'website': 'https://www.chartmill.com'}}],
#    'mentioned_users': [],
#    'entities': {'sentiment': None},
#    'filters': {'day_counts': 895, 'official_api': False}},
#   {'id': 195224570,
#    'body': 'January 2020 Dividend Income Summary $OXY $CSCO $CVX $ED https://talkmarkets.com/content/stocks--equities/january-2020-dividend-income-summary?post=251275',
#    'created_at': '2020-02-17T14:11:14Z',
#    'user': {'id': 296805,
#     'username': 'TalkMarkets',
#     'name': 'TalkMarkets',
#     'avatar_url': 'https://avatars.stocktwits.com/production/296805/thumb-1388900805.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/296805/thumb-1388900805.png',
#     'join_date': '2014-01-05',
#     'official': True,
#     'identity': 'Official',
#     'classification': ['official'],
#     'followers': 28356,
#     'following': 316,
#     'ideas': 237988,
#     'watchlist_stocks_count': 0,
#     'like_count': 353,
#     'plus_tier': '',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 1644,
#     'title': 'TalkMarkets',
#     'url': 'http://talkmarkets.com'},
#    'symbols': [{'id': 1471,
#      'symbol': 'CSCO',
#      'title': 'Cisco Systems, Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 38534},
#     {'id': 4874,
#      'symbol': 'CVX',
#      'title': 'Chevron Corp.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 12214},
#     {'id': 5108,
#      'symbol': 'ED',
#      'title': 'Consolidated Edison Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 1592},
#     {'id': 6666,
#      'symbol': 'OXY',
#      'title': 'Occidental Petroleum Corporation',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 5586}],
#    'links': [{'title': 'January 2020 Dividend Income Summary',
#      'url': 'https://talkmarkets.com/content/stocks--equities/january-2020-dividend-income-summary?post=251275',
#      'shortened_url': 'https://talkmarkets.com/content/stocks--equities/january-2020-dividend-income-summary?post=251275',
#      'shortened_expanded_url': 'talkmarkets.com/content/sto...',
#      'description': "Man, I can't believe that we are already one and a half months through 2020. Time continues to fly by at an amazing clip. Soon, my daughter will be one and I'll be reminiscing about all of her amazing milestones from her first year. I will say this, she loves to babble and crawl.",
#      'image': 'https://www.dividenddiplomats.com/wp-content/uploads/2019/04/Berts-dividend-income-300x189.jpg',
#      'created_at': '2020-02-17T14:11:17Z',
#      'video_url': None,
#      'source': {'name': 'TalkMarkets', 'website': 'https://talkmarkets.com'}}],
#    'mentioned_users': [],
#    'entities': {'sentiment': None},
#    'filters': {'day_counts': 101, 'official_api': False}},
#   {'id': 195228171,
#    'body': '$CSCO I hope 3 days rule applies tomorrow for a reversal',
#    'created_at': '2020-02-17T15:19:58Z',
#    'user': {'id': 908240,
#     'username': 'deblozay',
#     'name': 'Carlito Douyon',
#     'avatar_url': 'http://avatars.stocktwits.com/images/default_avatar_thumb.jpg',
#     'avatar_url_ssl': 'https://s3.amazonaws.com/st-avatars/images/default_avatar_thumb.jpg',
#     'join_date': '2016-12-22',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 5,
#     'following': 1,
#     'ideas': 1899,
#     'watchlist_stocks_count': 114,
#     'like_count': 235,
#     'plus_tier': '',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 2095,
#     'title': 'StockTwits For Android ',
#     'url': 'http://www.stocktwits.com/mobile'},
#    'symbols': [{'id': 1471,
#      'symbol': 'CSCO',
#      'title': 'Cisco Systems, Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 38538}],
#    'likes': {'total': 1, 'user_ids': [1142792]},
#    'mentioned_users': [],
#    'entities': {'sentiment': None},
#    'filters': {'day_counts': 2, 'official_api': True}},
#   {'id': 195229315,
#    'body': 'New volatility landscape for Cisco Systems($CSCO), Safety… http://dlvr.it/RQCLGB #canada #canadian_equities #CA',
#    'created_at': '2020-02-17T15:40:35Z',
#    'user': {'id': 56948,
#     'username': 'macroaxis',
#     'name': 'Macroaxis',
#     'avatar_url': 'https://avatars.stocktwits.com/production/56948/thumb-1361399398.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/56948/thumb-1361399398.png',
#     'join_date': '2011-03-04',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 1340,
#     'following': 4,
#     'ideas': 199259,
#     'watchlist_stocks_count': 14,
#     'like_count': 28,
#     'plus_tier': '',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 1351, 'title': 'dlvr.it', 'url': 'https://dlvrit.com/'},
#    'symbols': [{'id': 1471,
#      'symbol': 'CSCO',
#      'title': 'Cisco Systems, Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 38538}],
#    'links': [{'title': 'Stock Volatility',
#      'url': 'http://dlvr.it/RQCLGB',
#      'shortened_url': 'http://dlvr.it/RQCLGB',
#      'shortened_expanded_url': 'macroaxis.com/invest/market...',
#      'description': 'To execute equity pricing pattern simulations, real time valuations, recommendations, instant reporting, and portfolio analytics such as mean-variance optimization takes huge amount of computing resources. Since we are a small company we cannot afford to have hundreds of servers in our cluster.',
#      'image': 'https://www.macroaxis.com/images/aboutMacroaxisGuy.png',
#      'created_at': '2020-02-17T15:40:36Z',
#      'video_url': None,
#      'source': {'name': 'Macroaxis', 'website': 'https://www.macroaxis.com'}}],
#    'mentioned_users': [],
#    'entities': {'sentiment': None},
#    'filters': {'day_counts': 717, 'official_api': False}},
#   {'id': 195234318,
#    'body': '$CSCO NEW ARTICLE : Why Cisco Shouldn&#39;t Buy FireEye https://dashboard.stck.pro/news.php?ticker=CSCO&amp;rowid=3638675 Get all the latest $CSCO related news here : https://dashboard.stck.pro/news.php?ticker=CSCO',
#    'created_at': '2020-02-17T17:09:11Z',
#    'user': {'id': 1555408,
#     'username': 'STCKPRO',
#     'name': 'STCK.PRO',
#     'avatar_url': 'https://avatars.stocktwits.com/production/1555408/thumb-1576077822.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/1555408/thumb-1576077822.png',
#     'join_date': '2018-07-24',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 730,
#     'following': 8,
#     'ideas': 64069,
#     'watchlist_stocks_count': 15,
#     'like_count': 36,
#     'plus_tier': 'month',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 5011,
#     'title': 'STCK.PRO',
#     'url': 'https://dashboard.stck.pro'},
#    'symbols': [{'id': 1471,
#      'symbol': 'CSCO',
#      'title': 'Cisco Systems, Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 38538}],
#    'links': [{'title': 'CISCO SYSTEMS (CSCO) News - STCK.PRO',
#      'url': 'https://dashboard.stck.pro/news.php?ticker=CSCO&rowid=3638675',
#      'shortened_url': 'https://dashboard.stck.pro/news.php?ticker=CSCO&rowid=3638675',
#      'shortened_expanded_url': 'dashboard.stck.pro/news.php...',
#      'description': 'Create watchlists and get real-time prices and news updates for all your watchlist symbols. join the STCK.PRO community of +40.000 active users and discover the power of social financial news!',
#      'image': 'https://dashboard.stck.pro/img/stocktwits.png',
#      'created_at': '2020-02-17T17:09:49Z',
#      'video_url': None,
#      'source': {'name': 'Stck', 'website': 'https://dashboard.stck.pro'}}],
#    'mentioned_users': [],
#    'entities': {'chart': {'thumb': 'https://charts.stocktwits.com/production/small_195234318.jpg',
#      'large': 'https://charts.stocktwits.com/production/large_195234318.jpg',
#      'original': 'https://charts.stocktwits.com/production/original_195234318.jpg',
#      'url': 'https://charts.stocktwits.com/production/original_195234318.jpg'},
#     'sentiment': None},
#    'filters': {'day_counts': 252, 'official_api': False}},
#   {'id': 195235098,
#    'body': '$CSCO - Cisco: Fast Growing Earnings, Cheap Stock, Attractive Investment. https://t.co/phIP2hpevq #business #stocks #investing',
#    'created_at': '2020-02-17T17:23:38Z',
#    'user': {'id': 3100678,
#     'username': 'Seeking_Alpha_',
#     'name': 'Seeking Alpha',
#     'avatar_url': 'https://avatars.stocktwits.com/production/3100678/thumb-1581856355.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/3100678/thumb-1581856355.png',
#     'join_date': '2020-02-16',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 29,
#     'following': 44,
#     'ideas': 728,
#     'watchlist_stocks_count': 13,
#     'like_count': 84,
#     'plus_tier': '',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 1022, 'title': 'Zapier', 'url': 'https://zapier.com/'},
#    'symbols': [{'id': 1471,
#      'symbol': 'CSCO',
#      'title': 'Cisco Systems, Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 38554}],
#    'links': [{'title': 'Cisco: Fast Growing Earnings, Cheap Stock, Attractive Investment',
#      'url': 'https://t.co/phIP2hpevq',
#      'shortened_url': 'https://t.co/phIP2hpevq',
#      'shortened_expanded_url': 'seekingalpha.com/article/43...',
#      'description': 'Cisco (NASDAQ: CSCO) has hit a rough patch of late failing to return to top-line growth. Its management continues to act prudently in the face of customer uncertainty. Even while accounting for its lackluster, near-term growth opportunities, this is an attractive investment that is being cheaply priced and worthwhile considering.',
#      'image': 'https://static1.seekingalpha.com/uploads/2020/2/17/saupload_cisco-logo-16x9_thumb1.jpg',
#      'created_at': '2020-02-17T17:23:40Z',
#      'video_url': None,
#      'source': {'name': 'Seeking Alpha',
#       'website': 'https://seekingalpha.com'}}],
#    'mentioned_users': [],
#    'entities': {'sentiment': None},
#    'filters': {'day_counts': 150, 'official_api': False}},
#   {'id': 195236602,
#    'body': '$CSCO NEW ARTICLE : Cisco: Fast Growing Earnings, Cheap Stock, Attractive Investment https://dashboard.stck.pro/news.php?ticker=CSCO&amp;rowid=3638764 Get all the latest $CSCO related news here : https://dashboard.stck.pro/news.php?ticker=CSCO',
#    'created_at': '2020-02-17T17:50:06Z',
#    'user': {'id': 1555408,
#     'username': 'STCKPRO',
#     'name': 'STCK.PRO',
#     'avatar_url': 'https://avatars.stocktwits.com/production/1555408/thumb-1576077822.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/1555408/thumb-1576077822.png',
#     'join_date': '2018-07-24',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 731,
#     'following': 8,
#     'ideas': 64181,
#     'watchlist_stocks_count': 15,
#     'like_count': 36,
#     'plus_tier': 'month',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 5011,
#     'title': 'STCK.PRO',
#     'url': 'https://dashboard.stck.pro'},
#    'symbols': [{'id': 1471,
#      'symbol': 'CSCO',
#      'title': 'Cisco Systems, Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 38554}],
#    'links': [{'title': 'CISCO SYSTEMS (CSCO) News - STCK.PRO',
#      'url': 'https://dashboard.stck.pro/news.php?ticker=CSCO&rowid=3638764',
#      'shortened_url': 'https://dashboard.stck.pro/news.php?ticker=CSCO&rowid=3638764',
#      'shortened_expanded_url': 'dashboard.stck.pro/news.php...',
#      'description': 'Create watchlists and get real-time prices and news updates for all your watchlist symbols. join the STCK.PRO community of +40.000 active users and discover the power of social financial news!',
#      'image': 'https://dashboard.stck.pro/img/stocktwits.png',
#      'created_at': '2020-02-17T17:50:08Z',
#      'video_url': None,
#      'source': {'name': 'Stck', 'website': 'https://dashboard.stck.pro'}}],
#    'mentioned_users': [],
#    'entities': {'sentiment': None},
#    'filters': {'day_counts': 252, 'official_api': False}},
#   {'id': 195248939,
#    'body': 'Your daily News digest for Cisco Systems $CSCO https://wsfriend.com/daily/news/CSCO/2020-02-17/',
#    'created_at': '2020-02-17T21:30:05Z',
#    'user': {'id': 732840,
#     'username': 'WallStreetFriend',
#     'name': 'Wall Street Friend',
#     'avatar_url': 'https://avatars.stocktwits.com/production/732840/thumb-1577167895.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/732840/thumb-1577167895.png',
#     'join_date': '2016-04-17',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 89,
#     'following': 39,
#     'ideas': 12859,
#     'watchlist_stocks_count': 31,
#     'like_count': 23,
#     'plus_tier': '',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 5142,
#     'title': 'Programmatic Alerts ',
#     'url': 'https://wsfriend.com'},
#    'symbols': [{'id': 1471,
#      'symbol': 'CSCO',
#      'title': 'Cisco Systems, Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 38563}],
#    'links': [{'title': 'CSCO Trending News and Daily News Digest for on Feb 17, 2020',
#      'url': 'https://wsfriend.com/daily/news/CSCO/2020-02-17/',
#      'shortened_url': 'https://wsfriend.com/daily/news/CSCO/2020-02-17/',
#      'shortened_expanded_url': 'wsfriend.com/daily/news/CSC...',
#      'description': 'CSCO Dail News Digest and Top trending news for',
#      'image': 'https://g.foolcdn.com/editorial/images/558005/man-rejecting-to-discuss-with-business-partner.jpg',
#      'created_at': '2020-02-17T21:30:07Z',
#      'video_url': None,
#      'source': {'name': 'Wsfriend', 'website': 'https://wsfriend.com'}}],
#    'mentioned_users': [],
#    'entities': {'sentiment': None},
#    'filters': {'day_counts': 245, 'official_api': False}},
#   {'id': 195251608,
#    'body': '$CSCO - Cisco: In The Dividend Growth Penalty Box. https://t.co/QkxuuIEbkF #stockmarket #finance #economy',
#    'created_at': '2020-02-17T22:04:02Z',
#    'user': {'id': 3100678,
#     'username': 'Seeking_Alpha_',
#     'name': 'Seeking Alpha',
#     'avatar_url': 'https://avatars.stocktwits.com/production/3100678/thumb-1581856355.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/3100678/thumb-1581856355.png',
#     'join_date': '2020-02-16',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 37,
#     'following': 44,
#     'ideas': 919,
#     'watchlist_stocks_count': 13,
#     'like_count': 84,
#     'plus_tier': '',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 1022, 'title': 'Zapier', 'url': 'https://zapier.com/'},
#    'symbols': [{'id': 1471,
#      'symbol': 'CSCO',
#      'title': 'Cisco Systems, Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 38563}],
#    'links': [{'title': 'Cisco: In The Dividend Growth Penalty Box',
#      'url': 'https://t.co/QkxuuIEbkF',
#      'shortened_url': 'https://t.co/QkxuuIEbkF',
#      'shortened_expanded_url': 'seekingalpha.com/article/43...',
#      'description': "Honestly, Cisco's ( CSCO) earnings report was probably the most disappointing that I've seen all year. And it's not because the company completely bombed its top or bottom-line results. It's not because the company's shares totally tanked in the aftermath. Simply put, I was taken aback by Cisco's $0.01 dividend increase.",
#      'image': 'https://static3.seekingalpha.com/images/marketing_images/fair_use_logos_products/sacl_csco_cisco_logo_2.png',
#      'created_at': '2020-02-17T22:04:03Z',
#      'video_url': None,
#      'source': {'name': 'Seeking Alpha',
#       'website': 'https://seekingalpha.com'}}],
#    'mentioned_users': [],
#    'entities': {'sentiment': None},
#    'filters': {'day_counts': 172, 'official_api': False}},
#   {'id': 195255339,
#    'body': 'Top Most Active S&amp;P 500 Stocks today: $AMD $F $GE $FCX $CSCO https://www.finscreener.com/screener/most-active/stocks/sp500',
#    'created_at': '2020-02-17T22:59:40Z',
#    'user': {'id': 1550174,
#     'username': 'Finscreener',
#     'name': 'Finscreener',
#     'avatar_url': 'https://avatars.stocktwits.com/production/1550174/thumb-1531918007.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/1550174/thumb-1531918007.png',
#     'join_date': '2018-07-18',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 203,
#     'following': 28,
#     'ideas': 2201,
#     'watchlist_stocks_count': 0,
#     'like_count': 9,
#     'plus_tier': '',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 2269,
#     'title': 'StockTwits Web',
#     'url': 'https://stocktwits.com'},
#    'symbols': [{'id': 1471,
#      'symbol': 'CSCO',
#      'title': 'Cisco Systems, Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 38554},
#     {'id': 4331,
#      'symbol': 'AMD',
#      'title': 'Advanced Micro Devices, Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 203753},
#     {'id': 5281,
#      'symbol': 'F',
#      'title': 'Ford Motor Co.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 68313},
#     {'id': 5310,
#      'symbol': 'FCX',
#      'title': 'Freeport-McMoRan Copper & Gold Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 17151},
#     {'id': 5481,
#      'symbol': 'GE',
#      'title': 'General Electric Co.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 86501}],
#    'links': [{'title': 'Most Active S&P 500 | Finscreener',
#      'url': 'https://www.finscreener.com/screener/most-active/stocks/sp500',
#      'shortened_url': 'https://www.finscreener.com/screener/most-active/stocks/sp500',
#      'shortened_expanded_url': 'finscreener.com/screener/mo...',
#      'description': 'Most Active securities brings U.S. markets and europe market biggest volumes in actual trading day together with quotes information and performance.',
#      'image': None,
#      'created_at': '2020-02-17T22:59:42Z',
#      'video_url': None,
#      'source': {'name': 'Finscreener',
#       'website': 'https://www.finscreener.com'}}],
#    'mentioned_users': [],
#    'entities': {'chart': {'thumb': 'https://charts.stocktwits.com/production/small_195255339.png',
#      'large': 'https://charts.stocktwits.com/production/large_195255339.png',
#      'original': 'https://charts.stocktwits.com/production/original_195255339.png',
#      'url': 'https://charts.stocktwits.com/production/original_195255339.png'},
#     'sentiment': None},
#    'filters': {'day_counts': 21, 'official_api': True}},
#   {'id': 195255710,
#    'body': '$CSCO NEW ARTICLE : Arista Networks: Starting To Look Interesting https://dashboard.stck.pro/news.php?ticker=CSCO&amp;rowid=3640297 Get all the latest $CSCO related news here : https://dashboard.stck.pro/news.php?ticker=CSCO',
#    'created_at': '2020-02-17T23:04:07Z',
#    'user': {'id': 1555408,
#     'username': 'STCKPRO',
#     'name': 'STCK.PRO',
#     'avatar_url': 'https://avatars.stocktwits.com/production/1555408/thumb-1576077822.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/1555408/thumb-1576077822.png',
#     'join_date': '2018-07-24',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 736,
#     'following': 8,
#     'ideas': 64474,
#     'watchlist_stocks_count': 15,
#     'like_count': 36,
#     'plus_tier': 'month',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 5011,
#     'title': 'STCK.PRO',
#     'url': 'https://dashboard.stck.pro'},
#    'symbols': [{'id': 1471,
#      'symbol': 'CSCO',
#      'title': 'Cisco Systems, Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 38563}],
#    'links': [{'title': 'CISCO SYSTEMS (CSCO) News - STCK.PRO',
#      'url': 'https://dashboard.stck.pro/news.php?ticker=CSCO&rowid=3640297',
#      'shortened_url': 'https://dashboard.stck.pro/news.php?ticker=CSCO&rowid=3640297',
#      'shortened_expanded_url': 'dashboard.stck.pro/news.php...',
#      'description': 'Create watchlists and get real-time prices and news updates for all your watchlist symbols. join the STCK.PRO community of +40.000 active users and discover the power of social financial news!',
#      'image': 'https://dashboard.stck.pro/img/stocktwits.png',
#      'created_at': '2020-02-17T23:04:10Z',
#      'video_url': None,
#      'source': {'name': 'Stck', 'website': 'https://dashboard.stck.pro'}}],
#    'mentioned_users': [],
#    'entities': {'sentiment': None},
#    'filters': {'day_counts': 308, 'official_api': False}},
#   {'id': 195257583,
#    'body': '$CSCO seems stuck at the 50 day SMA the past two days. Thursday and Friday both had somewhat larger wicks but the close was right at the 50 day SMA. Wait for a clear break from this point before taking a position.',
#    'created_at': '2020-02-17T23:27:42Z',
#    'user': {'id': 1812845,
#     'username': 'StockTricksWithNick',
#     'name': 'Nick',
#     'avatar_url': 'https://avatars.stocktwits.com/production/1812845/thumb-1577477940.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/1812845/thumb-1577477940.png',
#     'join_date': '2019-01-17',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 147,
#     'following': 9,
#     'ideas': 1293,
#     'watchlist_stocks_count': 8,
#     'like_count': 238,
#     'plus_tier': '',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 2269,
#     'title': 'StockTwits Web',
#     'url': 'https://stocktwits.com'},
#    'symbols': [{'id': 1471,
#      'symbol': 'CSCO',
#      'title': 'Cisco Systems, Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 38563}],
#    'mentioned_users': [],
#    'entities': {'sentiment': None},
#    'filters': {'day_counts': 15, 'official_api': True}},
#   {'id': 195257824,
#    'body': '$CSCO should get a bounce at the bottom of the range',
#    'created_at': '2020-02-17T23:30:38Z',
#    'user': {'id': 50220,
#     'username': 'Learnstocks101',
#     'name': 'Learnstocks Community',
#     'avatar_url': 'https://avatars.stocktwits.com/production/50220/thumb-1355460167.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/50220/thumb-1355460167.png',
#     'join_date': '2011-02-04',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 2396,
#     'following': 4,
#     'ideas': 21412,
#     'watchlist_stocks_count': 4,
#     'like_count': 6,
#     'plus_tier': '',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 2269,
#     'title': 'StockTwits Web',
#     'url': 'https://stocktwits.com'},
#    'symbols': [{'id': 1471,
#      'symbol': 'CSCO',
#      'title': 'Cisco Systems, Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 38558}],
#    'conversation': {'parent_message_id': 195257824,
#     'in_reply_to_message_id': None,
#     'parent': True,
#     'replies': 1},
#    'likes': {'total': 1, 'user_ids': [2907403]},
#    'mentioned_users': [],
#    'entities': {'chart': {'thumb': 'https://charts.stocktwits.com/production/small_195257824.png',
#      'large': 'https://charts.stocktwits.com/production/large_195257824.png',
#      'original': 'https://charts.stocktwits.com/production/original_195257824.png',
#      'url': 'https://charts.stocktwits.com/production/original_195257824.png'},
#     'sentiment': None},
#    'filters': {'day_counts': 6, 'official_api': True}},
#   {'id': 195259058,
#    'body': '$CSCO loooking good',
#    'created_at': '2020-02-17T23:46:53Z',
#    'user': {'id': 2239476,
#     'username': 'organismee',
#     'name': 'Jeeves',
#     'avatar_url': 'https://avatars.stocktwits.com/production/2239476/thumb-1566587327.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/2239476/thumb-1566587327.png',
#     'join_date': '2019-08-03',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 16,
#     'following': 20,
#     'ideas': 1629,
#     'watchlist_stocks_count': 104,
#     'like_count': 182,
#     'plus_tier': '',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 2095,
#     'title': 'StockTwits For Android ',
#     'url': 'http://www.stocktwits.com/mobile'},
#    'symbols': [{'id': 1471,
#      'symbol': 'CSCO',
#      'title': 'Cisco Systems, Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 38534}],
#    'likes': {'total': 2, 'user_ids': [2012256, 1235262]},
#    'mentioned_users': [],
#    'entities': {'sentiment': {'basic': 'Bearish'}},
#    'filters': {'day_counts': 28, 'official_api': True}}]}

# %%
noEmojisDF.cleanSents
# Out:
# 0        $CSCO  I would rather buy Cisco vs the rest of...
# 1        $AAPL great traders on here higher on below av...
# 2        $QCOM $AAPL \nHave u watched Korean movies or ...
# 3        $AAPL waiting waiting; for 330! I got all day ...
# 4        $AAPL This Pump today has my 330 calls fully E...
#                                ...
# 90414    $AAPL THe BEST stock on this planet! $$$$$$$$$...
# 90415        $SPY $AMD $AAPL $JPM whats a monthly candle?
# 90416    $FB lowest value among fang stocks.  Sell $AAP...
# 90417                               $AAPL  not sustainable
# 90418    $AAPL 4 Green weekly candles. Hasn&#39;t had m...
# Name: cleanSents, Length: 90419, dtype: object

# %%
historicalTwits
# Out:
#               id                                         cleanSents  \
# 0      194642803  $CSCO  I would rather buy Cisco vs the rest of...
# 1      194642760  $AAPL great traders on here higher on below av...
# 2      194642633  $QCOM $AAPL \nHave u watched Korean movies or ...
# 3      194642618  $AAPL waiting waiting; for 330! I got all day ...
# 4      194642405  $AAPL This Pump today has my 330 calls fully E...
# ...          ...                                                ...
# 90414  182248130  $AAPL THe BEST stock on this planet! $$$$$$$$$...
# 90415  182248110      $SPY $AMD $AAPL $JPM whats a monthly candle?
# 90416  182247963  $FB lowest value among fang stocks.  Sell $AAP...
# 90417  182247807                             $AAPL  not sustainable
# 90418  182247789  $AAPL 4 Green weekly candles. Hasn&#39;t had m...
#
#                    created      tag  \
# 0      2020-02-12 21:59:02     none
# 1      2020-02-12 21:58:51  Bearish
# 2      2020-02-12 21:58:19     none
# 3      2020-02-12 21:58:15     none
# 4      2020-02-12 21:57:24     none
# ...                    ...      ...
# 90414  2019-11-01 17:40:39  Bullish
# 90415  2019-11-01 17:40:26     none
# 90416  2019-11-01 17:39:30  Bullish
# 90417  2019-11-01 17:38:32  Bearish
# 90418  2019-11-01 17:38:27  Bearish
#
#                                               newSymbols
# 0      [{'symbol': 'AAPL', 'title': 'Apple Inc.'}, {'...
# 1            [{'symbol': 'AAPL', 'title': 'Apple Inc.'}]
# 2      [{'symbol': 'AAPL', 'title': 'Apple Inc.'}, {'...
# 3            [{'symbol': 'AAPL', 'title': 'Apple Inc.'}]
# 4            [{'symbol': 'AAPL', 'title': 'Apple Inc.'}]
# ...                                                  ...
# 90414        [{'symbol': 'AAPL', 'title': 'Apple Inc.'}]
# 90415  [{'symbol': 'AAPL', 'title': 'Apple Inc.'}, {'...
# 90416  [{'symbol': 'AAPL', 'title': 'Apple Inc.'}, {'...
# 90417        [{'symbol': 'AAPL', 'title': 'Apple Inc.'}]
# 90418        [{'symbol': 'AAPL', 'title': 'Apple Inc.'}]
#
# [90419 rows x 5 columns]

# %%
url = "https://api.stocktwits.com/api/2/streams/symbol/{}.json".format('DELL')
response = requests.get(url, params = {'since' : 195873489}).json()

# %%
response
# Out:
# {'response': {'status': 200},
#  'symbol': {'id': 1579,
#   'symbol': 'DELL',
#   'title': 'Dell Inc.',
#   'aliases': [],
#   'is_following': False,
#   'watchlist_count': 2971},
#  'cursor': {'more': False, 'since': None, 'max': None},
#  'messages': []}

# %%
json_normalize(response['messages']).empty
# Out:
# c:\users\russell\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """Entry point for launching an IPython kernel.
# True
