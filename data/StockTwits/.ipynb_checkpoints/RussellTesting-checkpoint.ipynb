# %%
# The stock Symbols that we will iterate through
# Apple = AAPL
# Amazon = AMZN
# Google = GOOGL
# Microsoft = MSFT
# Dell = DELL
# IBM = IBM
# Intel = INTC
# HP = HPQ
# Facebook = FB
# Cisco Systems = CSCO
# Oracle = ORCL
# HP Enterprise = HPE
# Micron Tech = MU
# DXC Tech = DXC
# Thermo Fisher Scientific = TMO

# Qualcomm = QCOM
# Jabil = JBL
# Broadcom = AVGO
# Western Digital = WDC
# Applied Materials = AMAT


# Tesla = TSLA
# Alibaba = BABA
# Nvidia = NVDA
# Walmart = WMT
# Walt Disney = DIS
stockSymbol = ["AAPL", "AMZN", "GOOGL","MSFT", "DELL", "IBM", "INTC", "HPQ",
               "FB", "CSCO", "ORCL", "HPE", "MU", "DXC", "TMO"]

# %%
#Import statements
import json
from pandas.io.json import json_normalize
import requests
import pandas as pd
import datetime
import os
import csv
import time

# %%
url = "https://api.stocktwits.com/api/2/streams/symbol/AAPL.json"
response = requests.get(url).json()

# %%
dataframe = json_normalize(response['messages'])[{'body', 'id', 'symbols'}]

# %%
print(type(dataframe['symbols'][0]))
dataframe['symbols'].head(1)
# Out:
# <class 'list'>
# 0    [{'id': 677, 'symbol': 'DJIA', 'title': 'Dow J...
# Name: symbols, dtype: object

# %%
s = pd.Series(['A', 'B', 'C'])
for index in s.items():
    print(f"Index : {index}, Value : {value}")

# %%
dataF = pd.DataFrame()

# %%
type(dataframe['symbols'][0])
# Out:
# list

# %%
for index in dataframe['symbols']:
    tempSym = []
    tempTi = []
    for diction in index:
        if diction.get('symbol') != 'AAPL':
            tempSym.append(diction.get('symbol'))
            tempTi.append(diction.get('title'))
            
    print(tempSym)
    print(tempTi)
# Out:
# ['DJIA', 'MSFT', 'SPY', 'QQQ']
# ['Dow Jones Industrial Index', 'Microsoft Corporation', 'SPDR S&P 500', 'PowerShares Nasdaq-100 QQQ']
# []
# []
# []
# []
# ['MSFT', 'GOOGL', 'BABA']
# ['Microsoft Corporation', 'Alphabet Inc. Class A', 'Alibaba']
# []
# []
# []
# []
# []
# []
# []
# []
# ['AMD', 'TSLA']
# ['Advanced Micro Devices, Inc.', 'Tesla, Inc.']
# ['AMZN', 'S', 'BABA', 'SPCE']
# ['Amazon.com Inc.', 'Sprint Nextel Corp.', 'Alibaba', 'Virgin Galactic ']
# []
# []
# []
# []
# ['BABA']
# ['Alibaba']
# ['ACB']
# ['Aurora Cannabis Inc']
# []
# []
# []
# []
# []
# []
# ['SPY']
# ['SPDR S&P 500']
# ['AMZN', 'NFLX', 'BA', 'TSLA']
# ['Amazon.com Inc.', 'Netflix, Inc.', 'Boeing Co.', 'Tesla, Inc.']
# ['SPY', 'QQQ']
# ['SPDR S&P 500', 'PowerShares Nasdaq-100 QQQ']
# ['NFLX']
# ['Netflix, Inc.']
# []
# []
# []
# []
# ['SPY']
# ['SPDR S&P 500']
# ['MSFT', 'GOOGL']
# ['Microsoft Corporation', 'Alphabet Inc. Class A']
# ['AMZN', 'GOOG', 'MSFT', 'FB']
# ['Amazon.com Inc.', 'Alphabet Inc. Class C', 'Microsoft Corporation', 'Facebook']
# []
# []
# ['BABA']
# ['Alibaba']
# ['SPY']
# ['SPDR S&P 500']
# []
# []

# %%
dataF = dataF.append(pd.DataFrame([lis.get('symbol'),lis.get('title')]))
# Out:
#                              0
# 0                   Apple Inc.
# 1                         AAPL
# 0   Dow Jones Industrial Index
# 1                         DJIA
# 0                   Apple Inc.
# 1                         AAPL
# 0        Microsoft Corporation
# 1                         MSFT
# 0                          SPY
# 1                 SPDR S&P 500
# 0   PowerShares Nasdaq-100 QQQ
# 1                          QQQ
# 0                   Apple Inc.
# 1                         AAPL
# 0                   Apple Inc.
# 1                         AAPL
# 0                   Apple Inc.
# 1                         AAPL
# 0        Microsoft Corporation
# 1                         MSFT
# 0        Alphabet Inc. Class A
# 1                        GOOGL
# 0                         BABA
# 1                      Alibaba
# 0                   Apple Inc.
# 1                         AAPL
# 0                   Apple Inc.
# 1                         AAPL
# 0                   Apple Inc.
# 1                         AAPL
# ..                         ...
# 0                          SPY
# 1                 SPDR S&P 500
# 0                         AAPL
# 1                   Apple Inc.
# 0                         MSFT
# 1        Microsoft Corporation
# 0                        GOOGL
# 1        Alphabet Inc. Class A
# 0                         AAPL
# 1                   Apple Inc.
# 0                         AMZN
# 1              Amazon.com Inc.
# 0                         GOOG
# 1        Alphabet Inc. Class C
# 0                         MSFT
# 1        Microsoft Corporation
# 0                           FB
# 1                     Facebook
# 0                         AAPL
# 1                   Apple Inc.
# 0                         AAPL
# 1                   Apple Inc.
# 0                         BABA
# 1                      Alibaba
# 0                         AAPL
# 1                   Apple Inc.
# 0                          SPY
# 1                 SPDR S&P 500
# 0                         AAPL
# 1                   Apple Inc.
#
# [250 rows x 1 columns]

# %%
dataframe['symbols'][0][:2]
# Out:
# [{'id': 677,
#   'symbol': 'DJIA',
#   'title': 'Dow Jones Industrial Index',
#   'aliases': [],
#   'is_following': False,
#   'watchlist_count': 45326},
#  {'id': 686,
#   'symbol': 'AAPL',
#   'title': 'Apple Inc.',
#   'aliases': [],
#   'is_following': False,
#   'watchlist_count': 347394}]

# %%
symbol = dataframe['symbols'][everyRow][everySymbolPerRow].get('symbol')
title = dataframe['symbols'][everyRow][everySymbolPerRow].get('title')
# Out:
# [{'id': 677,
#   'symbol': 'DJIA',
#   'title': 'Dow Jones Industrial Index',
#   'aliases': [],
#   'is_following': False,
#   'watchlist_count': 45326},
#  {'id': 686,
#   'symbol': 'AAPL',
#   'title': 'Apple Inc.',
#   'aliases': [],
#   'is_following': False,
#   'watchlist_count': 347394},
#  {'id': 2735,
#   'symbol': 'MSFT',
#   'title': 'Microsoft Corporation',
#   'aliases': [],
#   'is_following': False,
#   'watchlist_count': 156556},
#  {'id': 7271,
#   'symbol': 'SPY',
#   'title': 'SPDR S&P 500',
#   'aliases': [],
#   'is_following': False,
#   'watchlist_count': 160361},
#  {'id': 9581,
#   'symbol': 'QQQ',
#   'title': 'PowerShares Nasdaq-100 QQQ',
#   'aliases': ['QQQQ'],
#   'is_following': False,
#   'watchlist_count': 48712}]

# %%
def get_other_symbols(df):
    for element in df['symbols']:
        print(df['symbols'][row])

# %%
for row in dataframe['symbols']:
    print(dataframe['symbols'][element])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-99-006eb492ee69> in <module>
#       1 for row in dataframe['symbols']:
# ----> 2     print(dataframe['symbols'][element])
#
# NameError: name 'element' is not defined

# %%
get_other_symbols(dataframe)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-95-2bc62a5d86ea> in <module>
# ----> 1 get_other_symbols(dataframe)
#
# <ipython-input-94-d515724c54b2> in get_other_symbols(df)
#       1 def get_other_symbols(df):
#       2     for row in df['symbols']:
# ----> 3         print(df['symbols'][row])
#
# c:\users\russe\appdata\local\programs\python\python37\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#    1111             key = check_bool_indexer(self.index, key)
#    1112
# -> 1113         return self._get_with(key)
#    1114
#    1115     def _get_with(self, key):
#
# c:\users\russe\appdata\local\programs\python\python37\lib\site-packages\pandas\core\series.py in _get_with(self, key)
#    1153             # handle the dup indexing case (GH 4246)
#    1154             if isinstance(key, (list, tuple)):
# -> 1155                 return self.loc[key]
#    1156
#    1157             return self.reindex(key)
#
# c:\users\russe\appdata\local\programs\python\python37\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1422
#    1423             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1424             return self._getitem_axis(maybe_callable, axis=axis)
#    1425
#    1426     def _is_scalar_access(self, key: Tuple):
#
# c:\users\russe\appdata\local\programs\python\python37\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1837                     raise ValueError("Cannot index with multidimensional key")
#    1838
# -> 1839                 return self._getitem_iterable(key, axis=axis)
#    1840
#    1841             # nested tuple slicing
#
# c:\users\russe\appdata\local\programs\python\python37\lib\site-packages\pandas\core\indexing.py in _getitem_iterable(self, key, axis)
#    1131         else:
#    1132             # A collection of keys
# -> 1133             keyarr, indexer = self._get_listlike_indexer(key, axis, raise_missing=False)
#    1134             return self.obj._reindex_with_indexers(
#    1135                 {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#
# c:\users\russe\appdata\local\programs\python\python37\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1084             if len(ax) or not len(key):
#    1085                 key = self._convert_for_reindex(key, axis)
# -> 1086             indexer = ax.get_indexer_for(key)
#    1087             keyarr = ax.reindex(keyarr)[0]
#    1088         else:
#
# c:\users\russe\appdata\local\programs\python\python37\lib\site-packages\pandas\core\indexes\base.py in get_indexer_for(self, target, **kwargs)
#    4815         """
#    4816         if self.is_unique:
# -> 4817             return self.get_indexer(target, **kwargs)
#    4818         indexer, _ = self.get_indexer_non_unique(target, **kwargs)
#    4819         return indexer
#
# c:\users\russe\appdata\local\programs\python\python37\lib\site-packages\pandas\core\indexes\range.py in get_indexer(self, target, method, limit, tolerance)
#     396         if not (is_integer_dtype(target_array) and target_array.ndim == 1):
#     397             # checks/conversions/roundings are delegated to general method
# --> 398             return super().get_indexer(target, method=method, tolerance=tolerance)
#     399
#     400         locs = target_array - start
#
# c:\users\russe\appdata\local\programs\python\python37\lib\site-packages\pandas\core\indexes\base.py in get_indexer(self, target, method, limit, tolerance)
#    2978             target = target.astype(object)
#    2979             return this.get_indexer(
# -> 2980                 target, method=method, limit=limit, tolerance=tolerance
#    2981             )
#    2982
#
# c:\users\russe\appdata\local\programs\python\python37\lib\site-packages\pandas\core\indexes\base.py in get_indexer(self, target, method, limit, tolerance)
#    3002                 )
#    3003
# -> 3004             indexer = self._engine.get_indexer(target._ndarray_values)
#    3005
#    3006         return ensure_platform_int(indexer)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_indexer()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.lookup()
#
# TypeError: unhashable type: 'dict'

# %%
dataframe['symbols'][4][:5]
# Out:
# [{'id': 733,
#   'symbol': 'ACWI',
#   'title': 'iShares MSCI ACWI Index',
#   'aliases': [],
#   'is_following': False,
#   'watchlist_count': 205},
#  {'id': 4559,
#   'symbol': 'BMY',
#   'title': 'Bristol-Myers Squibb Company',
#   'aliases': [],
#   'is_following': False,
#   'watchlist_count': 12708},
#  {'id': 7434,
#   'symbol': 'TMO',
#   'title': 'Thermo Fisher Scientific, Inc.',
#   'aliases': [],
#   'is_following': False,
#   'watchlist_count': 1982},
#  {'id': 11836,
#   'symbol': 'PCI',
#   'title': 'PIMCO Dynamic Credit Income Fund',
#   'aliases': [],
#   'is_following': False,
#   'watchlist_count': 385},
#  {'id': 13254,
#   'symbol': 'ARNC',
#   'title': 'Arconic Inc',
#   'aliases': [],
#   'is_following': False,
#   'watchlist_count': 2206}]

# %%
# Extracting specifix keys from dictionary 
res = dict((k, test_dict[k]) for k in ['nikhil', 'akshat'] 
                                        if k in test_dict) 
res = dict((k, symbols['symbols'][4]) for k in ['symbol'])

# %%
response = requests.get(url, params={'max' : '193528854' }).json()
