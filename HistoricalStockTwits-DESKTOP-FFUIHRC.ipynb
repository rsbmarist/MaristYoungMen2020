# %%
#Import statements
import json
import requests
import pandas as pd
import numpy as np
import datetime
from pandas.io.json import json_normalize
import os
import csv
import time

# %%
# The stock Symbols that we will iterate through
# Apple = AAPL
# Amazon = AMZN
# Google = GOOGL
# Microsoft = MSFT
# Dell = DELL
# IBM = IBM
# Intel = INTC
# HP = HPQ
# Facebook = FB
# Cisco Systems = CSCO
# Oracle = ORCL
# HP Enterprise = HPE
# Micron Tech = MU
# DXC Tech = DXC  We have recovered all available historical data March 2017 was IPO
# Thermo Fisher Scientific = TMO

# Qualcomm = QCOM
# Jabil = JBL
# Broadcom = AVGO
# Western Digital = WDC
# Applied Materials = AMAT


# Tesla = TSLA
# Alibaba = BABA
# Nvidia = NVDA
# Walmart = WMT
# Walt Disney = DIS
stockSymbol = ["AAPL", "AMZN", "GOOGL","MSFT", "DELL", "IBM", "INTC", "HPQ",
               "FB", "CSCO", "ORCL", "HPE", "MU", "DXC", "TMO"]

# %%
#Gathers the json file and all needed data values.
def collect_Twits(res):
    try:
        df = (json_normalize(res['messages'])[{'id','body','created_at','entities.sentiment.basic','symbols'}])
        
        #Reorders the columns
        df = df[['id','body','created_at','entities.sentiment.basic','symbols']]
        
        #Renames the columns
        df = df.rename(columns = {'created_at':'created', 'entities.sentiment.basic': 'tag'})
        
    except:
        df = (json_normalize(res['messages'])[{'id','body','created_at','entities.sentiment','symbols'}])
        #Reorders the columns
        df = df[['id','body','created_at','entities.sentiment','symbols']]
        
        #Renames the columns
        df = df.rename(columns = {'created_at':'created', 'entities.sentiment': 'tag'})


    #Replaces the NAN with a string "none"
    df = df.replace(np.nan, 'none', regex=True)
    
    #Replaces the string as a datetime variable
    dateFormat = "%Y-%m-%dT%H:%M:%SZ"
    df['created'] = pd.to_datetime(df['created'], format=dateFormat)
    
    #returns the dataframe in correct format
    return df

# %%
while True:
    for symbol in stockSymbol:
    
        #selects the file to add to
        file = '{}_twits.csv'.format(symbol)
    
        historicalTwits = pd.read_csv(file)
        oldestID = historicalTwits['id'].iloc[-1]
    
        url = "https://api.stocktwits.com/api/2/streams/symbol/{}.json".format(symbol)
        response = requests.get(url, params = {'max' :  oldestID}).json()
        
        if not (response['cursor']['more']):
            stockSymbol.remove(symbol)
            continue
    
        tempTwitsDf = collect_Twits(response)

        newHistoricalTwits = historicalTwits.append(tempTwitsDf)
    
        newHistoricalTwits.to_csv(r'{}_twits.csv'.format(symbol), index=False)
        time.sleep(15)
        newHistoricalTwits.to_csv(r'{}_twitsCopy.csv'.format(symbol), index=False)
        time.sleep(15)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-28-206abae353ad> in <module>
#       9
#      10         url = "https://api.stocktwits.com/api/2/streams/symbol/{}.json".format(symbol)
# ---> 11         response = requests.get(url, params = {'max' :  oldestID}).json()
#      12
#      13         if not (response['cursor']['more']):
#
# ~\Anaconda3\lib\site-packages\requests\models.py in json(self, **kwargs)
#     895                     # used.
#     896                     pass
# --> 897         return complexjson.loads(self.text, **kwargs)
#     898
#     899     @property
#
# ~\Anaconda3\lib\json\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346             parse_int is None and parse_float is None and
#     347             parse_constant is None and object_pairs_hook is None and not kw):
# --> 348         return _default_decoder.decode(s)
#     349     if cls is None:
#     350         cls = JSONDecoder
#
# ~\Anaconda3\lib\json\decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# ~\Anaconda3\lib\json\decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
#start the files and gather most recent data right now

#Do not RUN anymore!!

#for symbol in stockSymbol:
    
    #selects the file to add to
    #file = '{}_twits.csv'.format(symbol)
    
    #historicalTwits = pd.read_csv(file)
    #oldestID = historicalTwits['id'][-1]
    
    #url = "https://api.stocktwits.com/api/2/streams/symbol/{}.json".format(symbol)
    #response = requests.get(url, params = {'max' :  oldestID}).json()
    
    #response = requests.get(url).json()
    
    #tempTwitsDf = collect_Twits(response)
    
    #tempTwitsDf.to_csv(r'{}_twits.csv'.format(symbol), index=False)

# %%
(response['cursor']['more'])
# Out:
# True

# %%
response
# Out:
# {'response': {'status': 200},
#  'symbol': {'id': 12845,
#   'symbol': 'HPE',
#   'title': 'Hewlett Packard Enterprise',
#   'aliases': [],
#   'is_following': False,
#   'watchlist_count': 4353},
#  'cursor': {'more': True, 'since': 121801532, 'max': 120532905},
#  'messages': [{'id': 121801532,
#    'body': '$HPE 2.9m ago: SC Magazine Names Aruba IntroSpect UEBA as Industry’s Finest for Detecting Advanced Cyberattacks http://www.enhancedonlinenews.com/news/eon/20180501005587/en/SC-Magazine-Names-Aruba-IntroSpect-UEBA-Industry%E2%80%99s/',
#    'created_at': '2018-05-01T12:03:52Z',
#    'user': {'id': 1277938,
#     'username': 'livetraderalerts',
#     'name': 'LiveTraderAlerts.com News feed',
#     'avatar_url': 'https://avatars.stocktwits.com/production/1277938/thumb-1526067389.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/1277938/thumb-1526067389.png',
#     'join_date': '2017-11-22',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 3646,
#     'following': 8,
#     'ideas': 517860,
#     'watchlist_stocks_count': 3,
#     'like_count': 6,
#     'plus_tier': 'life',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 3746,
#     'title': 'LiveTraderAlerts.com',
#     'url': 'https://LiveTraderAlerts.com'},
#    'symbols': [{'id': 12845,
#      'symbol': 'HPE',
#      'title': 'Hewlett Packard Enterprise',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 4353}],
#    'links': [{'title': "SC Magazine Names Aruba IntroSpect UEBA as Industry's Finest for Detecting Advanced Cyberattacks",
#      'url': 'http://www.enhancedonlinenews.com/news/eon/20180501005587/en/SC-Magazine-Names-Aruba-IntroSpect-UEBA-Industry%E2%80%99s/',
#      'shortened_url': 'http://www.enhancedonlinenews.com/news/eon/20180501005587/en/SC-Magazine-Names-Aruba-IntroSpect-UEBA-Industry%E2%80%99s/',
#      'shortened_expanded_url': 'enhancedonlinenews.com/news...',
#      'description': "SANTA CLARA, Calif.--( EON: Enhanced Online News )--Aruba, a Hewlett Packard Enterprise company (NYSE: HPE), today announced that SC Magazine, the world's preeminent publication for cybersecurity professionals, named Aruba IntroSpect as this year's best product for detecting and stopping increasingly sophisticated cyberattacks due to mobile, IoT, and cloud.",
#      'image': 'https://mms.businesswire.com/media/20180410005590/en/650577/21/Klein_ISD_Image_1.jpg',
#      'created_at': '2018-05-01T12:03:55Z',
#      'video_url': None,
#      'source': {'name': 'Enhancedonlinenews',
#       'website': 'https://www.enhancedonlinenews.com'}}],
#    'mentioned_users': [],
#    'entities': {'sentiment': None},
#    'filters': {'day_counts': 0, 'official_api': False}},
#   {'id': 121773273,
#    'body': '$HPE  .,',
#    'created_at': '2018-05-01T01:13:30Z',
#    'user': {'id': 636311,
#     'username': 'Pulverizer',
#     'name': 'Pul',
#     'avatar_url': 'https://avatars.stocktwits.com/production/636311/thumb-1527003922.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/636311/thumb-1527003922.png',
#     'join_date': '2015-11-19',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 231,
#     'following': 80,
#     'ideas': 7552,
#     'watchlist_stocks_count': 20,
#     'like_count': 7128,
#     'plus_tier': '',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 2269,
#     'title': 'StockTwits Web',
#     'url': 'https://stocktwits.com'},
#    'symbols': [{'id': 12845,
#      'symbol': 'HPE',
#      'title': 'Hewlett Packard Enterprise',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 4353}],
#    'mentioned_users': [],
#    'entities': {'chart': {'thumb': 'https://charts.stocktwits.com/production/small_121773273.PNG',
#      'large': 'https://charts.stocktwits.com/production/large_121773273.PNG',
#      'original': 'https://charts.stocktwits.com/production/original_121773273.PNG',
#      'url': 'https://charts.stocktwits.com/production/original_121773273.PNG'},
#     'sentiment': None},
#    'filters': {'day_counts': 0, 'official_api': True}},
#   {'id': 121692928,
#    'body': '$HPE BLOCK TRADE [10:51:34] @ $17.37 for 995,477 shares.',
#    'created_at': '2018-04-30T14:51:35Z',
#    'user': {'id': 339513,
#     'username': 'equityswing',
#     'name': 'EquitySwing',
#     'avatar_url': 'https://avatars.stocktwits.com/production/339513/thumb-1498006810.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/339513/thumb-1498006810.png',
#     'join_date': '2014-04-04',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 3001,
#     'following': 1382,
#     'ideas': 75715,
#     'watchlist_stocks_count': 0,
#     'like_count': 2266,
#     'plus_tier': '',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 2985,
#     'title': 'Equity$wing',
#     'url': 'https://www.equityswing.com'},
#    'symbols': [{'id': 12845,
#      'symbol': 'HPE',
#      'title': 'Hewlett Packard Enterprise',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 4353}],
#    'mentioned_users': [],
#    'entities': {'sentiment': None},
#    'filters': {'day_counts': 0, 'official_api': False}},
#   {'id': 121646672,
#    'body': 'We have detected 2 positive indicators as of 04-27 for $HPE More info at http://www.dividendbot.com?s=HPE',
#    'created_at': '2018-04-29T23:52:06Z',
#    'user': {'id': 1279378,
#     'username': 'DividendBot',
#     'name': 'Dividend Bot',
#     'avatar_url': 'https://avatars.stocktwits.com/production/1279378/thumb-1512247023.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/1279378/thumb-1512247023.png',
#     'join_date': '2017-11-23',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 1041,
#     'following': 59,
#     'ideas': 102594,
#     'watchlist_stocks_count': 0,
#     'like_count': 0,
#     'plus_tier': '',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 3771,
#     'title': 'Dividend Bot',
#     'url': 'http://dividendbot.com/'},
#    'symbols': [{'id': 12845,
#      'symbol': 'HPE',
#      'title': 'Hewlett Packard Enterprise',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 4353}],
#    'links': [{'title': 'HPE | Dividend Bot',
#      'url': 'http://www.dividendbot.com?s=HPE',
#      'shortened_url': 'http://www.dividendbot.com?s=HPE',
#      'shortened_expanded_url': 'dividendbot.com/?s=HPE',
#      'description': 'Insiders have made 2 acquisition(s) over past seven days. [see insider section below for more details]',
#      'image': 'http://dividendbot.com/wp-content/uploads/2017/12/dividend-bot.png',
#      'created_at': '2018-04-29T23:52:08Z',
#      'video_url': None,
#      'source': {'name': 'Dividendbot',
#       'website': 'http://www.dividendbot.com'}}],
#    'mentioned_users': [],
#    'entities': {'sentiment': None},
#    'filters': {'day_counts': 0, 'official_api': False}},
#   {'id': 121487785,
#    'body': 'First Hour Top Option Volume! $IMGN $CBL $BCS, $TWX $HIG $OCLR $EXPE $HPE $KNX.',
#    'created_at': '2018-04-27T14:33:38Z',
#    'user': {'id': 1479525,
#     'username': 'JamesTyler_Live',
#     'name': 'James Tyler',
#     'avatar_url': 'https://avatars.stocktwits.com/production/1479525/thumb-1524625740.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/1479525/thumb-1524625740.png',
#     'join_date': '2018-04-25',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 15,
#     'following': 0,
#     'ideas': 210,
#     'watchlist_stocks_count': 0,
#     'like_count': 1,
#     'plus_tier': '',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 2269,
#     'title': 'StockTwits Web',
#     'url': 'https://stocktwits.com'},
#    'symbols': [{'id': 1812,
#      'symbol': 'EXPE',
#      'title': 'Expedia Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 6871},
#     {'id': 2278,
#      'symbol': 'IMGN',
#      'title': 'Immunogen Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 8773},
#     {'id': 2956,
#      'symbol': 'OCLR',
#      'title': 'Oclaro, Inc.',
#      'aliases': ['BKHM'],
#      'is_following': False,
#      'watchlist_count': 6946},
#     {'id': 4466,
#      'symbol': 'BCS',
#      'title': 'Barclays PLC',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 3133},
#     {'id': 4665,
#      'symbol': 'CBL',
#      'title': 'CBL & Associates Properties Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 1705},
#     {'id': 5670,
#      'symbol': 'HIG',
#      'title': 'Hartford Financial Services Group Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 622},
#     {'id': 6101,
#      'symbol': 'KNX',
#      'title': 'Knight Transportation Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 512},
#     {'id': 7502,
#      'symbol': 'TWX',
#      'title': 'Time Warner Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 3501},
#     {'id': 12845,
#      'symbol': 'HPE',
#      'title': 'Hewlett Packard Enterprise',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 4354}],
#    'mentioned_users': [],
#    'entities': {'sentiment': None},
#    'filters': {'day_counts': 0, 'official_api': True}},
#   {'id': 121487408,
#    'body': '- Heavy first hour option volume DETECTED in :  $IMGN $CBL $BCS, $TWX $HIG $OCLR $EXPE $HPE $KNX.',
#    'created_at': '2018-04-27T14:32:02Z',
#    'user': {'id': 112834,
#     'username': 'WallStJesus',
#     'name': 'WALL ST JESUS',
#     'avatar_url': 'https://avatars.stocktwits.com/production/112834/thumb-1581401422.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/112834/thumb-1581401422.png',
#     'join_date': '2011-10-19',
#     'official': False,
#     'identity': 'User',
#     'classification': ['suggested'],
#     'followers': 41618,
#     'following': 82,
#     'ideas': 64406,
#     'watchlist_stocks_count': 62,
#     'like_count': 673,
#     'plus_tier': '',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 2269,
#     'title': 'StockTwits Web',
#     'url': 'https://stocktwits.com'},
#    'symbols': [{'id': 1812,
#      'symbol': 'EXPE',
#      'title': 'Expedia Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 6871},
#     {'id': 2278,
#      'symbol': 'IMGN',
#      'title': 'Immunogen Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 8773},
#     {'id': 2956,
#      'symbol': 'OCLR',
#      'title': 'Oclaro, Inc.',
#      'aliases': ['BKHM'],
#      'is_following': False,
#      'watchlist_count': 6946},
#     {'id': 4466,
#      'symbol': 'BCS',
#      'title': 'Barclays PLC',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 3133},
#     {'id': 4665,
#      'symbol': 'CBL',
#      'title': 'CBL & Associates Properties Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 1705},
#     {'id': 5670,
#      'symbol': 'HIG',
#      'title': 'Hartford Financial Services Group Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 622},
#     {'id': 6101,
#      'symbol': 'KNX',
#      'title': 'Knight Transportation Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 512},
#     {'id': 7502,
#      'symbol': 'TWX',
#      'title': 'Time Warner Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 3501},
#     {'id': 12845,
#      'symbol': 'HPE',
#      'title': 'Hewlett Packard Enterprise',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 4354}],
#    'mentioned_users': [],
#    'entities': {'sentiment': None},
#    'filters': {'day_counts': 0, 'official_api': True}},
#   {'id': 121462414,
#    'body': '$HPE hey nerds. Magic Formula time. \nhttps://magicformulamoney.com/hpe/',
#    'created_at': '2018-04-27T12:10:13Z',
#    'user': {'id': 1148087,
#     'username': 'That_MFing_Guy',
#     'name': 'That_MFing_Guy',
#     'avatar_url': 'https://avatars.stocktwits.com/production/1148087/thumb-1505251465.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/1148087/thumb-1505251465.png',
#     'join_date': '2017-08-05',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 14,
#     'following': 176,
#     'ideas': 376,
#     'watchlist_stocks_count': 34,
#     'like_count': 100,
#     'plus_tier': '',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 2269,
#     'title': 'StockTwits Web',
#     'url': 'https://stocktwits.com'},
#    'symbols': [{'id': 12845,
#      'symbol': 'HPE',
#      'title': 'Hewlett Packard Enterprise',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 4353}],
#    'links': [{'title': 'Magic Formula Money >> Hewlett Packard *starship* Enterprise (HPE)',
#      'url': 'https://magicformulamoney.com/hpe/',
#      'shortened_url': 'https://magicformulamoney.com/hpe/',
#      'shortened_expanded_url': 'magicformulamoney.com/hpe/',
#      'description': "You've found your way to the second post regarding Hewlett Packard's 2015 split. If you haven't read the post on HPQ, please start there! Here's a refresher: HP was one big company that sold software and computers. Investors didn't think computers were the future. So HP split.",
#      'image': 'https://magicformulamoney.com/wp-content/uploads/2018/04/You-Turn-Software-Into-Hardware-Funny-Computer-Meme-Picture.jpg',
#      'created_at': '2018-04-27T12:10:16Z',
#      'video_url': None,
#      'source': {'name': 'Magic Formula Money',
#       'website': 'https://magicformulamoney.com'}}],
#    'mentioned_users': [],
#    'entities': {'chart': {'thumb': 'https://charts.stocktwits.com/production/small_121462414.jpg',
#      'large': 'https://charts.stocktwits.com/production/large_121462414.jpg',
#      'original': 'https://charts.stocktwits.com/production/original_121462414.jpg',
#      'url': 'https://charts.stocktwits.com/production/original_121462414.jpg'},
#     'sentiment': None},
#    'filters': {'day_counts': 0, 'official_api': True}},
#   {'id': 121437185,
#    'body': 'With a Forward PE of 11.67, the valuation of $HPE can be described as very reasonable. https://www.chartmill.com/analyze.php?utm_source=stocktwits&amp;utm_medium=FA&amp;utm_content=VALUATION&amp;utm_campaign=social_tracking#/HPE?r=fa&amp;key=9733e702-233c-4673-b1fb-e154a2b10a81',
#    'created_at': '2018-04-27T01:57:03Z',
#    'user': {'id': 47688,
#     'username': 'ChartMill',
#     'name': 'ChartMill',
#     'avatar_url': 'https://avatars.stocktwits.com/production/47688/thumb-1363343728.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/47688/thumb-1363343728.png',
#     'join_date': '2011-01-26',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 13805,
#     'following': 899,
#     'ideas': 790911,
#     'watchlist_stocks_count': 20,
#     'like_count': 32,
#     'plus_tier': '',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 3193,
#     'title': 'Chartmill alerts',
#     'url': 'http://www.chartmill.com'},
#    'symbols': [{'id': 12845,
#      'symbol': 'HPE',
#      'title': 'Hewlett Packard Enterprise',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 4353}],
#    'links': [{'title': 'ChartMill.com | Technical Analysis Report',
#      'url': 'https://www.chartmill.com/analyze.php?utm_source=stocktwits&utm_medium=FA&utm_content=VALUATION&utm_campaign=social_tracking#/HPE?r=fa&key=9733e702-233c-4673-b1fb-e154a2b10a81',
#      'shortened_url': 'https://www.chartmill.com/analyze.php?utm_source=stocktwits&utm_medium=FA&utm_content=VALUATION&utm_campaign=social_tracking#/HPE?r=fa&key=9733e702-233c-4673-b1fb-e154a2b10a81',
#      'shortened_expanded_url': 'chartmill.com/analyze.php?u...',
#      'description': 'Technical Analysis reports, inspect technical and setup rating of stocks on NASDAQ,NYSE,AMEX and Euronext',
#      'image': 'https://www.chartmill.com/img/report.png',
#      'created_at': '2018-04-27T01:57:03Z',
#      'video_url': None,
#      'source': {'name': 'Chartmill', 'website': 'https://www.chartmill.com'}}],
#    'mentioned_users': [],
#    'entities': {'sentiment': None},
#    'filters': {'day_counts': 0, 'official_api': False}},
#   {'id': 121427835,
#    'body': 'Hewlett Packard Enterprise Director Margaret Whitman Sells $11,660,200.00 in $HPE http://www.marketbeat.com/i/271718',
#    'created_at': '2018-04-27T00:08:01Z',
#    'user': {'id': 1034235,
#     'username': 'MarketBeatInsiderTrades',
#     'name': 'MarketBeat Insider Trades',
#     'avatar_url': 'https://avatars.stocktwits.com/production/1034235/thumb-1492706962.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/1034235/thumb-1492706962.png',
#     'join_date': '2017-04-20',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 2004,
#     'following': 60,
#     'ideas': 113103,
#     'watchlist_stocks_count': 0,
#     'like_count': 0,
#     'plus_tier': '',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 1022, 'title': 'Zapier', 'url': 'https://zapier.com/'},
#    'symbols': [{'id': 12845,
#      'symbol': 'HPE',
#      'title': 'Hewlett Packard Enterprise',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 4353}],
#    'links': [{'title': 'NYSE:HPE - Hewlett Packard Enterprise Stock Price, Price Target & More',
#      'url': 'http://www.marketbeat.com/i/271718',
#      'shortened_url': 'http://www.marketbeat.com/i/271718',
#      'shortened_expanded_url': 'marketbeat.com/stocks/NYSE/...',
#      'description': "Thinking about adding Hewlett Packard Enterprise (NYSE:HPE) stock to your your portfolio? View HPE's stock price, price target, analyst ratings, dividend information, earnings history, financials, history, insider trades, news headlines and SEC filings in real-time at MarketBeat.",
#      'image': 'https://www.marketbeat.com/logos/hewlett-packard-enterprise-co-logo.jpg',
#      'created_at': '2018-04-27T00:08:05Z',
#      'video_url': None,
#      'source': {'name': 'Marketbeat',
#       'website': 'https://www.marketbeat.com'}}],
#    'mentioned_users': [],
#    'entities': {'sentiment': None},
#    'filters': {'day_counts': 0, 'official_api': False}},
#   {'id': 121409292,
#    'body': '$HPE Director &quot;WHITMAN MARGARET C&quot; just cashed in 674,000 Options (Tran Code - M, S)  --- Insider Forms, iOS app',
#    'created_at': '2018-04-26T21:30:27Z',
#    'user': {'id': 909249,
#     'username': 'InsiderForms',
#     'name': 'Insider Forms',
#     'avatar_url': 'https://avatars.stocktwits.com/production/909249/thumb-1482551759.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/909249/thumb-1482551759.png',
#     'join_date': '2016-12-24',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 2142,
#     'following': 2,
#     'ideas': 190047,
#     'watchlist_stocks_count': 1,
#     'like_count': 0,
#     'plus_tier': '',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 3019,
#     'title': 'Insider Forms',
#     'url': 'http://stocktwits.com/InsiderForms'},
#    'symbols': [{'id': 12845,
#      'symbol': 'HPE',
#      'title': 'Hewlett Packard Enterprise',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 4353}],
#    'mentioned_users': [],
#    'entities': {'sentiment': None},
#    'filters': {'day_counts': 0, 'official_api': False}},
#   {'id': 121408888,
#    'body': 'Hewlett Packard Enterprise Co director just cashed-in 674,000 options  http://www.conferencecalltranscripts.org/4/summary/?id=4850480 $HPE',
#    'created_at': '2018-04-26T21:28:00Z',
#    'user': {'id': 210967,
#     'username': 'cctranscripts',
#     'name': 'Conference Call Transcripts',
#     'avatar_url': 'https://avatars.stocktwits.com/production/210967/thumb-1363372333.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/210967/thumb-1363372333.png',
#     'join_date': '2013-01-30',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 5327,
#     'following': 9,
#     'ideas': 2071769,
#     'watchlist_stocks_count': 0,
#     'like_count': 736,
#     'plus_tier': '',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 1130,
#     'title': 'cctranscripts',
#     'url': 'http://conferencecalltranscripts.org'},
#    'symbols': [{'id': 12845,
#      'symbol': 'HPE',
#      'title': 'Hewlett Packard Enterprise',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 4353}],
#    'links': [{'title': 'Conference Call Transcripts',
#      'url': 'http://www.conferencecalltranscripts.org/4/summary/?id=4850480',
#      'shortened_url': 'http://www.conferencecalltranscripts.org/4/summary/?id=4850480',
#      'shortened_expanded_url': 'conferencecalltranscripts.o...',
#      'description': 'Company Conference Call Transcripts',
#      'image': None,
#      'created_at': '2018-04-26T21:28:01Z',
#      'video_url': None,
#      'source': {'name': 'Conferencecalltranscripts',
#       'website': 'http://www.conferencecalltranscripts.org'}}],
#    'mentioned_users': [],
#    'entities': {'sentiment': None},
#    'filters': {'day_counts': 0, 'official_api': False}},
#   {'id': 121408312,
#    'body': '$HPE new insider selling: 674000 shares. http://insiderbuyingselling.com/?t=HPE',
#    'created_at': '2018-04-26T21:23:39Z',
#    'user': {'id': 1419740,
#     'username': 'insiderbuyingselling',
#     'name': 'sky',
#     'avatar_url': 'https://avatars.stocktwits.com/production/1419740/thumb-1522159697.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/1419740/thumb-1522159697.png',
#     'join_date': '2018-02-22',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 1214,
#     'following': 0,
#     'ideas': 40514,
#     'watchlist_stocks_count': 0,
#     'like_count': 0,
#     'plus_tier': '',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 4049,
#     'title': 'insiderbuyingselling',
#     'url': 'http://insiderbuyingselling.com'},
#    'symbols': [{'id': 12845,
#      'symbol': 'HPE',
#      'title': 'Hewlett Packard Enterprise',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 4353}],
#    'links': [{'title': 'Tracking insider buying and selling stocks for Hewlett Packard Enterprise Co ( HPE )',
#      'url': 'http://insiderbuyingselling.com/?t=HPE',
#      'shortened_url': 'http://insiderbuyingselling.com/?t=HPE',
#      'shortened_expanded_url': 'insiderbuyingselling.com/?t...',
#      'description': 'Tracking insider buying and selling stocks for Hewlett Packard Enterprise Co ( HPE ). at insiderbuyingselling.com',
#      'image': None,
#      'created_at': '2018-04-26T21:23:39Z',
#      'video_url': None,
#      'source': {'name': 'Insiderbuyingselling',
#       'website': 'http://insiderbuyingselling.com'}}],
#    'mentioned_users': [],
#    'entities': {'sentiment': None},
#    'filters': {'day_counts': 0, 'official_api': False}},
#   {'id': 121357685,
#    'body': '$HPE BLOCK TRADE [13:4:37] @ $17.45 for 2,500,000 shares.',
#    'created_at': '2018-04-26T17:04:38Z',
#    'user': {'id': 339513,
#     'username': 'equityswing',
#     'name': 'EquitySwing',
#     'avatar_url': 'https://avatars.stocktwits.com/production/339513/thumb-1498006810.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/339513/thumb-1498006810.png',
#     'join_date': '2014-04-04',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 3001,
#     'following': 1382,
#     'ideas': 75715,
#     'watchlist_stocks_count': 0,
#     'like_count': 2266,
#     'plus_tier': '',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 2985,
#     'title': 'Equity$wing',
#     'url': 'https://www.equityswing.com'},
#    'symbols': [{'id': 12845,
#      'symbol': 'HPE',
#      'title': 'Hewlett Packard Enterprise',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 4353}],
#    'mentioned_users': [],
#    'entities': {'sentiment': None},
#    'filters': {'day_counts': 0, 'official_api': False}},
#   {'id': 121055502,
#    'body': '$HPE bears have 2 reasons on 04-24 to pay more attention http://www.dividendbot.com?s=HPE',
#    'created_at': '2018-04-24T18:24:08Z',
#    'user': {'id': 1279378,
#     'username': 'DividendBot',
#     'name': 'Dividend Bot',
#     'avatar_url': 'https://avatars.stocktwits.com/production/1279378/thumb-1512247023.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/1279378/thumb-1512247023.png',
#     'join_date': '2017-11-23',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 1041,
#     'following': 59,
#     'ideas': 102594,
#     'watchlist_stocks_count': 0,
#     'like_count': 0,
#     'plus_tier': '',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 3771,
#     'title': 'Dividend Bot',
#     'url': 'http://dividendbot.com/'},
#    'symbols': [{'id': 12845,
#      'symbol': 'HPE',
#      'title': 'Hewlett Packard Enterprise',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 4353}],
#    'links': [{'title': 'HPE | Dividend Bot',
#      'url': 'http://www.dividendbot.com?s=HPE',
#      'shortened_url': 'http://www.dividendbot.com?s=HPE',
#      'shortened_expanded_url': 'dividendbot.com/?s=HPE',
#      'description': 'Insiders have made 2 acquisition(s) over past seven days. [see insider section below for more details]',
#      'image': 'http://dividendbot.com/wp-content/uploads/2017/12/dividend-bot.png',
#      'created_at': '2018-04-24T18:24:10Z',
#      'video_url': None,
#      'source': {'name': 'Dividendbot',
#       'website': 'http://www.dividendbot.com'}}],
#    'mentioned_users': [],
#    'entities': {'sentiment': None},
#    'filters': {'day_counts': 0, 'official_api': False}},
#   {'id': 121022700,
#    'body': '$HPE Market Positioning is Slightly Overweight. CrowdThnk&#39;s Algo forecasts 57% chance Moving Higher: https://crowdthnk.com/stocks/HPE',
#    'created_at': '2018-04-24T15:28:31Z',
#    'user': {'id': 1352973,
#     'username': 'CrowdThnk',
#     'name': 'CrowdThnk',
#     'avatar_url': 'https://avatars.stocktwits.com/production/1352973/thumb-1518208375.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/1352973/thumb-1518208375.png',
#     'join_date': '2018-01-05',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 188,
#     'following': 0,
#     'ideas': 23132,
#     'watchlist_stocks_count': 9,
#     'like_count': 0,
#     'plus_tier': '',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 2269,
#     'title': 'StockTwits Web',
#     'url': 'https://stocktwits.com'},
#    'symbols': [{'id': 12845,
#      'symbol': 'HPE',
#      'title': 'Hewlett Packard Enterprise',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 4353}],
#    'links': [{'title': 'CrowdThnk',
#      'url': 'https://crowdthnk.com/stocks/HPE',
#      'shortened_url': 'https://crowdthnk.com/stocks/HPE',
#      'shortened_expanded_url': 'crowdthnk.com/stocks/HPE',
#      'description': '© Copyright 2017 CrowdThnk. All Rights reserved',
#      'image': None,
#      'created_at': '2018-04-24T15:28:32Z',
#      'video_url': None,
#      'source': {'name': 'Crowdthnk', 'website': 'https://crowdthnk.com'}}],
#    'mentioned_users': [],
#    'entities': {'chart': {'thumb': 'https://charts.stocktwits.com/production/small_121022700.png',
#      'large': 'https://charts.stocktwits.com/production/large_121022700.png',
#      'original': 'https://charts.stocktwits.com/production/original_121022700.png',
#      'url': 'https://charts.stocktwits.com/production/original_121022700.png'},
#     'sentiment': None},
#    'filters': {'day_counts': 0, 'official_api': True}},
#   {'id': 120986961,
#    'body': '$HPE 1.3m ago: KU Leuven and Hewlett Packard Enterprise Advance AI Capabilities through New Supercomputer http://globenewswire.com/news-release/2018/04/24/1486115/0/en/KU-Leuven-and-Hewlett-Packard-Enterprise-Advance-AI-Capabilities-through-New-Supercomputer.html',
#    'created_at': '2018-04-24T11:47:21Z',
#    'user': {'id': 1277938,
#     'username': 'livetraderalerts',
#     'name': 'LiveTraderAlerts.com News feed',
#     'avatar_url': 'https://avatars.stocktwits.com/production/1277938/thumb-1526067389.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/1277938/thumb-1526067389.png',
#     'join_date': '2017-11-22',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 3646,
#     'following': 8,
#     'ideas': 517860,
#     'watchlist_stocks_count': 3,
#     'like_count': 6,
#     'plus_tier': 'life',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 3746,
#     'title': 'LiveTraderAlerts.com',
#     'url': 'https://LiveTraderAlerts.com'},
#    'symbols': [{'id': 12845,
#      'symbol': 'HPE',
#      'title': 'Hewlett Packard Enterprise',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 4353}],
#    'links': [{'title': 'KU Leuven and Hewlett Packard Enterprise Advance AI Capabilities through New Supercomputer',
#      'url': 'http://globenewswire.com/news-release/2018/04/24/1486115/0/en/KU-Leuven-and-Hewlett-Packard-Enterprise-Advance-AI-Capabilities-through-New-Supercomputer.html',
#      'shortened_url': 'http://globenewswire.com/news-release/2018/04/24/1486115/0/en/KU-Leuven-and-Hewlett-Packard-Enterprise-Advance-AI-Capabilities-through-New-Supercomputer.html',
#      'shortened_expanded_url': 'globenewswire.com/news-rele...',
#      'description': 'PALO ALTO, Calif., April 24, 2018 (GLOBE NEWSWIRE) -- Hewlett Packard Enterprise (NYSE: HPE) today announced a new supercomputer installation at KU Leuven, a Flemish research university consistently ranked as one of the five most innovative universities in the world. HPE collaborated with KU Leuven to develop and deploy Genius, a new supercomputer built to run artificial intelligence (AI) workloads.',
#      'image': 'https://globenewswire.com/news-release/logo/437728/0/437728.jpg?lastModified=03%2F23%2F2017%2016%3A05%3A29&size=2',
#      'created_at': '2018-04-24T11:47:22Z',
#      'video_url': None,
#      'source': {'name': 'GlobeNewswire News Room',
#       'website': 'https://globenewswire.com'}}],
#    'mentioned_users': [],
#    'entities': {'sentiment': None},
#    'filters': {'day_counts': 0, 'official_api': False}},
#   {'id': 120917876,
#    'body': '$HPE one of the most undervalued stocks: https://www.finstead.com/posts/HPE-buy-or-sell',
#    'created_at': '2018-04-23T18:09:48Z',
#    'user': {'id': 479892,
#     'username': 'ExtremeAlpha',
#     'name': 'ExtremeAlpha',
#     'avatar_url': 'https://avatars.stocktwits.com/production/479892/thumb-1504217401.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/479892/thumb-1504217401.png',
#     'join_date': '2015-03-05',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 956,
#     'following': 51,
#     'ideas': 12227,
#     'watchlist_stocks_count': 16,
#     'like_count': 308,
#     'plus_tier': '',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 2269,
#     'title': 'StockTwits Web',
#     'url': 'https://stocktwits.com'},
#    'symbols': [{'id': 12845,
#      'symbol': 'HPE',
#      'title': 'Hewlett Packard Enterprise',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 4353}],
#    'links': [{'title': 'Finstead - Hewlett Packard Enterprise Company (HPE) Buy or Sell Stock Guide',
#      'url': 'https://www.finstead.com/posts/HPE-buy-or-sell',
#      'shortened_url': 'https://www.finstead.com/posts/HPE-buy-or-sell',
#      'shortened_expanded_url': 'finstead.com/posts/HPE-buy-...',
#      'description': 'The analysis below may be helpful to you if you have any of the following questions about HPE stock: Is HPE a buy or a sell? Should I sell or hold HPE stock today? Is HPE a good buy / a good investment? What are HPE analyst opinions, recommendations, ratings?',
#      'image': 'https://www.finstead.com/img/logo-inverse.png',
#      'created_at': '2018-04-23T18:09:49Z',
#      'video_url': None,
#      'source': {'name': 'Finstead', 'website': 'https://www.finstead.com'}}],
#    'likes': {'total': 2, 'user_ids': [857540, 215620]},
#    'mentioned_users': [],
#    'entities': {'sentiment': None},
#    'filters': {'day_counts': 0, 'official_api': True}},
#   {'id': 120852515,
#    'body': 'Trade Ideas and notable options activity for the week ahead http://sabacapital.capital/  $AMBA $HPE $TSLA',
#    'created_at': '2018-04-23T02:53:13Z',
#    'user': {'id': 301024,
#     'username': 'SabaCapital13',
#     'name': 'SabaCapital',
#     'avatar_url': 'https://avatars.stocktwits.com/production/301024/thumb-1502966960.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/301024/thumb-1502966960.png',
#     'join_date': '2014-01-15',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 1524,
#     'following': 64,
#     'ideas': 9293,
#     'watchlist_stocks_count': 33,
#     'like_count': 723,
#     'plus_tier': '',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 2269,
#     'title': 'StockTwits Web',
#     'url': 'https://stocktwits.com'},
#    'symbols': [{'id': 8660,
#      'symbol': 'TSLA',
#      'title': 'Tesla, Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 279334},
#     {'id': 11361,
#      'symbol': 'AMBA',
#      'title': 'Ambarella, Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 13119},
#     {'id': 12845,
#      'symbol': 'HPE',
#      'title': 'Hewlett Packard Enterprise',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 4353}],
#    'links': [{'title': 'SabaCapital - Fundamentally and technically motivated trade ideas |',
#      'url': 'http://sabacapital.capital/',
#      'shortened_url': 'http://sabacapital.capital/',
#      'shortened_expanded_url': 'sabacapital.capital/',
#      'description': 'Fundamentally and Technically Motivated Trade Ideas and Analysis',
#      'image': 'http://sabacapital.capital/wp-content/uploads/2017/09/cropped-SAba-caoutal12.png',
#      'created_at': '2018-04-23T02:53:17Z',
#      'video_url': None,
#      'source': {'name': 'Sabacapital',
#       'website': 'http://sabacapital.capital'}}],
#    'mentioned_users': [],
#    'entities': {'sentiment': {'basic': 'Bullish'}},
#    'filters': {'day_counts': 0, 'official_api': True}},
#   {'id': 120846628,
#    'body': '$HPE  Is Hewlett Packard Stock Setting Up A Symmetrical Triangle Breakout? https://www.guerillastocktrading.com/stock-trading/hewlett-packard-stock-setting-symmetrical-triangle-breakout/',
#    'created_at': '2018-04-23T00:09:47Z',
#    'user': {'id': 919032,
#     'username': 'lancejepsen',
#     'name': 'Lance Jepsen',
#     'avatar_url': 'https://avatars.stocktwits.com/production/919032/thumb-1547479019.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/919032/thumb-1547479019.png',
#     'join_date': '2017-01-07',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 433,
#     'following': 2,
#     'ideas': 2652,
#     'watchlist_stocks_count': 0,
#     'like_count': 169,
#     'plus_tier': '',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 2269,
#     'title': 'StockTwits Web',
#     'url': 'https://stocktwits.com'},
#    'symbols': [{'id': 12845,
#      'symbol': 'HPE',
#      'title': 'Hewlett Packard Enterprise',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 4353}],
#    'links': [{'title': 'IS Hewlett Packard Stock Setting Up A Symmetrical Triangle Breakout?',
#      'url': 'https://www.guerillastocktrading.com/stock-trading/hewlett-packard-stock-setting-symmetrical-triangle-breakout/',
#      'shortened_url': 'https://www.guerillastocktrading.com/stock-trading/hewlett-packard-stock-setting-symmetrical-triangle-breakout/',
#      'shortened_expanded_url': 'guerillastocktrading.com/st...',
#      'description': 'Hewlett Packard stock could be setting up a Symmetrical Triangle breakout pattern. Large players volume is rising into the apex of the Symmetrical Triangle pattern which is bullish. Last Monday, April 16, 2018, a bullish Pocket Pivot signal (blue dot) occurred. The Twiggs Money Flow is rising but is still negative.',
#      'image': 'https://www.guerillastocktrading.com/wp-content/uploads/2018/04/hpe-chart.png',
#      'created_at': '2018-04-23T00:09:50Z',
#      'video_url': None,
#      'source': {'name': 'Guerillastocktrading',
#       'website': 'https://www.guerillastocktrading.com'}}],
#    'mentioned_users': [],
#    'entities': {'chart': {'thumb': 'https://charts.stocktwits.com/production/small_120846628.png',
#      'large': 'https://charts.stocktwits.com/production/large_120846628.png',
#      'original': 'https://charts.stocktwits.com/production/original_120846628.png',
#      'url': 'https://charts.stocktwits.com/production/original_120846628.png'},
#     'sentiment': None},
#    'filters': {'day_counts': 0, 'official_api': True}},
#   {'id': 120809670,
#    'body': 'We have detected 2 negative indicators as of 04-20 for $HPE More info at http://www.dividendbot.com?s=HPE',
#    'created_at': '2018-04-22T00:48:08Z',
#    'user': {'id': 1279378,
#     'username': 'DividendBot',
#     'name': 'Dividend Bot',
#     'avatar_url': 'https://avatars.stocktwits.com/production/1279378/thumb-1512247023.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/1279378/thumb-1512247023.png',
#     'join_date': '2017-11-23',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 1041,
#     'following': 59,
#     'ideas': 102594,
#     'watchlist_stocks_count': 0,
#     'like_count': 0,
#     'plus_tier': '',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 3771,
#     'title': 'Dividend Bot',
#     'url': 'http://dividendbot.com/'},
#    'symbols': [{'id': 12845,
#      'symbol': 'HPE',
#      'title': 'Hewlett Packard Enterprise',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 4353}],
#    'links': [{'title': 'HPE | Dividend Bot',
#      'url': 'http://www.dividendbot.com?s=HPE',
#      'shortened_url': 'http://www.dividendbot.com?s=HPE',
#      'shortened_expanded_url': 'dividendbot.com/?s=HPE',
#      'description': 'Insiders have made 2 acquisition(s) over past seven days. [see insider section below for more details]',
#      'image': None,
#      'created_at': '2018-04-22T00:48:09Z',
#      'video_url': None,
#      'source': {'name': 'Dividendbot',
#       'website': 'http://www.dividendbot.com'}}],
#    'mentioned_users': [],
#    'entities': {'sentiment': None},
#    'filters': {'day_counts': 0, 'official_api': False}},
#   {'id': 120764708,
#    'body': '$NVDA $AMZN $MSFT $ORCL $IBM $CRAY $HPQ $HPE $PSTG $NLST $MU Got Resilience? Anyone in storage servers needs to see this: https://youtu.be/BVji7uENZyU',
#    'created_at': '2018-04-21T00:47:12Z',
#    'user': {'id': 710303,
#     'username': 'bmaine4',
#     'name': 'Bruce Froehlich',
#     'avatar_url': 'https://avatars.stocktwits.com/production/710303/thumb-1464203353.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/710303/thumb-1464203353.png',
#     'join_date': '2016-03-18',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 36,
#     'following': 66,
#     'ideas': 3172,
#     'watchlist_stocks_count': 288,
#     'like_count': 990,
#     'plus_tier': '',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 2095,
#     'title': 'StockTwits For Android ',
#     'url': 'http://www.stocktwits.com/mobile'},
#    'symbols': [{'id': 864,
#      'symbol': 'AMZN',
#      'title': 'Amazon.com Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 243205},
#     {'id': 1434,
#      'symbol': 'CRAY',
#      'title': 'Cray Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 589},
#     {'id': 2735,
#      'symbol': 'MSFT',
#      'title': 'Microsoft Corporation',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 155320},
#     {'id': 2862,
#      'symbol': 'NLST',
#      'title': 'Netlist Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 13382},
#     {'id': 2925,
#      'symbol': 'NVDA',
#      'title': 'NVIDIA Corporation',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 161612},
#     {'id': 3012,
#      'symbol': 'ORCL',
#      'title': 'Oracle Corp.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 12794},
#     {'id': 5715,
#      'symbol': 'HPQ',
#      'title': 'Hewlett-Packard Company',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 8163},
#     {'id': 5786,
#      'symbol': 'IBM',
#      'title': 'International Business Machines Corp.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 35685},
#     {'id': 6403,
#      'symbol': 'MU',
#      'title': 'Micron Technology Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 97303},
#     {'id': 12792,
#      'symbol': 'PSTG',
#      'title': 'Pure Storage',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 3617},
#     {'id': 12845,
#      'symbol': 'HPE',
#      'title': 'Hewlett Packard Enterprise',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 4350}],
#    'links': [{'title': 'RAID No More: GPUs Power NSULATE for Extreme HPC Data Protection',
#      'url': 'https://youtu.be/BVji7uENZyU',
#      'shortened_url': 'https://youtu.be/BVji7uENZyU',
#      'shortened_expanded_url': 'youtube.com/watch?v=BVji7uE...',
#      'description': 'In this video from GTC 2018, Alexander St . John from Nyriad demonstrates how the company\'s NSULATE software running on Advanced HPC gear provides extreme data protection for HPC data. "RAID6 was standardized in 1993 in an era of single-core computing. For exascale computing, RAID is an obstacle to higher performance and resilience.',
#      'image': 'https://i.ytimg.com/vi/BVji7uENZyU/hqdefault.jpg',
#      'created_at': '2018-04-21T00:47:12Z',
#      'video_url': '//cdn.embedly.com/widgets/media.html?src=https%3A%2F%2Fwww.youtube.com%2Fembed%2FBVji7uENZyU%3Ffeature%3Doembed=http%3A%2F%2Fwww.youtube.com%2Fwatch%3Fv%3DBVji7uENZyU=https%3A%2F%2Fi.ytimg.com%2Fvi%2FBVji7uENZyU%2Fhqdefault.jpg=38dd9af069fe4432a0efe5550d2ea231=text%2Fhtml=youtube',
#      'source': {'name': 'YouTube', 'website': 'https://www.youtube.com/'}}],
#    'likes': {'total': 1, 'user_ids': [1447327]},
#    'mentioned_users': [],
#    'entities': {'sentiment': None},
#    'filters': {'day_counts': 0, 'official_api': True}},
#   {'id': 120736911,
#    'body': '$HPE Hewlett Packard Enterprise call volume above normal and directionally bullish',
#    'created_at': '2018-04-20T19:48:46Z',
#    'user': {'id': 850976,
#     'username': 'MariaC82',
#     'name': 'Maria Chaudhry',
#     'avatar_url': 'https://avatars.stocktwits.com/production/850976/thumb-1547223587.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/850976/thumb-1547223587.png',
#     'join_date': '2016-09-30',
#     'official': True,
#     'identity': 'Official',
#     'classification': ['official'],
#     'followers': 35029,
#     'following': 143,
#     'ideas': 39598,
#     'watchlist_stocks_count': 300,
#     'like_count': 42937,
#     'plus_tier': 'month',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 2269,
#     'title': 'StockTwits Web',
#     'url': 'https://stocktwits.com'},
#    'symbols': [{'id': 12845,
#      'symbol': 'HPE',
#      'title': 'Hewlett Packard Enterprise',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 4353}],
#    'mentioned_users': [],
#    'entities': {'chart': {'thumb': 'https://charts.stocktwits.com/production/small_120736911.png',
#      'large': 'https://charts.stocktwits.com/production/large_120736911.png',
#      'original': 'https://charts.stocktwits.com/production/original_120736911.png',
#      'url': 'https://charts.stocktwits.com/production/original_120736911.png'},
#     'sentiment': None},
#    'filters': {'day_counts': 0, 'official_api': True}},
#   {'id': 120667601,
#    'body': '4/20 Low IV Watch List: $SVXY $UNG $KORS $CIEN $STZ $URBN $LULU $UVXY $JNUG $FXE $NRG $KODK $XNET $UNIT $GDXJ $NUGT $EFA $HPE $MOMO $DVMT',
#    'created_at': '2018-04-20T13:03:39Z',
#    'user': {'id': 937959,
#     'username': 'TradeAcademyCo',
#     'name': 'Trade Academy',
#     'avatar_url': 'https://avatars.stocktwits.com/production/937959/thumb-1490373514.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/937959/thumb-1490373514.png',
#     'join_date': '2017-01-27',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 1182,
#     'following': 0,
#     'ideas': 4788,
#     'watchlist_stocks_count': 4,
#     'like_count': 23,
#     'plus_tier': '',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 2269,
#     'title': 'StockTwits Web',
#     'url': 'https://stocktwits.com'},
#    'symbols': [{'id': 1314,
#      'symbol': 'CIEN',
#      'title': 'CIENA Corp.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 3151},
#     {'id': 2562,
#      'symbol': 'LULU',
#      'title': 'Lululemon Athletica Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 22028},
#     {'id': 3963,
#      'symbol': 'URBN',
#      'title': 'Urban Outfitters Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 3399},
#     {'id': 5129,
#      'symbol': 'EFA',
#      'title': 'iShares MSCI EAFE Index',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 907},
#     {'id': 5151,
#      'symbol': 'KODK',
#      'title': 'Eastman Kodak Co.',
#      'aliases': ['EK', 'EKOD'],
#      'is_following': False,
#      'watchlist_count': 8333},
#     {'id': 5429,
#      'symbol': 'FXE',
#      'title': 'CurrencyShares Euro Trust',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 1064},
#     {'id': 6558,
#      'symbol': 'NRG',
#      'title': 'NRG Energy, Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 2506},
#     {'id': 7305,
#      'symbol': 'STZ',
#      'title': 'Constellation Brands Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 8542},
#     {'id': 7568,
#      'symbol': 'UNG',
#      'title': 'United States Natural Gas',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 10318},
#     {'id': 7948,
#      'symbol': 'GDXJ',
#      'title': 'VanEck Vectors Junior Gold Miners ETF',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 8268},
#     {'id': 9553,
#      'symbol': 'NUGT',
#      'title': 'Direxion Daily Gold Miners Bull 3X Shrs',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 45817},
#     {'id': 11085,
#      'symbol': 'KORS',
#      'title': 'Michael Kors Holdings Ltd',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 6296},
#     {'id': 11188,
#      'symbol': 'UVXY',
#      'title': 'ProShares Trust Ultra VIX Short-Term Futures ETF',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 40854},
#     {'id': 11253,
#      'symbol': 'SVXY',
#      'title': 'Short VIX Short-Term Futures ETF',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 11228},
#     {'id': 11631,
#      'symbol': 'JNUG',
#      'title': 'Direxion Daily Jr Gld Mnrs Bull 3X Shrs',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 55998},
#     {'id': 12040,
#      'symbol': 'XNET',
#      'title': 'Xunlei',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 6981},
#     {'id': 12310,
#      'symbol': 'MOMO',
#      'title': 'Momo',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 14520},
#     {'id': 12845,
#      'symbol': 'HPE',
#      'title': 'Hewlett Packard Enterprise',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 4353},
#     {'id': 13253,
#      'symbol': 'DVMT',
#      'title': 'Dell Technologies Inc',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 996},
#     {'id': 13372,
#      'symbol': 'UNIT',
#      'title': 'Uniti Group Inc ',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 1907}],
#    'likes': {'total': 3, 'user_ids': [797207, 1032336, 910484]},
#    'mentioned_users': [],
#    'entities': {'sentiment': None},
#    'filters': {'day_counts': 0, 'official_api': True}},
#   {'id': 120619844,
#    'body': 'Hewlett Packard Enterprise Director Margaret Whitman Sells $11,835,440.00 in $HPE http://www.marketbeat.com/i/270952',
#    'created_at': '2018-04-20T00:07:57Z',
#    'user': {'id': 1034235,
#     'username': 'MarketBeatInsiderTrades',
#     'name': 'MarketBeat Insider Trades',
#     'avatar_url': 'https://avatars.stocktwits.com/production/1034235/thumb-1492706962.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/1034235/thumb-1492706962.png',
#     'join_date': '2017-04-20',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 2004,
#     'following': 60,
#     'ideas': 113103,
#     'watchlist_stocks_count': 0,
#     'like_count': 0,
#     'plus_tier': '',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 1022, 'title': 'Zapier', 'url': 'https://zapier.com/'},
#    'symbols': [{'id': 12845,
#      'symbol': 'HPE',
#      'title': 'Hewlett Packard Enterprise',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 4353}],
#    'links': [{'title': 'NYSE:HPE - Hewlett Packard Enterprise Stock Price, Price Target & More',
#      'url': 'http://www.marketbeat.com/i/270952',
#      'shortened_url': 'http://www.marketbeat.com/i/270952',
#      'shortened_expanded_url': 'marketbeat.com/stocks/NYSE/...',
#      'description': "Thinking about adding Hewlett Packard Enterprise (NYSE:HPE) stock to your your portfolio? View HPE's stock price, price target, analyst ratings, dividend information, earnings history, financials, history, insider trades, news headlines and SEC filings in real-time at MarketBeat.",
#      'image': 'https://www.marketbeat.com/logos/hewlett-packard-enterprise-co-logo.jpg',
#      'created_at': '2018-04-20T00:08:00Z',
#      'video_url': None,
#      'source': {'name': 'Marketbeat',
#       'website': 'https://www.marketbeat.com'}}],
#    'mentioned_users': [],
#    'entities': {'sentiment': None},
#    'filters': {'day_counts': 0, 'official_api': False}},
#   {'id': 120602334,
#    'body': '$HPE Director &quot;WHITMAN MARGARET C&quot; just cashed in 674,000 Options (Tran Code - M, S)  --- Insider Forms, iOS app',
#    'created_at': '2018-04-19T21:00:30Z',
#    'user': {'id': 909249,
#     'username': 'InsiderForms',
#     'name': 'Insider Forms',
#     'avatar_url': 'https://avatars.stocktwits.com/production/909249/thumb-1482551759.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/909249/thumb-1482551759.png',
#     'join_date': '2016-12-24',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 2142,
#     'following': 2,
#     'ideas': 190047,
#     'watchlist_stocks_count': 1,
#     'like_count': 0,
#     'plus_tier': '',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 3019,
#     'title': 'Insider Forms',
#     'url': 'http://stocktwits.com/InsiderForms'},
#    'symbols': [{'id': 12845,
#      'symbol': 'HPE',
#      'title': 'Hewlett Packard Enterprise',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 4353}],
#    'mentioned_users': [],
#    'entities': {'sentiment': None},
#    'filters': {'day_counts': 0, 'official_api': False}},
#   {'id': 120600521,
#    'body': 'Hewlett Packard Enterprise Co director just cashed-in 674,000 options  http://www.conferencecalltranscripts.org/4/summary/?id=4825566 $HPE',
#    'created_at': '2018-04-19T20:48:15Z',
#    'user': {'id': 210967,
#     'username': 'cctranscripts',
#     'name': 'Conference Call Transcripts',
#     'avatar_url': 'https://avatars.stocktwits.com/production/210967/thumb-1363372333.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/210967/thumb-1363372333.png',
#     'join_date': '2013-01-30',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 5327,
#     'following': 9,
#     'ideas': 2071769,
#     'watchlist_stocks_count': 0,
#     'like_count': 736,
#     'plus_tier': '',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 1130,
#     'title': 'cctranscripts',
#     'url': 'http://conferencecalltranscripts.org'},
#    'symbols': [{'id': 12845,
#      'symbol': 'HPE',
#      'title': 'Hewlett Packard Enterprise',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 4353}],
#    'links': [{'title': 'Conference Call Transcripts',
#      'url': 'http://www.conferencecalltranscripts.org/4/summary/?id=4825566',
#      'shortened_url': 'http://www.conferencecalltranscripts.org/4/summary/?id=4825566',
#      'shortened_expanded_url': 'conferencecalltranscripts.o...',
#      'description': 'Company Conference Call Transcripts',
#      'image': None,
#      'created_at': '2018-04-19T20:48:16Z',
#      'video_url': None,
#      'source': {'name': 'Conferencecalltranscripts',
#       'website': 'http://www.conferencecalltranscripts.org'}}],
#    'mentioned_users': [],
#    'entities': {'sentiment': None},
#    'filters': {'day_counts': 0, 'official_api': False}},
#   {'id': 120600402,
#    'body': '$HPE new insider selling: 674000 shares. http://insiderbuyingselling.com/?t=HPE',
#    'created_at': '2018-04-19T20:47:37Z',
#    'user': {'id': 1419740,
#     'username': 'insiderbuyingselling',
#     'name': 'sky',
#     'avatar_url': 'https://avatars.stocktwits.com/production/1419740/thumb-1522159697.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/1419740/thumb-1522159697.png',
#     'join_date': '2018-02-22',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 1214,
#     'following': 0,
#     'ideas': 40514,
#     'watchlist_stocks_count': 0,
#     'like_count': 0,
#     'plus_tier': '',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 4049,
#     'title': 'insiderbuyingselling',
#     'url': 'http://insiderbuyingselling.com'},
#    'symbols': [{'id': 12845,
#      'symbol': 'HPE',
#      'title': 'Hewlett Packard Enterprise',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 4353}],
#    'links': [{'title': 'Tracking insider buying and selling stocks for Hewlett Packard Enterprise Co ( HPE )',
#      'url': 'http://insiderbuyingselling.com/?t=HPE',
#      'shortened_url': 'http://insiderbuyingselling.com/?t=HPE',
#      'shortened_expanded_url': 'insiderbuyingselling.com/?t...',
#      'description': 'Tracking insider buying and selling stocks for Hewlett Packard Enterprise Co ( HPE ). at insiderbuyingselling.com',
#      'image': None,
#      'created_at': '2018-04-19T20:47:38Z',
#      'video_url': None,
#      'source': {'name': 'Insiderbuyingselling',
#       'website': 'http://insiderbuyingselling.com'}}],
#    'mentioned_users': [],
#    'entities': {'sentiment': None},
#    'filters': {'day_counts': 0, 'official_api': False}},
#   {'id': 120589827,
#    'body': '$XRX closing strong,$hpe chatter yesterday',
#    'created_at': '2018-04-19T19:52:43Z',
#    'user': {'id': 18393,
#     'username': 'fatcoin888',
#     'name': 'rob b',
#     'avatar_url': 'https://avatars.stocktwits.com/production/18393/thumb-1279112686.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/18393/thumb-1279112686.png',
#     'join_date': '2010-07-07',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 159,
#     'following': 10,
#     'ideas': 6049,
#     'watchlist_stocks_count': 0,
#     'like_count': 424,
#     'plus_tier': '',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 2269,
#     'title': 'StockTwits Web',
#     'url': 'https://stocktwits.com'},
#    'symbols': [{'id': 7832,
#      'symbol': 'XRX',
#      'title': 'Xerox Corp.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 2353},
#     {'id': 12845,
#      'symbol': 'HPE',
#      'title': 'Hewlett Packard Enterprise',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 4353}],
#    'mentioned_users': [],
#    'entities': {'sentiment': None},
#    'filters': {'day_counts': 0, 'official_api': True}},
#   {'id': 120562017,
#    'body': '$HPE Price rally after CrowdThnk&#39;s forecast of move higher based on Positioning Data: https://crowdthnk.com/stocks/HPE',
#    'created_at': '2018-04-19T17:20:01Z',
#    'user': {'id': 1352973,
#     'username': 'CrowdThnk',
#     'name': 'CrowdThnk',
#     'avatar_url': 'https://avatars.stocktwits.com/production/1352973/thumb-1518208375.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/1352973/thumb-1518208375.png',
#     'join_date': '2018-01-05',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 188,
#     'following': 0,
#     'ideas': 23132,
#     'watchlist_stocks_count': 9,
#     'like_count': 0,
#     'plus_tier': '',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 2269,
#     'title': 'StockTwits Web',
#     'url': 'https://stocktwits.com'},
#    'symbols': [{'id': 12845,
#      'symbol': 'HPE',
#      'title': 'Hewlett Packard Enterprise',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 4353}],
#    'links': [{'title': 'CrowdThnk',
#      'url': 'https://crowdthnk.com/stocks/HPE',
#      'shortened_url': 'https://crowdthnk.com/stocks/HPE',
#      'shortened_expanded_url': 'crowdthnk.com/stocks/HPE',
#      'description': '© Copyright 2017 CrowdThnk. All Rights reserved',
#      'image': None,
#      'created_at': '2018-04-19T17:20:02Z',
#      'video_url': None,
#      'source': {'name': 'Crowdthnk', 'website': 'https://crowdthnk.com'}}],
#    'mentioned_users': [],
#    'entities': {'sentiment': None},
#    'filters': {'day_counts': 0, 'official_api': True}},
#   {'id': 120532905,
#    'body': '$HPE go to HP in medium term!',
#    'created_at': '2018-04-19T14:41:18Z',
#    'user': {'id': 1451038,
#     'username': 'daniyari',
#     'name': 'Daniyar',
#     'avatar_url': 'http://avatars.stocktwits.com/images/default_avatar_thumb.jpg',
#     'avatar_url_ssl': 'https://s3.amazonaws.com/st-avatars/images/default_avatar_thumb.jpg',
#     'join_date': '2018-03-21',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 4,
#     'following': 11,
#     'ideas': 33,
#     'watchlist_stocks_count': 21,
#     'like_count': 56,
#     'plus_tier': '',
#     'premium_room': '',
#     'trade_app': False},
#    'source': {'id': 1149,
#     'title': 'StockTwits for iOS',
#     'url': 'http://www.stocktwits.com/mobile'},
#    'symbols': [{'id': 12845,
#      'symbol': 'HPE',
#      'title': 'Hewlett Packard Enterprise',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 4353}],
#    'likes': {'total': 2, 'user_ids': [1455088, 1459091]},
#    'mentioned_users': [],
#    'entities': {'chart': {'thumb': 'https://charts.stocktwits.com/production/small_120532905.png',
#      'large': 'https://charts.stocktwits.com/production/large_120532905.png',
#      'original': 'https://charts.stocktwits.com/production/original_120532905.png',
#      'url': 'https://charts.stocktwits.com/production/original_120532905.png'},
#     'sentiment': {'basic': 'Bullish'}},
#    'filters': {'day_counts': 0, 'official_api': True}}]}

# %%
if not (response['cursor']['more']):
    print("Hello")
